# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My Drive/IssuesManagement
# Out:
# /content/drive/.shortcut-targets-by-id/1Hgps4QuC_8w15htjlDJJFgm2WyvBtk5Y/IssuesManagement

# %%
PROJECT_NAME = "FLUME"

TEXT_FEATURES = ["title", "description", "summary"]
ADDING_TIME_FEATURES = ["CC", "CU"]

MAXLEN = 256
MODEL_NAME = "LSTM"
EMBEDDING_METHOD = "GloVe"

# %% [markdown]
# # Train Tokenizers

# %%
# !pip install tokenizers
# Out:
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.10/dist-packages (0.15.0)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers) (0.20.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers) (2023.11.17)

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.16.1-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: dill, multiprocess, datasets
# Successfully installed datasets-2.16.1 dill-0.3.7 multiprocess-0.70.15

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
tokenizer = Tokenizer(BPE(unk_token="[UNK]"))
from tokenizers.trainers import BpeTrainer
trainer = BpeTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"])
from tokenizers.pre_tokenizers import Whitespace
tokenizer.pre_tokenizer = Whitespace()

# %%
import pandas as pd

# %%
# train_links = pd.read_csv(
#     f"data/{PROJECT_NAME}/train_links.csv", keep_default_na=False)
# train_links['label'] = train_links['label'].map(lambda x: int(x!=0))
# issues = pd.read_csv(
#     f"data/{PROJECT_NAME}/preprocessed_attributes.csv", index_col="key")
# issues['created'] = pd.to_datetime(issues['created'], utc=True)
# issues['updated'] = pd.to_datetime(issues['updated'], utc=True)
# issues = issues.fillna(" ")
# first_feature = TEXT_FEATURES[0]
# issues["text"] = issues[first_feature]
# if len(TEXT_FEATURES)>1:
#   for feature in TEXT_FEATURES[1:]:
#     issues["text"] = issues["text"] + " " + issues[feature]

# %%
# texts = list(issues["text"].values)

# %%
# from sklearn.model_selection import train_test_split

# # Split the data into training, validation, and test sets
# train_texts, test_texts = train_test_split(texts, test_size=0.2, random_state=42)
# valid_texts, test_texts = train_test_split(test_texts, test_size=0.5, random_state=42)

# # Function to write a list of texts to a file
# def write_to_file(file_path, text_list):
#     with open(file_path, 'w', encoding='utf-8') as file:
#         file.writelines(text_list)

# # Write the sets to separate files
# write_to_file('train.txt', train_texts)
# write_to_file('valid.txt', valid_texts)
# write_to_file('test.txt', test_texts)

# %%
# files = [f"{split}.txt" for split in ["test", "train", "valid"]]
# tokenizer.train(files=files)

# %%
# tokenizer.save("custom-tokenizer.json")

# %%
# vocab = tokenizer.get_vocab()
# sorted_vocab = dict(sorted(vocab.items())).keys()

# %%
# len(sorted_vocab)
# Out:
# 27000

# %%
# def find_words_containing_token(token, vocab_list):
#     matching_words = [word for word in vocab_list if token in word]
#     return matching_words

# %%
# for token, token_id in vocab.items():
#   matching_words = find_words_containing_token(token, sorted_vocab)
#   if len(matching_words)>1:
#     print("\n------------\n")
#     print(token)
#     for word in matching_words:
#       if word!=token:
#         print(word)
# Out:
# Streaming output truncated to the last 5000 lines.
# inabilty
# isdebugenabled
# issecurityenabled
# maintainability
# maintainable
# monitorrunnable
# nabble
# ownable
# positionwriterrunnable
# reasonable
# reasonably
# runnable
# runnableadapter
# runnableerrorforwarder
# runnables
# s_enabled
# setenabled
# setenabledprotocols
# shutdownablethread
# spooldirectoryrunnable
# threadrenamingrunnable
# txnabor
# txnabortedexception
# unab
# unabl2020
# unable
# unopenable
# unreasonable
#
# ------------
#
# recreate
# recreated
#
# ------------
#
# cleanup
# abandonedconnectioncleanup
# abandonedconnectioncleanupthread
# cleanupenricher
# cleanuplogevent
# cleanuplogeventenrichbuilder
# cleanups
# cleanupwritebuffer
# connectioncleanup
#
# ------------
#
# 通
# リセマラめんどくさいし緑茶来たから普通にこのまま
# リセマラめんどくさいし緑茶来たから普通にこのまま進める
# 文件通过inode
# 文件通过inode进行唯一标识
# 普通
# 普通にこのまま
# 来たから普通にこのまま
# 通过inode
#
# ------------
#
# combination
# combinations
#
# ------------
#
# 1722
# 17227827
#
# ------------
#
# macy
# macys
# pharmacyname
#
# ------------
#
# abs
# absent
# absm
# absmiddle
# absolute
# abstact
# abstactrpcsink
# abstr
# abstra
# abstract
# abstractavroeventserializer
# abstractchannel
# abstractchecksu
# abstractchecksumpolicy
# abstractcollection
# abstractcommand
# abstractconfig
# abstractconfigurationprovider
# abstractconnector
# abstractcoordinator
# abstracted
# abstractfileconfiguration
# abstractfileconfigurationprovider
# abstracth
# abstracthdfs
# abstracthdfssink
# abstracthdfswrite
# abstracthdfswriter
# abstracthttpclient
# abstractinterruptible
# abstractinterruptiblechannel
# abstraction
# abstractjaxb
# abstractjaxbprovider
# abstractlifecycle
# abstractlist
# abstractlogger
# abstractloggerwrapper
# abstractmap
# abstractmessage
# abstractmessagelite
# abstractmetho
# abstractmethoderror
# abstractnio
# abstractnioselector
# abstractnioworker
# abstractnonblockingserver
# abstractnonblockingserverargs
# abstractoio
# abstractoioworker
# abstractoutputformat
# abstractparser
# abstractpollablesource
# abstractpool
# abstractpooled
# abstractpooledconnadapter
# abstractpoolent
# abstractpoolentry
# abstractqueued
# abstractqueuedsynchronizer
# abstractresource
# abstractresourcemethoddispatchprovider
# abstractrpcclient
# abstractrpcsink
# abstractselectthread
# abstractserverargs
# abstractsink
# abstractsinkprocessor
# abstractsinkselector
# abstractsource
# abstractsurefi
# abstractsurefiremojo
# abstracttraversable
# abstracttrevni
# abstracttrevniavroeventserializer
# abstractverifier
# databse
# getabsolute
# getabsolutepath
# grabs
# keytabs
# labs
# putifabsent
# tabseparated
# testabstract
# testabstractlogicalnodemanager
#
# ------------
#
# 1409
# 140958
#
# ------------
#
# executeafter
# executeafterpreconditionschecked
#
# ------------
#
# retention_period
# default_min_log_retention_period
# wal_min_retention_period
#
# ------------
#
# metastoreclient
# ablehivemetastoreclient
# cacheablehivemetastoreclient
# gethivemetastoreclient
# getmetastoreclient
# hivemetastoreclient
# retryingmetastoreclient
#
# ------------
#
# bha
# bhaskar
# blobhandler
#
# ------------
#
# 95
# 0295
# 0395
# 04972953
# 0876088142395
# 095
# 095000
# 0956
# 0956f
# 0957
# 095a
# 09958
# 0x00000000fb829588
# 0x00007f3e3c095000
# 0x129d953d26c
# 0x129d953d26c0000
# 0x129d953d26c0001
# 104955517
# 1056c129b10c95cee
# 1056c129b10c95cee50e0c3f77e3096
# 1056c129b10c95cee50e0c3f77e309668f82bfc6
# 1195
# 11956
# 121958
# 122585423857995
# 122585423857995_
# 12953732
# 12953732_image
# 13202095
# 1338286279596
# 134862061951
# 13509958
# 1350995824815
# 135959
# 1359598587425
# 1369355138695
# 1381195
# 1381195210953
# 13841952960
# 1384195296058
# 1386560295
# 1386560295104
# 1386560349521
# 138695
# 1388647956
# 1391957
# 1391957195572
# 140958
# 143951131
# 1441895965
# 1441895965442
# 1441895965538
# 1451095068
# 1595
# 15e5a95d
# 1623195
# 1623195625
# 1623195640
# 1623195647
# 1659507
# 165950727
# 1659527
# 165952737
# 1695
# 17295
# 1795
# 18129953
# 1895965
# 195
# 1950
# 19501368
# 1951
# 19528
# 1952960
# 1954
# 19546240
# 195572
# 195f163
# 1b95e0
# 20595071802
# 205950718029499
# 2061951
# 210953
# 21757952
# 2295
# 2329552799
# 2329552799040638
# 23808904976957
# 2380890497695726
# 2395
# 2795545
# 279596
# 286795624
# 295
# 29502
# 2953
# 2957
# 29591
# 29953
# 36847695
# 3795
# 3895
# 395
# 39977782795545
# 428595
# 42859568720
# 435584395296983
# 445125995972908
# 445239286795624
# 44954
# 455959
# 495
# 4950
# 50692789519690425
# 5069280957
# 50692809571710425
# 51829953
# 518299533012218
# 542b1695
# 542b1695033d330eb00ae
# 542b1695033d330eb00ae81713fdc838b88332b6
# 57952
# 595
# 5957
# 595780d9
# 5959
# 5a95d
# 60953
# 67489551254
# 6748955125414911
# 695
# 73016743409545744
# 7528094804972953
# 752809480497295360
# 76995
# 769951623909325
# 795
# 795560527813415_25
# 7956
# 82f0957
# 82f0957804be0ca
# 82f0957804be0cafb4d83e46e
# 833895
# 87295
# 8729556570223344
# 895
# 91957
# 9280957
# 950
# 9500a0
# 9500a0fd008
# 9500a0fd0084429fe7b0ecf18132be2b
# 951
# 951969
# 9519690425
# 952
# 9520
# 95296
# 95296983
# 953
# 95376ms
# 954
# 955
# 95584
# 9558423
# 956
# 957
# 958
# 95875535167
# 959
# 9597
# 95972908
# 95cee
# 95d
# 95e0
# 976957
# 995
# b10c95cee
# b1695
# b3dbe9c0956f
# blk_709795560527813415_25
# blk_709795560527813415_25801594
# c129b10c95cee
# c3195f163
# c3195f16324f43c8
# d953
# d953d26c
# dfsclient_nonmapreduce_833895
# dfsclient_nonmapreduce_833895359_50
# eefefa941a60c0982f0957804be0cafb4d83e46e
# f0957
# id2760395
# surefire30095875535167
# surefire300958755351670987tmp
# surefire455959
# surefire455959252081693840tmp
# surefirebooter4589769951623909325
# usersroshanappdatalocaltemp1369355138695
#
# ------------
#
# commits
# commitsync
#
# ------------
#
# war_
# war__flumeagen
#
# ------------
#
# 00069
# msg00069
#
# ------------
#
# 7f
# 0e7005136e4160ed4cc157c4ddd7f
# 0e7005136e4160ed4cc157c4ddd7f4f1c6e11ffa
# 0x00000007fae00000
# 0x00000007fc2
# 0x00000007fc2c0000
# 0x00007f
# 0x00007f1d
# 0x00007f1d6400
# 0x00007f1d64009800
# 0x00007f1d68018800
# 0x00007f1d9b
# 0x00007f1d9b163000
# 0x00007f1d9b364000
# 0x00007f2e
# 0x00007f2e26419800
# 0x00007f2e2e8cd
# 0x00007f2e2e8cd000
# 0x00007f3e
# 0x00007f3e1c
# 0x00007f3e1c00
# 0x00007f3e1c001800
# 0x00007f3e1c006800
# 0x00007f3e1c007800
# 0x00007f3e2800
# 0x00007f3e28002000
# 0x00007f3e300
# 0x00007f3e3000
# 0x00007f3e3000f800
# 0x00007f3e30010800
# 0x00007f3e30012800
# 0x00007f3e30019000
# 0x00007f3e3001a000
# 0x00007f3e3002c000
# 0x00007f3e34001000
# 0x00007f3e38
# 0x00007f3e3800
# 0x00007f3e38007000
# 0x00007f3e38008800
# 0x00007f3e3801a000
# 0x00007f3e381
# 0x00007f3e3819d800
# 0x00007f3e381a
# 0x00007f3e381a0800
# 0x00007f3e381a4800
# 0x00007f3e381a6000
# 0x00007f3e3c
# 0x00007f3e3c04
# 0x00007f3e3c04c000
# 0x00007f3e3c04d000
# 0x00007f3e3c04e800
# 0x00007f3e3c085000
# 0x00007f3e3c095000
# 0x00007f3e5000
# 0x00007f3e50001000
# 0x00007f3e55
# 0x00007f3e5558e000
# 0x00007f3e5568f000
# 0x00007f3e557
# 0x00007f3e55790000
# 0x00007f3e559
# 0x00007f3e55992000
# 0x00007f3e55a93
# 0x00007f3e55a93000
# 0x00007f3e56
# 0x00007f3e5606d000
# 0x00007f3e5616e000
# 0x00007f3e7
# 0x00007f3e74
# 0x00007f3e741b9000
# 0x00007f3e742ba000
# 0x00007f3e743bb
# 0x00007f3e743bb000
# 0x00007f3e744bc
# 0x00007f3e744bc000
# 0x00007f3e745bd
# 0x00007f3e745bd000
# 0x00007f3e746be000
# 0x00007f3e747bf000
# 0x00007f3e748
# 0x00007f3e748c0000
# 0x00007f3e749c1000
# 0x00007f3e74ac2000
# 0x00007f3e74bc3000
# 0x00007f3e74cc4000
# 0x00007f3e74dc5000
# 0x00007f3e74ec6000
# 0x00007f3e74fc7000
# 0x00007f3e750c
# 0x00007f3e750c8000
# 0x00007f3e751c9000
# 0x00007f3e752ca000
# 0x00007f3e755d3000
# 0x00007f3e756d
# 0x00007f3e756d4000
# 0x00007f3e757d5000
# 0x00007f3e758d6000
# 0x00007f3e84cf
# 0x00007f3e84cf2000
# 0x00007f3e88
# 0x00007f3e880
# 0x00007f3e8800f800
# 0x00007f3e88021000
# 0x00007f3e88022800
# 0x00007f3e88024800
# 0x00007f3e88026
# 0x00007f3e88026800
# 0x00007f3e880a7000
# 0x00007f3e880ea800
# 0x00007f3e880ef000
# 0x00007f3e880f1000
# 0x00007f3e8811
# 0x00007f3e88111800
# 0x00007f3e88113800
# 0x00007f3e88116000
# 0x00007f3e88118
# 0x00007f3e88118000
# 0x00007f3e8811b000
# 0x00007f3e8812e000
# 0x00007f3e88744
# 0x00007f3e88744000
# 0x00007f3e888
# 0x00007f3e8880a800
# 0x00007f3e8885
# 0x00007f3e88852800
# 0x00007f3e8885f800
# 0x00007f3e888ba800
# 0x00007f3e888f4000
# 0x00007f3e8c1b
# 0x00007f3e8c1b8000
# 0x00007f94
# 0x00007f94100b3d
# 0x00007f94100b3d10
# 0x00007f947
# 0x00007f947c00aba0
# 0x00007f949
# 0x00007f949cc73000
# 0x00007f94b4294000
# 0x00007fa
# 0x00007fa223474700
# 0x00007fa38a2bb
# 0x00007fa38a2bbd81
# 0x00007fa662000800
# 0x00007fcf
# 0x00007fcf9492c000
# 0x00007fcf98007000
# 0x00007fcf981a7000
# 0x00007fcf9d9a8000
# 0x00007fdeb
# 0x00007fdeb7972000
# 0x00007fdeb9000000
# 0x0b07f45
# 0x0b07f45d
# 0x3b17f000
# 0x7f
# 0x7f6d
# 0x7f6f
# 0x7fe91d9b
# 0x7fe91d9bf639
# 0xac7f
# 0xac7f61fa
# 115c7fa
# 115c7fa343a66
# 17f000
# 1c7fqcd
# 27f468
# 30a2d5396115c7fa343a66
# 37fd
# 44b9b69a1b43d22047fc25687699
# 44b9b69a1b43d22047fc25687699098282f172a8
# 4537f94556
# 4537f94556c9ba71ffca316514e0c
# 4537f94556c9ba71ffca316514e0c0101f76b63b
# 47fc
# 65673e6989ba887d27f468991c1e27
# 77f
# 77fddc31
# 77ff
# 77ffc9ab
# 7d27f468
# 7d27f468991c1e27
# 7f50c
# 7f50c72fc
# 7fa
# 7fae00000
# 7fc2
# 7fde7f
# 7fde7f12540ae
# 7fde7f12540ae30a2d5396115c7fa343a66
# 7fde7f12540ae30a2d5396115c7fa343a66fd56d
# 7fqcd
# 96503a6e737f96
# 96503a6e737f9604ab3ee9397a5809ff
# 977f
# 9e0bc5bf4865673e6989ba887d27f468991c1e27
# a4c5af0da1de3a7f50c72fc
# a4c5af0da1de3a7f50c72fc7edaa1f653ca276dd
# a9b37fd
# a9b37fd75ee2e473
# ac7f
# b07f45
# c157c4ddd7f
# c4ddd7f
# c7fa
# d22047fc
# d22047fc25687699
# d7f
# ddd7f
# de7f
# e4160ed4cc157c4ddd7f
# e737f96
# vy1c7fqcd
# vy1c7fqcdqvq5grcqp6q5j
# vy1c7fqcdqvq5grcqp6q5jyyb302khyz
#
# ------------
#
# upgrade
# upgraded
# upgrades
# upgradeto2_
# upgradeto2_2
# upgradeto2_4
#
# ------------
#
# co4
# alco4
# fvm2pkpwuaalco4
# uaalco4
#
# ------------
#
# dual_channel
# use_dual_channel
#
# ------------
#
# tcloud
# tcloud_syncer
#
# ------------
#
# 0x00000000cfae4f
# 0x00000000cfae4f40
# 0x00000000cfae4f58
# 0x00000000cfae4f88
# 0x00000000cfae4fa0
# 0x00000000cfae4fd0
#
# ------------
#
# j2e
# noj2e
# noj2ee
#
# ------------
#
# allproviders
# executeallproviders
#
# ------------
#
# petion
# excpetion
#
# ------------
#
# 7822
# 13057822
# 13057822_screenshot
#
# ------------
#
# 9334
# 2069334
#
# ------------
#
# hivesink
# testhivesink
#
# ------------
#
# ching
# attaching
# batching
# batchingdecorator
# branching
# cachepatternmatching
# caching
# catching
# fetching
# getmatching
# getmatchingfiles
# getmatchingfilesnocache
# launching
# matching
# patching
# reaching
# searching
# switching
# touching
# unbatching
# unbatchingdecorator
# watching
#
# ------------
#
# node1
# barnode1
# foonode1
# namenode1
#
# ------------
#
# offsets
# commitoffsets
# commitoffsetssync
# filetimeminoffsetseconds
# migrateoffsets
# offsetsandmetadata
# testoffsets
#
# ------------
#
# 置
# pos被重置为0
# 下配置是否错误
# 中如下配置是否错误
# 位置
# 就会按照老位置继续读取文件
# 置为0
# 置是否错误
# 老位置
# 老位置继续读取文件
#
# ------------
#
# 3165
# 316514e0c
# 4537f94556c9ba71ffca316514e0c
# 4537f94556c9ba71ffca316514e0c0101f76b63b
# c9ba71ffca316514e0c
# ffca316514e0c
#
# ------------
#
# cto
# 12factor
# 2fredirector
# _and_collectors
# _collectors
# _directory
# _tiering_flume_nodes_agents_and_collectors
# abledirectorysource
# abstractconnector
# abstractnioselector
# abstractoio
# abstractoioworker
# abstractoutputformat
# abstractsinkselector
# activemqinitialcontextfactory
# adaptivereceivebuffersizepredictorfactory
# advancedchannelpipelinefactory
# artifactory
# autocollector
# autocollectorsink
# autocollectorsource
# autocollectorsources
# basicrepositoryconnector
# buffersizepredictor
# buffersizepredictorfactory
# builddirectory
# builderfactory
# cdh3collector3
# channelfactory
# channelpipelinefactory
# channelselector
# channelselectorfactory
# cketfactory
# cleandirectory
# colector
# collector
# collector01
# collector02
# collector0_
# collector0_log_dir
# collector0_rpc
# collector1
# collector2
# collector3
# collector_agent
# collectordeco
# collectormagic
# collectors
# collectorsink
# collectorsinks
# collectorsource
# colllector
# compactor
# componentconfigurationfactory
# connectionfactory
# connector
# connectors
# constructor
# constructoraccessorimpl
# constructors
# containerfactory
# ctom
# ctopic
# ctor
# ctory
# cuctom
# current_working_directory
# customchannelfactory
# dateextractor
# defaultchannelfactory
# defaultdependencycollector
# defaultproxyfactory
# defaultrequestdirector
# defaultsinkfactory
# defaultsourcefactory
# delegatingconstructoraccessorimpl
# deletedirectory
# directo
# director
# directories
# directorio
# directory
# directoryafter
# directorysearch
# directorysource
# directorystream
# directorywith
# directorywithquotafeature
# disabledprotocolssocketfactory
# driverconnectionfactory
# eceivebuffersizepredictorfactory
# elasticsearchclientfactory
# elasticsearchindexrequestbuilderfactory
# emptydirectory
# epollselectorimpl
# epollselectorprovider
# eventbackingstorefactory
# eventqueuebackingstorefactory
# eventschannelselector
# eventserailizerfactory
# eventserializerfactory
# extractor
# extractors
# facto
# factor
# factored
# factories
# factors
# factory
# fastsaslserverfactory
# formatfactory
# fsdirectory
# genericconnectionfactory
# getconstructor
# getconstructor0
# getdeclaredconstructors
# getdeclaredconstructors0
# getiloggerfactory
# hdfsformatterfactory
# hdfswriterfactory
# hostselector
# httpcontainerfactory
# indexrequestfactory
# initialcontextfactory
# interceptorbuilderfactory
# isdirectory
# itoryconnector
# jdbcchannelproviderfactory
# jettyhttpcontainerfactory
# joinselector
# keymanagerfactory
# kqueueselectorimpl
# ldirectorysource
# lector
# lizerfactory
# loadbalancingchannelselector
# log4jloggerfactory
# logfilefactory
# loggerfactory
# messagebodyfactory
# mqqueueconnectionfactory
# multiplexingchannelselector
# multiplexingchannelselectorconfigurator
# nativeconstructoraccessorimpl
# nector
# ninitialcontextfactory
# nioclientsocketchannelfactory
# nioservercnxnfactory
# nioserversocketchannelfactory
# nodes_agents_and_collectors
# oiodatagramchannelfactory
# openselector
# orderselector
# pipelineeventschannelselector
# plainsaslserverfactory
# privategetdeclaredconstructors
# protosfactory
# providerfactory
# queueconnectionfactory
# reactor
# recursivedirectorysearch
# redirectoutputtofile
# refactor
# refactored
# refactoring
# refactors
# regex_extractor
# regexallextractor
# regexextractor
# regexextractorinterceptor
# regexextractorinterceptormillisseri
# regexextractorinterceptormillisserializer
# replicatingchannelselector
# replicationfactor
# resourcedirectory
# roundrobinorderselector
# rpcclientfactory
# securerpcclientfactory
# selectchannelconnector
# selector
# selectorconfig
# selectorimpl
# selectormanager
# selectorprovider
# selectors
# selectorserver
# selectorthread
# serverconnector
# serverfactory
# setsourcefactory
# sinkfactory
# sinkfactoryimpl
# sinkselector
# socketchannelfactory
# socketselector
# sourcedirectory
# sourcefactory
# sourcefactoryimpl
# spool_directory
# spoolabledirectorysource
# spooldirectory
# spooldirectoryrunnable
# spooldirectorysource
# spooldirectorysourceconfigurationconstants
# spoolingdirectory
# spoolingdirectorysource
# sqlexceptionfactory
# sqlexceptionfactory40
# sslcompressionchannelfactory
# sslsocketconnector
# sslsocketfactory
# subdirectories
# subdirectory
# syslogwireextractor
# telnetserverpipelinefactory
# testcollectorsink
# testelasticsearchindexrequestbuilderfactory
# testemptydirectoryafter
# testemptydirectoryaftercommittingfile
# testeventqueuebackingstorefactory
# testinitiallyemptydirectory
# testspooldirectorysource
# teststatictopic
# threadfactory
# threadfactorybuilder
# tibjmsinitialcontextfactory
# tibjmsqueueconnectionfactory
# tiloggerfactory
# tractor
# transceiverthreadfactory
# transportfactory
# trustmanagerfactory
# tthreadedselectorserver
# unsatisfactory
# vector
# vectorcvss
# víctor
# wlinitialcontextfactory
# wlinitialcontextfactorydelegate
# wmqinitialcontextfactory
# wsninitialcontextfactory
# xcontentfactory
# yamlfactory
# zookeeperconsumerconnector
#
# ------------
#
# 6d
# 06d000
# 0x00007f3e5606d000
# 0x00007f3e756d
# 0x00007f3e756d4000
# 0x6d
# 0x6d9c
# 0x7f6d
# 169756df81
# 169756df81aa110bd979a4bcb93
# 1dd6d80aa
# 1dd6d80aa61
# 26de6
# 4d7124700f678169756df81aa110bd979a4bcb93
# 536d
# 536d52f39
# 536d52f3908e
# 53ca276dd
# 56d
# 56df81
# 576d4
# 5ae576d4
# 6d1019
# 6d1019b3
# 6d581
# 6d581e80
# 6d80aa
# 7edaa1f653ca276dd
# 7fde7f12540ae30a2d5396115c7fa343a66fd56d
# 86d15
# 93a6d
# 99193a6d
# 99193a6d8078
# a1a6d
# a4c5af0da1de3a7f50c72fc7edaa1f653ca276dd
# a6d
# a86d
# caa64a1a6d
# caa64a1a6d4bc97be5993cb468516
# caa64a1a6d4bc97be5993cb468516e9ffe862794
# ceda6aa1126a01370641caf729d8b1dd6d80aa61
# dfc6dd56066
# e9b26de6
# fd56d
# t6c86d15
# t6c86d15a5593c90381ef2d
# t6c86d15a5593c90381ef2d0b33fa7aa9
#
# ------------
#
# ledged
# priviledged
# priviledgedactionexception
#
# ------------
#
# 1328
# 13285
# 13286
# 29731328
#
# ------------
#
# 0ies
# 0iesb4zyw
# 3ccajmzdxm8ngdswfan08phw9dct6lwkvwu8bcdey6pm0iesb4zyw
# dey6pm0iesb4zyw
# kvwu8bcdey6pm0iesb4zyw
#
# ------------
#
# 428
# 0x000000004286
# 0x0000000042869000
# 1428
# 14285
# 24288
# 2428837
# 242883747
# 242883779
# 428595
# 42859568720
# 4286
# 42889
# 428e
# 4428
# 524288
# 524288000
# 524288026
# 54280
#
# ------------
#
# yun
# ods_flume_json_yun
# ods_flume_json_yunc_transcation
#
# ------------
#
# interruptibly
# acquiresharedinterruptibly
# doacquiresharedinterruptibly
# sleepmicrosuninterruptibly
# sleepuninterruptibly
# suninterruptibly
# uninterruptibly
#
# ------------
#
# j3x
# 8za9dsfj3x
# a9bszwj3xhx
# a9dsfj3x
# ahktxvbfoa9bszwj3xhx
# dsfj3x
# fj3x
# j3xhx
# pfbid0mqahktxvbfoa9bszwj3xhx
# pfbid0mqahktxvbfoa9bszwj3xhxty1kfgpofdi7gckfnb9afawkwfetgv
# pfbid0mqahktxvbfoa9bszwj3xhxty1kfgpofdi7gckfnb9afawkwfetgv26m6yn7xcvhjl
#
# ------------
#
# dal
# addall
# dalvik
# readall
# readallfromchannel
# standalone
#
# ------------
#
# 5g
# 25gb
# 2bod_5g
# 5gb
# _5g
# q5g
# qvq5g
# qvq5grcqp6q5j
# vy1c7fqcdqvq5grcqp6q5j
# vy1c7fqcdqvq5grcqp6q5jyyb302khyz
#
# ------------
#
# ه
# الله
# الهرر
# الهرري
# ظه
# لعيونه
# له
# نه
# هرر
# ونه
# يحفظه
#
# ------------
#
# 0x000000076bc0
# 0x000000076bc0dc48
# 0x000000076bc0dd
# 0x000000076bc0dd68
# 0x000000076bc0dd78
#
# ------------
#
# ils
# adminutils
# bails
# beanutils
# ckeventutils
# clientutils
# cvedetails
# details
# detailsimpl
# emails
# emailsource
# encryptiontestutils
# fails
# filenameutils
# fileutils
# getobjectdetails
# getobjectdetailsimpl
# ilst
# javautils
# logutils
# maputils
# mockeventutils
# netutils
# numberutils
# printgcdetails
# reflectionutils
# stringutils
# syslogutils
# systemutils
# tails
# tailsource
# tailsrc
# tailsrcfile
# testsyslogutils
# testtailsource
# testtailsourcecursor
# testutils
# traceutils
# utils
# ventutils
# whilst
# zkutils
#
# ------------
#
# scal
# escal
# escalated
# escalation
# scala
# scalability
# scalable
# scale
# scaled
#
# ------------
#
# ab_sh
# rs_ab_sh
# rs_ab_shunt
#
# ------------
#
# loggerfactory
# getiloggerfactory
# log4jloggerfactory
# tiloggerfactory
#
# ------------
#
# boun
# acrossfileboundary
# arrayindexoutofboundsexception
# arrayoutofbound
# arrayoutofbounds
# bounce
# bouncycast
# bouncycastle
# bound
# boundaries
# boundary
# bounded
# boundedbytebufferreceive
# bounds
# fileboundary
# inbound
# indexoutofbound
# indexoutofboundsexception
# outbound
# outofbound
# stringindexoutofboundsexception
# testbatchedreadsacrossfileboundary
# unbound
# unbounded
#
# ------------
#
# esp
# bulkresponse
# correspon
# correspond
# corresponding
# correspondingly
# corresponds
# correspondsto
# customizeservletresponse
# deletesnapshotresponse
# deletesnapshotresponseproto
# desp
# despite
# errorresponse
# espa
# españa
# especially
# flumespe
# flumespec
# flumespecexception
# flumespecgen
# flumespool
# flumespooldir
# flumespooling
# getusablespace
# httpservletresponse
# jcsmperrorresponse
# jcsmperrorresponseexception
# namespace
# nextnonwhitespace
# reliablespoolingfile
# reliablespoolingfileeventreader
# resp
# resp_bytes
# respec
# respect
# respected
# respective
# respectively
# respon
# respond
# responded
# responder
# responderservlet
# responding
# response
# responseprocessor
# responses
# responsibi
# responsibilities
# responsible
# responsive
# scribespout
# snapshotresponse
# specificresponder
# testnamecorrespondsto
# testnamecorrespondstolatestread
# testreliablespoolingfileeventreader
# tresp
# unresponsive
# usablespace
# whitespace
# whitespaces
#
# ------------
#
# num
# _numbers
# _sequence_numbers
# buildnumber
# convertnumbertobig
# convertnumbertobigdecimal
# createnumber
# enum
# enumber
# enumer
# enumerate
# enumeration
# enums
# enumset
# getnum
# getnumcurrentreplicas
# mapforenum
# maxnumber
# maxnumberlines
# num_processors
# number
# number_of_
# number_of_replicas
# number_of_shards
# numbered
# numberformate
# numberformatexception
# numberformatexp
# numberformatexpcetion
# numbers
# numbertobig
# numberutils
# numer
# numeric
# numerical
# numerous
# numthreads
# reflectgetnumcurrentreplicas
# renumbered
# tcp_analyze_sequence_numbers
# visitenums
# visitenumswitch
#
# ------------
#
# zooke
# 22zookeeper
# dzookeeper
# followerzookeeperserver
# hbase_zookeeper_opts
# pollingzookeeper
# pollingzookeeperconfigurationprovider
# recoverablezookeeper
# stopzookeeper
# zookeeper
# zookeeper_opts
# zookeeperclient
# zookeeperconfigstore
# zookeeperconnect
# zookeeperconsumer
# zookeeperconsumerconnector
# zookeeperquorum
# zookeepersasl
# zookeepersaslclient
# zookeeperserver
# zookeeperservice
# zookeper
# zookepper
# zookepperconfigstore
#
# ------------
#
# 28a50
# 28a50da4
#
# ------------
#
# bytes
# 47bytes
# _bytes
# addwritebytes
# bytes0
# bytescurblock
# bytesin
# bytesout
# bytesremaining
# bytesstream
# bytestrea
# bytestreams
# bytestring
# byteswritable
# doreadbytes
# getbytes
# getsentbytes
# maxreadbufferbytes
# maxthriftframesizebytes
# readbufferbytes
# readbufferbytesallocated
# readbytes
# resp_bytes
# syncintervalbytes
# tobytestring
# totalbytes
# unsignedbytes
# writebytes
# writebytesnotag
# writerawbytes
#
# ------------
#
# x4x
# x4xmuxfxt
# x4xmuxfxtzuzlt5f
#
# ------------
#
# failovers
# agentfailoversink
# backofffailoversink
# diskfailoversource
# failoversink
# failoversinkprocessor
# failoversinkrunner
# testdiskfailoversource
#
# ------------
#
# subtrac
# subtracted
#
# ------------
#
# zeroflted
# zerofltedv
#
# ------------
#
# handling
# decodeerrorhandlingreplace
# errorhandling
# handlingreplace
# testutf8decodeerrorhandlingreplace
#
# ------------
#
# family
# _family
# column_family
# columnfamily
#
# ------------
#
# allows
# swallows
#
# ------------
#
# max_
# _max_
# buffer_max_
# buffer_max_line_length
# default_max_logs_size
# max_io_
# max_io_workers
# max_limit
# max_logs_size
# max_value
# wal_max_logs_size
#
# ------------
#
# pointe
# ableflumeeventpointer
# badcheckpointexception
# checkpointed
# checkpointexception
# comparableflumeeventpointer
# flumeeventpointer
# notinmountpointexception
# nullpointer
# nullpointerexception
# nullpointerexceptions
# nullpointexception
# pointed
# pointer
# pointerdoesnot
# pointers
# pointexception
# testunknownpointerdoesnot
# testunknownpointerdoesnotcausesearch
#
# ------------
#
# rogate
# hsurrogate
# ighsurrogate
# ishighsurrogate
# surrogate
#
# ------------
#
# 8188
# 1341818888517
#
# ------------
#
# iniscr
# iniscrptact
#
# ------------
#
# ߟ
# кߟ
#
# ------------
#
# fileattribute
# unixfileattribute
# unixfileattributeviews
#
# ------------
#
# 53968
# 64753968
# 647539686z
#
# ------------
#
# magic
# automagically
# collectormagic
# magically
#
# ------------
#
# 37324
# 1340697637324
#
# ------------
#
# timebased
# timebasedrollingpolicy
#
# ------------
#
# 6aknog7m
# 6aknog7mfk5
#
# ------------
#
# 138656
# 1386560295
# 1386560295104
# 1386560349
# 1386560349521
# 13865604146
# 1386560414635
#
# ------------
#
# ollbacktimes
# putrollbacktimes
# takerollbacktimes
#
# ------------
#
# mount
# amount
# amounts
# mounted
# notinmount
# notinmountpointexception
#
# ------------
#
# 67712787tmp
# surefire_1058311834274967712787tmp
#
# ------------
#
# sbt
# ivysbt
# xsbt
#
# ------------
#
# queues
# kqueueselectorimpl
# memoryqueuesink
# memoryqueuesource
# queueset
# queuesize
# queuestored
#
# ------------
#
# gain
# again
# agains
# eagain
#
# ------------
#
# jo
# _csmxjokhh4ta
# _csmxjokhh4tamfxeiwm6nb
# _jopts
# abstractsurefiremojo
# checkmojo
# configuretablejobproperite
# configuretablejobproperites
# cronjob
# cronjob_src
# e5rfcm2mwg54ofjo
# executemojo
# flume_master_jopts
# flume_node_jopts
# job
# jobclient
# jobproperite
# jobs
# joda
# joey
# joh
# johnsmart
# johny
# join
# joiner
# joins
# joinselector
# jojo
# jojochuang
# jok
# jokhh4ta
# jon
# jonanthan
# jonathan
# jopts
# jos
# josh
# journal
# journal_timestamp
# latjon
# livejournal
# major
# majority
# mojo
# mojoexecutionexception
# mojoexecutor
# mojofailure
# mojofailureexc
# mojofailureexception
# mojos
# mwg54ofjo
# ofjo
# pojo
# ratcheckmojo
# rejoin
# rejoins
# remojo
#
# ------------
#
# c0005
# jmscc0005
#
# ------------
#
# 0542456
# 1532490542456
#
# ------------
#
# lockposition
# lockpositionforwrite
#
# ------------
#
# cheventserializer
# elasticsearcheventserializer
#
# ------------
#
# 909
# 100500909
# 1484909338012
# 1623909325
# 190948
# 190948775
# 445256100500909
# 44b9b69a1b43d22047fc25687699098282f172a8
# 49091
# 769951623909325
# 9090
# 9092
# 909325
# 9094
# surefirebooter4589769951623909325
#
# ------------
#
# inv
# _reportinvalid
# _reportinvalidtoken
# asinvalidprotocolbufferexception
# checkifinvalid
# getinvolved
# inval
# invali
# invalid
# invalidates
# invalidindexname
# invalidindexnameexception
# invalidoperation
# invalidoperationexception
# invalidprotocolbuffer
# invalidprotocolbufferexception
# invalidtable
# invalidtxns
# invalidwire
# invalidwiretype
# invari
# invariably
# invariant
# invasive
# inverse
# investig
# investigate
# investigated
# investigating
# investigation
# invisi
# invisibly
# invo
# invocation
# invocations
# invocationtarge
# invocationtargetexception
# invoke
# invoke0
# invoked
# invokeexplo
# invokeexplosively
# invokemethod
# invokemethodwitharray
# invokeprovider
# invoker
# invokertransformer
# invokes
# invoking
# invol
# involve
# involved
# involves
# protobufrpcinvoker
# reportinvalid
# reportinvalidinitial
# requestinvoke
# retryinvocation
# retryinvocationhandler
# typeoutinvoker
#
# ------------
#
# tps
# _https
# bidirectionalhttpsource
# customhttpsource
# dioflumehttpservlet
# dotesthttps
# flumehttpservlet
# https
# httpserver
# httpservlet
# httpservletfilter
# httpservletrequest
# httpservletresponse
# httpsolrserver
# httpsource
# httpsourcehandler
# httpsrc
# httpstatu
# httpstatusserver
# internalhttpserver
# internalhttpserverexception
# keedioflumehttpservlet
# media_url_https
# mycustomhttpservletfilter
# nhttps
# oflumehttpservlet
# profile_background_image_url_https
# profile_image_url_https
# starthttpsourceserver
# statushttpserver
# statushttpservers
# testhttps
# testhttpsource
# testhttpssslv3
# teststatushttpserver
#
# ------------
#
# intercept
# clientstaticinterceptor
# configureinterceptors
# defaultmbeanserverinterceptor
# deserializerinterceptor
# deviceusagedeserializerinterceptor
# eventinterceptor
# fieldprojectinterceptor
# formatflumemetricsinterceptor
# hostinterceptor
# ibinterceptor
# interceptor
# interceptorbuilderfactory
# interceptorchain
# interceptors
# morphlineinterceptor
# projectinterceptor
# regexextractorinterceptor
# regexextractorinterceptormillisseri
# regexextractorinterceptormillisserializer
# regexfilteringinterceptor
# searchandreplaceinterceptor
# staticinterceptor
# test_interceptors
# testinterceptor
# timestampinterceptor
# usagedeserializerinterceptor
#
# ------------
#
# expi
# expir
# expiration
# expire
# expired
# expiredexception
# expires
# expiring
# leaseexpiredexception
# sessionexpiredexception
#
# ------------
#
# semana
# leasemanager
#
# ------------
#
# f5aa
# 21b74010c34cef9a977c75ab5dec4dc747d8f5aa
# 4dc747d8f5aa
# 747d8f5aa
# 977c75ab5dec4dc747d8f5aa
# d8f5aa
#
# ------------
#
# checkpointbackup
# checkpointbackupexecutor
# checkpointbackupthread
#
# ------------
#
# 1111
# 11111
# 11113
# 201111
#
# ------------
#
# sqlexceptionfactory
# sqlexceptionfactory40
#
# ------------
#
# 包含
# 名包含
# 文件名包含
# 文件名包含年月日时
# 文件名包含年月日时分秒
#
# ------------
#
# 6d1019
# 6d1019b3
#
# ------------
#
# ently
# apparently
# concurrently
# consequently
# consistently
# currently
# differently
# efficiently
# equivalently
# frequently
# gently
# independently
# inherently
# insufficiently
# intelligently
# intermittently
# persistently
# presently
# recently
# silently
# subsequently
# sufficiently
# transparently
#
# ------------
#
# óûte
# zepuóûte
#
# ------------
#
# sw
# 3ccajmzdxm8ngdswfan08phw9dct6lw
# 3ccajmzdxm8ngdswfan08phw9dct6lwkvwu8bcdey6pm0iesb4zyw
# _password
# abstracthdfswrite
# abstracthdfswriter
# answer
# answered
# answers
# blockcompresswriter
# byteswritable
# classwor
# classworlds
# dswfan
# dswfan08phw9dct6lw
# filterlogswithappid
# flume_ssl_keystore_password
# flume_ssl_truststore_password
# hdfswriter
# hdfswriterfactory
# jcswitch
# jmspassword
# keypassword
# keystorepassword
# keystorepasswordfile
# logswithappid
# passwd
# password
# passwordcredentials
# passwordfile
# passwords
# processwith
# processwithexception
# processwithtruststore
# proxypassword
# startswith
# storepassword
# succeedswith
# swallowed
# swallowing
# swallows
# swap
# swapping
# sway
# swayam
# sweep
# sweeping
# swi
# swift
# swit
# switch
# switches
# switching
# swith
# swpd
# testbatchedreadswithinafile
# testdfswrite
# testmissingkeystorepasswordfile
# testreplaysucceedswith
# testreplaysucceedswithunusedemptylogmetadata
# testreplaysucceedswithunusedemptylogmetadatafastreplay
# testsslprocesswithtruststore
# truststorepassword
# useconcmarksweepgc
# usernamepasswordcredentials
# visitenumswitch
# visitswitch
# xm8ngdswfan08phw9dct6lw
#
# ------------
#
# 10728
# 107280
# 107281
# 107284
# 107285
# 107287
# 107288
#
# ------------
#
# consu
# barconsumer
# consult
# consum
# consume
# consumed
# consumeorder
# consumer
# consumerand
# consumeranditer
# consumeranditerator
# consumercoordinator
# consumerfetcher
# consumerfetchermanager
# consumeriterator
# consumerkey
# consumernetworkclient
# consumers
# consumersecret
# consumes
# consuming
# consumption
# createconsumer
# dataconsumer
# dataconsumer1
# dataconsumer2
# decommissionconsumerand
# decommissionconsumeranditerator
# decommissionconsumerandrecords
# flumeconsumer
# jmsmessageconsumer
# kafkaconsumer
# noconsumer
# testconsume
# testconsumefile
# testconsumefileoldestwithlexicographicalcomparision
# testconsumefiler
# testconsumefilerandomlynewfile
# testconsumefileyoungest
# testconsumefileyoungestwithlexicographicalcomparision
# zookeeperconsumer
# zookeeperconsumerconnector
#
# ------------
#
# jceks
# jceksfile
#
# ------------
#
# 474700
# 0x00007fa223474700
# 223474700
#
# ------------
#
# _logical_
# _logical_configurations
#
# ------------
#
# 7m
# 247m
# 6aknog7m
# 6aknog7mfk5
# 867m
# g7m
# knog7m
#
# ------------
#
# mands
# commands
# commandsimple
# demands
# importcommands
# testshellcommandsimple
#
# ------------
#
# loy
# deploy
# deployed
# deploying
# deployment
# deployments
# flumedeploy
# redeployment
#
# ------------
#
# 78af6c9cff03
# 78af6c9cff03c42c
#
# ------------
#
# 445276
# 445276127976
# 445276127976521
#
# ------------
#
# jacking
# clickjacking
# hijacking
#
# ------------
#
# 1243
# 1243tmp
# 257334314321243tmp
# surefire_1057455257334314321243tmp
#
# ------------
#
# capacity
# bytecapacity
# bytecapacitybufferpercentage
# bytecapacityslot
# bytecapacityslotsize
# channelcapacity
# channeltransactioncapacity
# ecapacity
# ensurecapacity
# getoverflowcapacity
# memorycapacity
# overflowcapacity
# queuecapacity
# setchannelcapacity
# testcapacity
# testcapacitywithoverflow
# testdecreasecapacity
# testincreasecapacity
# transaction_capacity
# transactioncapacity
#
# ------------
#
# tio
# 20resolution
# _action
# _catch_exception
# _construction
# _convention
# _exception
# _exceptions
# _logical_configurations
# _naming_convention
# _obligation
# _position
# abandonedconnectioncleanup
# abandonedconnectioncleanupthread
# abbreviations
# ableioexception
# abstractcollection
# abstractconfigurationprovider
# abstractfileconfiguration
# abstractfileconfigurationprovider
# abstraction
# acquisition
# action
# action_10
# action_10341
# action_type
# actionable
# actionexception
# actionget
# actions
# actionsdir
# actionserializerbuilder
# activateoptions
# activation
# addition
# additional
# additionally
# addoption
# addressexception
# adition
# administration
# adoption
# aforementioned
# agentconfiguration
# aggregation
# algorithmexception
# alization
# allocation
# alreadybeingcreatedexception
# alreadyexistsexception
# amazons3exception
# ambitious
# ancyfraction
# annotation
# annotations
# aposition
# appendwriteexception
# application
# application_class
# applicationhandler
# applicationid
# applications
# applicationshutdown
# applicationshutdownhooks
# arrayindexoutofboundsexception
# arraysizeexception
# asinvalidprotocolbufferexception
# assertion
# assertionerror
# assertionfaile
# assertionfailederror
# assertions
# assertnoexception
# assumption
# assumptions
# atch_exception
# atio
# ation
# ationaction
# ationexception
# ations
# atransaction
# attachannotations
# attention
# auction
# auction_logs
# auctionlog
# auctionlogsink
# authentication
# authorization
# authorizationheadermalformed
# authorizationproviderproxyclientprotocol
# avroreflection
# avroreflectionenabled
# avroruntimeexception
# awaittermination
# badcheckpointexception
# baseactivation
# basicconfigurationconstants
# basictransaction
# basictransactionsemantics
# batchduration
# batchdurationmillis
# beginnexttransaction
# bidirection
# bidirectional
# bidirectionalhttpsource
# bindexception
# blockreplication
# brokerendpointnotavailableexception
# btpageactionserializerbuilder
# bucketclosedexception
# bufferunderflowexception
# buildexception
# bution
# c_transcation
# calculation
# calculations
# cancelations
# cancellation
# cancellationexception
# capitalization
# caption
# cation
# cautious
# ception
# certpathvalidatorexception
# cetion
# cexception
# channelconfiguration
# channelconfigurationtype
# channeleexception
# channelexception
# channelexceptions
# channelfullexception
# channeltransactioncapacity
# charconversionexception
# checkandthrowinterruptedexception
# checkforcomodification
# checkpointexception
# checksumfailureexception
# chelementexception
# ciation
# clarification
# classcastexception
# classcastexceptions
# classification
# classnotfoundexception
# clientconnection
# closedbyinterruptexception
# closedchannelexception
# closedexception
# cmsinitiatingoccupancyfraction
# codingerroraction
# collection
# collections
# collectionsink
# combination
# combinations
# commandnotfoundexception
# commitexception
# communication
# communications
# compaction
# compilation
# completetransaction
# completion
# completionservice
# componentconfiguration
# componentconfigurationfactory
# compressionexception
# computations
# concatenation
# concurrentmodification
# concurrentmodificationexception
# concurrentrestrictions
# condition
# conditionally
# conditionobject
# conditions
# configexception
# configruation
# configuation
# configuration
# configurationchanged
# configurationconstants
# configurationevent
# configurationfile
# configurationmanager
# configurationobject
# configurationproperties
# configurationprovider
# configurations
# conjunction
# connectexception
# connection
# connectionchild
# connectioncleanup
# connectionclosed
# connectionclosedcount
# connectioncreated
# connectioncreatedcount
# connectionexception
# connectionfactory
# connectionfailedcount
# connectionid
# connectionimpl
# connectionmon
# connectionpool
# connectionpoolmanager
# connectionrefused
# connections
# connectionsfailed
# connectionsper
# connectivityexception
# conribution
# consideration
# considerations
# consolidation
# construction
# consumption
# contention
# contexthandlercollection
# continuation
# convention
# conventions
# conversationaction
# conversationactiontest
# conversations
# coordination
# corrdination
# correction
# corrections
# correlation
# corrupteventexception
# corruption
# createconnection
# createconnectionthread
# createtransaction
# creation
# creation_date
# cryption
# ction
# ctions
# ctiontimer
# ctransaction
# currentdescription
# customisation
# customization
# customizations
# datadiction
# datadictionaryimpl
# datasetrecordexception
# dateoptional
# dateoptionaltime
# declaration
# declarations
# decryption
# deduplication
# default_min_log_rentention_period
# default_min_log_retention_period
# defaultclientconnection
# defaultclientconnectionoperator
# defaultpartitioner
# defaultpartitionid
# definations
# definition
# definitions
# delegatingconnection
# delegation
# deletion
# deprecation
# description
# descriptions
# deserialization
# desiredreplication
# destination
# destinationlocator
# destinationname
# destinations
# destinationtopic
# destinationtype
# destroyconnection
# destroyconnectionthread
# detailedjmsexception
# detection
# deviation
# dexception
# dexecutionexception
# diction
# dictionaries
# dictionary
# dictionaryfiles
# dination
# direction
# distinction
# distribution
# dition
# documentation
# doperation
# doperationexception
# dpropertiesimplementation
# driverconnectionfactory
# duplication
# durablepositiontracker
# duration
# ec2production
# edexception
# edition
# election
# electionalg
# embedconnection
# embeddedagentconfiguration
# encryption
# encryptioncipherprovider
# encryptionkeyalias
# encryptionkeyprovider
# encryptiontestutils
# endofstreamexception
# enryption
# entation
# ention
# enumeration
# eofexception
# eption
# eratio
# erroraction
# escalation
# estion
# event_log_production
# eventdeliveryexception
# eventexception
# evictiontimer
# examination
# exception
# exceptionally
# exceptioncaught
# exceptions
# excpetion
# executeafterpreconditionschecked
# execution
# executionexception
# executionpolicy
# executions
# existsexception
# exitcodeexception
# exlaination
# expectation
# expectexception
# expiration
# expiredexception
# explanation
# extraction
# faction
# failoverconfigurationmanager
# failureexception
# fanouttransaction
# fastleaderelection
# fatalexception
# fication
# fied_obligation
# filebackedtransaction
# filechannelconfiguration
# fileconfiguration
# fileconfigurationprovider
# fileexception
# filenotfoundexception
# finishinitialization
# flume_application_class
# flumeauthentication
# flumeauthenticationutil
# flumeconfiguration
# flumeexception
# flumespecexception
# forkexception
# formation
# foundation
# fraction
# freeratio
# fsyncpertransaction
# function
# function1
# functional
# functionalities
# functionality
# functions
# generatecssqlexception
# generation
# genericconfigurationprovider
# genericconnectionfactory
# gestion
# getadditional
# getadditionalblock
# getconfiguration
# getconnection
# getcurrentblockreplication
# getdefaultreplication
# getflumeconfiguration
# getfsdesiredreplication
# getposition
# getsatisfaction
# getsqlexception
# gettransaction
# grokdictionary
# grokdictionarydir
# groundoperation
# gssexception
# handleconfigurationevent
# handleconnection
# handledisconnection
# handleexception
# harmonization
# hasoption
# hconnection
# hdfsconnectionmon
# hitchannelexception
# hivetransactions
# hiveupdatepartition
# hostexception
# htraceconfiguration
# httpbadrequestexception
# httpconnection
# httpurlconnection
# iction
# identification
# idleaction
# illegalargumentexception
# illegalstateexception
# illegalstateexceptions
# illigalstateexception
# impersonation
# implementation
# implementations
# implemetation
# implication
# implications
# ination
# inations
# incrementconnectionclosedcount
# incrementconnectionfailedcount
# incrposition
# inction
# incubation
# indentation
# indexoutofboundsexception
# indication
# infomation
# information
# ingestion
# initialisation
# initialization
# initiation
# injection
# injestion
# inputexception
# insertion
# inspection
# insqlexception
# instalation
# installation
# installations
# instancealreadyexistsexception
# instanciation
# instantiation
# instantiationexception
# institution
# institutions
# instruction
# instructions
# instrumentation
# integration
# intention
# intentionally
# interaction
# interactions
# internalhttpserverexception
# interpolation
# interpretation
# interruptedexception
# interruptedexceptions
# interruptexception
# interruption
# interruptions
# intervention
# introduction
# invalidindexnameexception
# invalidoperation
# invalidoperationexception
# invalidprotocolbufferexception
# investigation
# invocation
# invocations
# invocationtarge
# invocationtargetexception
# ioexception
# ioexceptions
# is_ignoring_recoverable_exceptions
# is_production_mode
# isation
# isolation
# iteration
# iterations
# ition
# itious
# ivyactions
# ization
# izations
# javalangillegalargumentexception
# jcsmperrorresponseexception
# jdbcchannelexception
# jdbctransaction
# jdbctransactionimpl
# jection
# jestion
# jmsexception
# jsonfileconfigurationprovider
# jsonparseexception
# jsonsyntaxexception
# jurisdiction
# juxtaposition
# kafka2hdfsconnectionmon
# kafkaexception
# kafkatransaction
# keeperexception
# kerberization
# krbexception
# lanation
# leaseexpiredexception
# lection
# leexception
# lementexception
# lexception
# lication
# lications
# lifecycleexception
# lifecycleexecutionexception
# limitation
# limitations
# loadpositionfile
# location
# locations
# lockposition
# lockpositionforwrite
# logfileretryableioexception
# loggingexception
# logicalconfigurationmanager
# logretentionperiod
# malformedinputexception
# materializedconfiguration
# materializedconfigurationprovider
# mation
# mavenization
# mavenreportexception
# maxallowedviolations
# maxbatchdurationmillis
# maxconnections
# maxconnectionsper
# maxconnectionsperhost
# maxheapfreeratio
# maxunderreplication
# maxunderreplicationcount
# maxunderreplicationtest
# memoryconfigurationprovider
# memorytransaction
# memtransaction
# mentation
# mentexception
# mention
# mentioned
# mentioning
# mentions
# messageexception
# mexception
# migration
# minheapfreeratio
# minlogretentionperiod
# minrentention
# minrententionperiod
# minretentionperiod
# misconfiguration
# modification
# modifications
# mojoexecutionexception
# mojofailureexception
# morphlinecompilation
# morphlinecompilationexception
# motivation
# mption
# mqexception
# mqqueueconnectionfactory
# muchcontention
# multiplication
# mutation
# mychannelconfiguration
# mydrivesolutions
# namenotfoundexception
# nation
# nations
# navigation
# negativearraysizeexception
# negotiation
# newconnection
# newconnectionimpl
# newexception
# newratio
# nextexception
# nexttransaction
# nm_class_naming_convention
# nonrecoverableeventexception
# noroutetohostexception
# nosuchalgorithmexception
# nosuchelementexception
# nosuchfileexception
# nosuchmethodexception
# nosuchtxnexception
# notation
# notfoundexception
# notification
# notifications
# notinmountpointexception
# notion
# nullpointerexception
# nullpointerexceptions
# nullpointexception
# numberformatexception
# numberformatexpcetion
# obfuscation
# obl_unsatisfied_obligation
# obligation
# observation
# ods_flume_json_yunc_transcation
# oexception
# onation
# oncompletion
# onconfiguration
# onconfigurationchange
# onexception
# onnodeconfigurationchanged
# openconnection
# openconnectioncount
# operation
# operational
# operations
# operationsfaq
# optimization
# optimizations
# option
# optional
# optionally
# optionaltextconfig
# optionbuilder
# optiongroup
# options
# optionvalidator
# orchestration
# organization
# ortedoperationexception
# ortexception
# ortion
# osition
# outofmemoryexception
# outofmemoryexceptions
# page_action
# pageactionserializerbuilder
# parseexception
# partition
# partitioncount
# partitioned
# partitioner
# partitionid
# partitionidheader
# partitioning
# partitions
# partitionsfor
# partitionvals
# pathvalidatorexception
# performinitialization
# permutations
# pertransaction
# petion
# pluginexecutionexception
# pluralization
# pointexception
# pollingpropertiesfileconfigurationprovider
# pollingzookeeperconfigurationprovider
# population
# portion
# portions
# position
# positioncache
# positionfile
# positions
# positiontracker
# positionwriter
# positionwriterrunnable
# postion
# preallocation
# precondition
# preconditions
# preconditionschecked
# preparation
# presentations
# prevalidation
# priviledgedactionexception
# processbackgroundoperation
# processfunction
# processwithexception
# production
# production_mode
# projectbuildingexception
# projection
# promotion
# propagation
# propertiesfileconfigurationprovider
# propertyfileconfigurationprovider
# proportion
# proportional
# protections
# ption
# publications
# putexception
# pyexception
# qlexception
# question
# questions
# queueconnectionfactory
# ralization
# ransaction
# ratcheckexception
# ratio
# ration
# rationale
# readcompoundannotation
# rec_catch_exception
# recommendation
# recommendations
# reconfiguration
# reconfigurations
# reconfigutations
# reconnection
# recordexception
# recoverable_exception
# recoverable_exception_classes
# recreation
# reduction
# reelection
# reflection
# reflectionhelper
# reflectionutils
# refreshconfiguration
# registration
# reimplementation
# rejectedexecutionexception
# relation
# relationship
# relationships
# relaxation
# remediation
# remoteexception
# remotetransportexception
# rentention
# rentention_period
# repetitions
# replication
# replicationfactor
# replicaunderconstruction
# representation
# reproduction
# requestexception
# resolution
# resolveexception
# retention
# retention_period
# retentionperiod
# rethrowasioexception
# retryinvocation
# retryinvocationhandler
# rotation
# rotations
# rpcclientconfigurationconstants
# rposition
# runcloseaction
# runtimeexception
# runtimeexceptions
# saction
# safemodeexception
# saslexception
# satisfied_obligation
# schemaexception
# section
# sections
# securityexception
# selection
# separation
# serialiazation
# serialisation
# serialization
# serializations
# sessionexpiredexception
# setconfiguration
# setupconnection
# sexception
# simplification
# sinkconfiguration
# sinkgroupconfiguration
# sioexception
# sition
# situation
# situations
# sizeexception
# socketexception
# socketio
# socketiowithtimeout
# sockettimeoutexception
# solution
# solutions
# solxaexception
# soption
# sourceconfiguration
# sourceconfigurationtype
# specification
# specifications
# speculation
# spillablememorytransaction
# spooldirectorysourceconfigurationconstants
# sqlexception
# sqlexceptionfactory
# sqlexceptionfactory40
# sqltransactionrollbacke
# sqltransactionrollbackexception
# sslconnection
# sslhandshakeexception
# sslpeerunverifiedexception
# standardexception
# standardization
# starvation
# stateexception
# stratio
# streamingexception
# stringindexoutofboundsexception
# subscription
# subscription_id
# subscriptions
# substitution
# substitutions
# suggestion
# suggestions
# suppositions
# suppressexceptions
# surefirebooterforkexception
# survivorratio
# synchronization
# synchronizations
# syntaxexception
# taildir_position
# tapplication
# tapplicationexception
# tedexception
# tedexecutionexception
# tention
# termination
# testapplication
# testdestination
# testdestinationexistsand
# testdestinationexistsanddifferentfile
# testdestinationexistsandsamefile
# testdestinationexistsandsamefilenotonwindows
# testdestinationexistsandsamefilewindows
# testexecution
# testfilechannelencryption
# testflumeconfiguration
# testflumenodeapplication
# testjsonfileconfigurationprovider
# testpollingpropertiesfileconfigurationprovider
# testpropertiesfileconfigurationprovider
# testrestartnextexception
# testtokenauthentication
# testwithoutconfigurationobject
# texception
# threadinterruptedexception
# throwexception
# throwinterruptedexception
# tibjmsqueueconnectionfactory
# timeoutexception
# tion
# tions
# titution
# tivation
# tohostexception
# toioexception
# toomuchcontention
# toomuchcontentionexception
# topicpartition
# tradition
# transaction
# transaction_
# transaction_capacity
# transaction_flag
# transactional
# transactionbatch
# transactionbatchimpl
# transactioncapa
# transactioncapacity
# transactioncapactiy
# transactionerror
# transactionevent
# transactioneventheader
# transactioneventrecord
# transactionid
# transactionresource
# transactionresourceimpl
# transactionrollbacke
# transactions
# transcation
# transformation
# transformations
# transition
# transitioning
# transitions
# translatetoioexception
# translatingconfigurationmanager
# translation
# translations
# transnation
# transnational
# transportexception
# trasaction
# truncation
# ttransportexception
# txnabortedexception
# typefunctions
# uation
# ulation
# unavailableshardsexception
# uncheckedexecutionexception
# unconditionally
# under_construction
# underconstruction
# undoperation
# uninitializedmessageexception
# unixexception
# unknownhostexception
# unresolvedaddressexception
# unresolvedunionexception
# unsupportedoperationexception
# unverifiedexception
# uriconfigurationprovider
# urisyntaxexception
# user_description
# user_location
# user_mentions
# useraction
# useractionchannel
# useractionsink
# usergroupinformation
# utations
# utetohostexception
# utexception
# utilization
# ution
# utionexception
# validateconfiguration
# validation
# validatorexception
# variation
# vation
# verification
# verifyconnection
# viations
# violation
# violations
# vulncurrentdescription
# vulncurrentdescriptiontitle
# wal_min_rentention_period
# wal_min_retention_period
# wasioexception
# webapplication
# webapplicationcontext
# webapplicationhandler
# webapplicationimpl
# wrapexception
# wrapinsqlexception
# wrappedcollection
# writableserialization
# writeposition
# xation
# xatransaction
# xception
# xtaposition
# yamlexception
# zation
#
# ------------
#
# transmit
# retransmit
# retransmits
# retransmitting
# transmitted
#
# ------------
#
# rable
# _recoverable
# comparableflumeeventpointer
# configurable
# configurables
# considerable
# desirable
# durable
# durablefilechannel
# durablepositiontracker
# ignoring_recoverable
# irrecoverable
# is_ignoring_recoverable
# is_ignoring_recoverable_exceptions
# iterables
# nonrecoverable
# nonrecoverableeventexception
# operable
# preferable
# recoverable
# recoverable_exception
# recoverable_exception_classes
# recoverablefilechannel
# recoverablememorychannel
# recoverablezookeeper
# reoverablememorychannel
# sharable
# testrecoverablememorychannel
# undesirable
# unrecoverable
# vulnerable
#
# ------------
#
# 1233
# 1233456
# 123456789012345678901233
# 1234567890123456789012345678901234567890123456789012345678901233
# 12345678901234567890123456789012345678901234567890123456789012334567890
#
# ------------
#
# naming
# _naming
# _naming_convention
# namingmanager
# nm_class_naming_convention
# renaming
# threadrenaming
# threadrenamingrunnable
# tibjmsnaming
#
# ------------
#
# _ph
# __t_note_ph
# __t_note_phone
# __t_note_phonet_note_ph
# __t_note_phonet_note_phone
# _note_ph
# ods_flume_json_thirdparty_db__t_note_phone
# onet_note_ph
# t_note_ph
# t_note_phone
#
# ------------
#
# 14710
# 36814710
#
# ------------
#
# blk_5249
# blk_524945627285846
# blk_5249456272858461891_436734
# blk_5249456272858461891_436734java
#
# ------------
#
# zpfd
# zpfdqw4l9g
#
# ------------
#
# nohang
# testnohang
#
# ------------
#
# e11
# 01e11
# 01e1133d
# 0e7005136e4160ed4cc157c4ddd7f4f1c6e11ffa
# 485941701e1133d
# 4f1c6e11
# 4f1c6e11ffa
# 7685f0e8485941701e1133d
# 99db32ccd163daf9d7685f0e8485941701e1133d
# c6e11
#
# ------------
#
# equivalent
# equivalently
#
# ------------
#
# kafk
# 2kafka
# incrementkafkaempty
# incrementkafkaemptycount
# kafka
# kafka1
# kafka2
# kafka2hdfsconnectionmon
# kafka3
# kafka_0
# kafka_2
# kafka_flume
# kafkaavro
# kafkaavrodeserializer
# kafkaavroserialized
# kafkachannel
# kafkaconsumer
# kafkadata
# kafkaempty
# kafkaexception
# kafkaheaders
# kafkaprodu
# kafkaproducer
# kafkasink
# kafkasink1
# kafkasinkconstants
# kafkasource
# kafkasourceconstants
# kafkasourcecounter
# kafkasourceembedded
# kafkasourceembeddedkafka
# kafkatopic
# kafkatransaction
# kafkazkclient
# multilinekafkasink
# testkafkachannel
# testkafkasink
# testkafkasource
# testkafkasourceutil
# tuzla2kafka
# usekafka
# usekafkaheader
#
# ------------
#
# thriftflumereport
# thriftflumereportserver
#
# ------------
#
# 不同的文件
# 会出现同一个inode对应不同的文件
#
# ------------
#
# 1666
# 61d16662
#
# ------------
#
# return
# bc_unconfirmed_cast_of_return_value
# return_value
# returned
# returning
# returns
#
# ------------
#
# apr
# 2014apr
# aprodu
# createnonhaproxy
# dataprodu
# dataproduce
# dfsclient_nonmapreduce
# dfsclient_nonmapreduce_
# dfsclient_nonmapreduce_20776924
# dfsclient_nonmapreduce_2077692400_17
# dfsclient_nonmapreduce_833895
# dfsclient_nonmapreduce_833895359_50
# g1heapregion
# g1heapregionsize
# getjavaproperty
# haproxy
# heapregion
# kafkaprodu
# kafkaproducer
# mapred
# mapreduce
# mapresolver
# nonmapreduce
# onhaproxy
#
# ------------
#
# 0900
# 090014
# 0x1375308bd090014
#
# ------------
#
# abstracthdfswrite
# abstracthdfswriter
#
# ------------
#
# 016
# 00000016
# 00000160
# 101629
# 10162970
# 1016300
# 10163002
# 10163004
# 12011016
# 140160
# 1536631531938140160
# 2016
# 2016十二月
# 23301662
# 31660163
# 31660163266
# 316601632688
# 316601632689
# 316601632689443
# 3166016326899
# 4302066137680167
# 445166016694026
# 60163
# 73016743409
# 73016743409545744
# 80167
# t101629
# t10162981
# u0016
# u0016gp
# u0016çx
# v201112011016
#
# ------------
#
# 0956
# ...
# deletes
# deletesnapshotresponse
# deletesnapshotresponseproto
# deleting
# deletion
# deplete
# derbyschemahandler
# desirable
# detailed
# detailedjmsexception
# dexample
# dfile
# dfromfilesin
# diasable
# dictionaryfiles
# differentfile
# digestible
# dioflumehttpservlet
# disable
# disabled
# disabledprotocolsso
# disabledprotocolssocketfactory
# disables
# disablesslv3
# distinguishable
# distributedfilesystem
# dles
# do_flush_error_sleep_time_
# do_flush_error_sleep_time_msec
# doprivileged
# doselect
# double
# doubled
# downsample
# dpidfile
# dpropertiesimplementation
# driverprofile
# durable
# durablefilechannel
# durablepositiontracker
# editable
# ele
# election
# electionalg
# eleg
# elegant
# element
# elements
# elementslogenrichbuilder
# elems
# elled
# embeddable
# emptyfile2
# enable
# enablecompression
# enabled
# enables
# enablev4
# enbled
# end_file
# endless
# endlessly
# ensemble
# epollselectorimpl
# epollselectorprovider
# equivalent
# equivalently
# escapable
# escapedthriftseqfiledfssink
# estible
# estlet
# evaluatechallenge
# eventhandler
# eventqueuebackingstorefile
# eventqueuebackingstorefilev3
# eventschannelselector
# example
# example3
# exampleattr
# examples
# exceedsmaxlinelength
# execable
# execrunnable
# executable
# executables
# extendable
# extensible
# extwritableserializer
# faile
# failed
# failed_to_
# failed_to_load_native_library
# failedcount
# failedevents
# fairscheduler
# fastleadere
# fastleaderelection
# fatalexception
# faulttolerance
# feasible
# fenqile
# ffled
# file
# file0
# file0filesuffix
# file1
# file1filesuffix
# file2
# file2filesuffix
# file3
# file3filesuffix
# file_
# file_channel
# file_channel_null
# file_channel_null_sink
# file_channels
# file_obj
# file_obj_incorrect
# file_obj_incorrect_md5_digest
# file_obj_null
# file_roll
# filea
# fileaccess
# fileappender
# fileattr
# fileattribute
# filebacked
# filebackedtransaction
# fileboundary
# filechan
# filechannel
# filechannel1
# filechannelconfiguration
# filechannelimpl
# filechannelintegritytool
# filechannels
# filechannle
# filechannle_data
# filechdata
# filechecker
# fileconfiguration
# fileconfigurationprovider
# filed
# filedelete
# filedeleted
# filedescriptor
# filedispatcher
# filedispatcherimpl
# fileencoding
# fileexception
# fileexclusively
# fileextension
# fileextensioncounter
# filefilesuffix
# fileflumelog
# fileflumelog1
# filegroup
# filegroupname
# filegroups
# filehandles
# fileheader
# fileheaderkey
# fileid
# fileidcounts
# fileinputformat
# fileinputstream
# filekeyprovider
# filelines
# filelinescountdbsav
# filelinescountdbsaver
# filelock
# filemanager
# filemask
# filemetrics
# filemetrics1
# filemode
# filen
# filename
# filenameheader
# filenamepattern
# filenames
# filenameutils
# filenotfound
# filenotfoundexception
# fileoutputstream
# filepath
# filepattern
# filepost
# filepostfix
# fileprefix
# filer
# filere
# filereader
# fileregex
# filero
# fileroll
# filerollingsink
# filerollsink
# files
# files_from_
# files_from_windows_using_flume
# files_wrong
# files_wrong_size
# filesin
# filesink
# filesize
# filesname
# filesnap
# filesource
# filesrequired
# filestate
# filesuffix
# filesystem
# filesystemprovider
# filesystems
# filesystemwriter
# filetime
# filetimeminoffset
# filetimeminoffsetseconds
# filetree
# filetreewalker
# filetxn
# filetxnsnaplog
# filetype
# fileupload
# fileutil
# fileutils
# filewatcher
# filewatcherrunnable
# filewriter
# filled
# filler
# filter_level
# firedeleted
# firedeletedfile
# fixable
# fle
# fle_
# fle_channel
# fle_payload
# fle_spill
# flex
# flexib
# flexibility
# flexible
# flexibly
# flumefile
# flumefileagent
# flumefilechannel
# flumehttpservlet
# flushable
# flushingseqfile
# followleader
# foofile
# footable5
# forcedelete
# forfilesin
# fragile
# fullfilename
# garbled
# genabled
# generatecssqlexception
# genericconglomeratecontroller
# geo_enabled
# getbackoffsleepincrement
# getboolean
# getcandidatefiles
# getfile
# getfilegroup
# getfileinfo
# getfilestatus
# getfilesystem
# getlease
# getleasebypath
# getleaseforpath
# getlifecyclestate
# getmatchingfiles
# getmatchingfilesnocache
# getnextfile
# getservlet
# getsimple
# getsimplename
# getsqlexception
# gettailfiles
# getusablespace
# getvalueasdouble
# gfiles
# gfiles02
# ggle
# gle
# glecompression
# gler
# glerp
# google
# googlecode
# googleplussource
# gradle
# hale
# handle
# handleaccepted
# handleacceptedsocket
# handlecommand
# handlecompleted
# handlecompletedreceives
# handleconfigurationevent
# handleconnection
# handled
# handledis
# handledisconnection
# handledownstream
# handleevent
# handleexception
# handleimpl
# handlenext
# handler
# handlercontext
# handleread
# handlerequest
# handlerimpl
# handlers
# handlerwrapper
# handles
# handlesasl
# handlesaslstartmessage
# handleserversocket
# handlesummary
# handleupstream
# harmless
# hashbasedtable
# hashtable
# hashtables
# hdfs_keepfiles
# hdfsfileprefix
# hdfssequencefile
# hdfstextwritableserializer
# headercomplete
# headertable
# hfile
# hitchannelexception
# hivestoragehandler
# hole
# hostselector
# htable
# httpmethodrule
# httpservlet
# httpservletfilter
# httpservletrequest
# httpservletresponse
# httpsourcehandler
# hurdles
# ible
# iddle
# idle
# idleaction
# idlecallback
# idleclosed
# idlefilechecker
# idlefilecheckerrunnable
# idlefuture
# idlefutures
# idleinodes
# idleness
# idles
# idlestate
# idlestateawarechannelhandler
# idlestateevent
# idlestatehandler
# idletimeout
# idlogfile
# idlogfilemap
# ignorehiddenfile
# ignoring_recoverable
# ile
# iler
# iles
# illegal
# illegalaccesserror
# illegalargu
# illegalargumentexception
# illegalstate
# illegalstateexception
# illegalstateexceptions
# illegitimate
# immutable
# immutablelistmultimap
# immutablemap
# immutablesorted
# immutablesortedset
# imple
# implement
# implementation
# implementations
# implemented
# implementing
# implements
# implemet
# implemetation
# impossible
# inaccessible
# incompatible
# incomplete
# incrementconnectionfailedcount
# inescapable
# informsinkfailed
# initializable
# insqlexception
# installed
# installer
# interleave
# interleaving
# interleavings
# interruptable
# interruptible
# invalidtable
# ipfilterrule
# ipfilterrules
# iptables
# irrecoverable
# is_ignoring_recoverable
# is_ignoring_recoverable_exceptions
# isdebugenabled
# isfile
# isfileclosed
# issamefile
# issecurityenabled
# isunmappable
# it_no_such_element
# itable
# iterables
# jarfile
# javalangillegalargumentexception
# jcefilekeyprovider
# jceksfile
# jconsole
# jdbcchannelexception
# jets3tnativefilesystem
# jets3tnativefilesystemstore
# jndiloginmodule
# joinselector
# jsonfileconfigurationprovider
# jsonhandler
# keedioflumehttpservlet
# keepfiles
# keleton
# keley
# keystorefile
# keystorepasswordfile
# killed
# killer
# kqueueselectorimpl
# latile
# lea
# lead
# leader
# leadere
# leaderfinder
# leaderfinderthread
# leading
# leads
# leaf
# leak
# leaked
# leaking
# leaks
# lean
# leap
# lear
# learn
# learner
# lease
# leasechecker
# leaseexpiredexception
# leasemanager
# least
# leav
# leave
# leaves
# leaving
# lection
# lector
# led
# ledateformat
# ledged
# leexception
# left
# leftr
# leftronic
# leg
# legacy
# legacythrift
# legacythriftsource
# legal
# lege
# leged
# legiti
# legitimate
# leline
# lement
# lementexception
# len
# lenc
# lene
# leng
# length
# lengths
# lent
# ler
# lers
# les
# lesc
# lese
# less
# lessly
# let
# lete
# leted
# leton
# lets
# letter
# letterimpress
# letters
# letting
# level
# levels
# levent
# levents
# lever
# leverage
# leveraged
# leverages
# leveraging
# levnt
# lex
# lexception
# lexecutor
# lexer
# lexico
# lexicographically
# lexited
# lexographically
# ley
# licable
# lidle
# lifecycle
# lifecycleaware
# lifecyclecontroller
# lifecycleexception
# lifecycleexecutionexception
# lifecyclefl
# lifecyclelock
# lifecyclemodule
# lifecyclemodulebuilder
# lifecyclestarter
# lifecyclestate
# lifecyclesupervisor
# line_length
# linelength
# linuxfilesystemprovider
# listopenfiles
# little
# loadbalancingchannelselector
# loadconfigfile
# loadpositionfile
# loadstanzatable
# locale
# localexited
# localfilesystem
# lockanddoselect
# logendfiledescriptor
# logfile
# logfile1
# logfile2
# logfilefactory
# logfileindex
# logfilemetadata
# logfiler
# logfilere
# logfilerefcountsall
# logfileretry
# logfileretryableioexception
# logfiles
# logfilev3
# logfilewriter
# loginmodule
# loglevel
# longwritable
# los_angeles
# lsb_release
# lynewfile
# maintainable
# makefile
# manageable
# mangle
# mappable
# masterfilesystem
# masterless
# maxbackoffsleep
# maxbloblength
# maxfilesize
# maxlinelength
# maxloglinelength
# maxopenfile
# maxopenfiles
# maxtotalevents
# mble
# meaningless
# meanwhile
# metafile
# methodrule
# mflex
# middle
# miles
# mishandled
# mislead
# misleading
# misleads
# misspelled
# modifiable
# module
# modules
# monitorrunnable
# morphlinefile
# morphlinehandlerimpl
# mqcc_failed
# msgafternewfilecreated
# muddled
# mulitple
# multiple
# multiplethreads
# multiplex
# multiplexer
# multiplexing
# multiplexingchannelselector
# multiplexingchannelselectorconfigurator
# multiplexsink
# mutable
# mutiple
# my_table
# mycustomhttpservletfilter
# myfile
# myfilename
# myrole
# myrollingfilesink
# mytable
# nabble
# naivefile
# naivefilefaa
# naivefilefaii
# naivefilefaill
# naivefilefailover
# naivefilefailovermanager
# naivefilewal
# naivefilewaldeco
# naivefilewalmanager
# nativefilesystem
# natives3filesystem
# navigable
# needlessly
# nettyclientavrohandler
# nettyserveravrohandler
# nevertheless
# newfile
# newfilecreated
# newscheduled
# newscheduledthreadpool
# newsingle
# newsinglethrea
# newsinglethreadexecutor
# newsinglethreadschedule
# newsinglethreadscheduledexecutor
# newsletterimpress
# newsletterimpressionlog01
# nle
# nodemailer
# nodes_agents_and_collectors
# nodesampler
# nonetheless
# nonrecoverable
# nonrecoverableeventexception
# noprofile
# nosuchelementexception
# nosuchfileexception
# notable
# notavailable
# notdeleted
# noticeable
# nullwritable
# obsolete
# obsoleted
# oflumehttpservlet
# oldestwithlexicographicalcomparision
# oler
# oncompletion
# onidle
# onidlecallback
# onidlecallbackpath
# oomkiller
# open_file
# openfile
# openselector
# operable
# oracle
# orderselector
# output_dfochain_open_file
# output_open_file
# outputtofile
# overridable
# ownable
# paralle
# parallel
# paralleli
# parallelism
# parallelize
# parametrizable
# parsable
# parseable
# parseavailable
# parseboolean
# passwordfile
# pathrule
# pelled
# penfiles
# people
# peoples
# persistableevent
# pid_file
# pidfile
# pipelineeventschannelselector
# pipleline
# plainloginmodule
# ple
# please
# plent
# plenty
# plex
# plexus
# plugable
# pluggable
# pollable
# pollablesink
# pollablesource
# pollablesourcerunner
# poller
# pollingpropertiesfileconfigurationprovider
# pooled
# poolent
# portable
# porthandler
# positionfile
# positionwriterrunnable
# possible
# ppc64le
# precompile
# precompiled
# predictable
# preferable
# principle
# printable
# priviledged
# priviledgedactionexception
# privilege
# privileged
# privilegedexecutor
# probable
# proble
# problem
# problematic
# problems
# probsampler
# processselected
# processselectedkeys
# profile
# profile_
# profile_background
# profile_background_color
# profile_background_image_url
# profile_background_image_url_https
# profile_background_tile
# profile_ban
# profile_banner_url
# profile_banners
# profile_image_url
# profile_image_url_https
# profile_images
# profile_link_color
# profile_sidebar
# profile_sidebar_
# profile_sidebar_border_color
# profile_sidebar_fill_color
# profile_text_color
# profile_use_
# profile_use_background_image
# profiled
# profiler
# profiles
# propertiesfileconfigurationprovider
# propertyfileconfigurationprovider
# proxycallable
# pulled
# putcalled
# qile
# qlexception
# queryable
# rable
# randomaccessfile
# randomaccessfiles
# rationale
# rawlocalfilesystem
# rawseqfile
# rcfile
# reachable
# readable
# readclassfile
# readeventsforfilesin
# readeventsforfilesindir
# reasonable
# recompile
# recompiled
# reconcile
# recoverable
# recoverable_exception
# recoverable_exception_classes
# recoverablefilechannel
# recoverablememorychannel
# recoverablezookeeper
# recoverlease
# recoverleaseinternal
# redirectoutputtofile
# reelection
# referencehandler
# refle
# reflect
# reflectdatum
# reflectdatumwriter
# reflected
# reflectgetnumcurrentreplicas
# reflecti
# reflection
# reflectionhelper
# reflectionutils
# reflective
# reflectivecall
# reflectivecallable
# reflectively
# regardless
# regexallex
# regexallextractor
# reimplement
# reimplementation
# rele
# releas
# release
# release_notes
# released
# releaseexternalresources
# releasenotes
# releases
# releaseshared
# releasing
# relent
# relentlessly
# relevant
# reliable
# reliableeventreader
# reliablespoolingfile
# reliablespoolingfileeventreader
# reliabletaildire
# reliabletaildireventreader
# reliabletaildireventreader类中的
# reliabletaildireventreader类中的tailfiles变量
# reliabletaildireventreader类中的tailfiles变量只有不断新增
# removeemptyelementslogenrichbuilder
# removeemptyelems
# reoverablememorychannel
# replaycomplete
# replayhandler
# replicatingchannelselector
# reproducable
# reproducible
# requesthandler
# reschedule
# reschedules
# resettable
# resettablefileinputstream
# resettableinputstream
# resettableteststring
# resettableteststringinputstream
# resizablearray
# resolvable
# resolveable
# resourceclassrule
# responderservlet
# responsible
# restartthrottle
# restarttogglecompression
# restlet
# retirecurrentfile
# retryinvocationhandler
# revealed
# righthandpathrule
# role
# roles
# rollcurrentfile
# rolled
# roller
# rollfile
# rollingfile
# rollingfileappender
# rollingfilesink
# rootresourceclassesrule
# rotatedfile
# roundrobinorderselector
# routesfile
# rpcretryable
# rule
# rules
# rundelegated
# rundelegatedtasks
# runleaf
# runnable
# runnableadapter
# runnableerrorforwarder
# runnables
# runprivileged
# runreflectivecall
# s_enabled
# sable
# samefile
# sample
# sampledata
# sampledataitem
# sampledatauser
# sampler
# samples
# saslexception
# savefile
# scalable
# scale
# scaled
# schedule
# scheduleatfixed
# scheduleatfixedrate
# scheduled
# scheduledexecutorservice
# scheduledf
# scheduledfuture
# scheduledfuturetask
# schedulednodesampler
# scheduledthreadpoolexecutor
# scheduler
# schedulers
# schedules
# schedulewithfixed
# schedulewithfixeddelay
# schemahandler
# scramble
# secondexample
# securityhandler
# seemlessly
# sele
# select
# selectchannel
# selectchannelcon
# selectchannelconnec
# selectchannelconnector
# selectchannelen
# selectchannelendpoint
# selectd
# selected
# selecting
# selection
# selectively
# selector
# selectorconfig
# selectorimpl
# selectormanager
# selectorprovider
# selectors
# selectorserver
# selectorthread
# selectserver
# selectset
# selectsym
# selectthread
# sensible
# seqfile
# seqfileeventsink
# sequencefile
# sequencefileoutputformat
# sequencefiles
# serializable
# servicehandleimpl
# servle
# servlet
# servletcontainer
# servlethandler
# servletholder
# servlets
# sessionhandler
# setcurrentfile
# setenabled
# setenabledprotocols
# setlevel
# setlifecyclestate
# setselected
# shandled
# sharable
# shareable
# shuffled
# shutdownablethread
# siample
# sible
# silent
# silently
# simple
# simpleappend
# simpleasynchbaseeventserializer
# simpleauthenticator
# simplechannelhandler
# simplechannelupstream
# simplechannelupstreamhandler
# simpledateformat
# simpleevent
# simplegeo
# simplehbaseeventserializer
# simplehdfst
# simplehdfstest
# simplenodesampler
# simpler
# simplest
# single
# singlesource
# singlesourceand
# singlethreaded
# singlethreadedbu
# singlethreadedbuild
# singlethreadedbuilder
# singleton
# singletoncontext
# sinkfailed
# sinkselector
# sinkwritable
# sle
# sleep
# sleep_ms
# sleep_time_
# sleeping
# sleepingstopwatch
# sleepmicro
# sleepmicrosuninterruptibly
# sleepped
# sleeps
# sleepuninterruptibly
# sleepycat
# slew
# smaller
# smile
# sockethandler
# socketselector
# somefile
# spelled
# spillable
# spillablechannel
# spillablememory
# spillablememorychannel
# spillablememorytransaction
# splittable
# spoolabledirectorysource
# spooldirectoryrunnable
# spoolevnt
# spoolevnts
# spoolingfile
# spoolingfilelinereader
# sqlexception
# sqlexceptionfactory
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-d0aacf7bbf98> in <cell line: 1>()
#       6     for word in matching_words:
#       7       if word!=token:
# ----> 8         print(word)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.10/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# # Global

# %%
import os
import pandas as pd
import numpy as np
import json
from tqdm import tqdm
import tensorflow as tf
import torch
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
PROJECT_NAME = "FLUME"

TEXT_FEATURES = ["title", "description", "summary"]
ADDING_TIME_FEATURES = ["CC", "CU"]

MAXLEN = 256
MODEL_NAME = "LSTM"
EMBEDDING_METHOD = "GloVe"
DEVICE = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
tokenizer = Tokenizer(BPE(unk_token="[UNK]"))
from tokenizers.trainers import BpeTrainer
trainer = BpeTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"])
from tokenizers.pre_tokenizers import Whitespace
tokenizer.pre_tokenizer = Whitespace()
tokenizer = Tokenizer.from_file("custom-tokenizer.json")

# %%
# Load GloVe pretrained model
__PADDED_INDEX__ = 0
__UNKNOWN_WORD__ = 1

def load_word_embeddings(fname):
    wordvecs = {}
    with open(fname, 'r') as file:
        lines = file.readlines()
        for line in lines:
            tokens = line.split(' ')
            vec = np.array(tokens[1:], dtype=np.float32)
            wordvecs[tokens[0]] = vec

    return wordvecs

if not os.path.exists("GloVe_embedding_matrix.npy"):
  wordvecs = load_word_embeddings("glove.42B.300d.txt")
  vocab = wordvecs.keys()
  matrix = list(wordvecs.values())
  WORD2INDEX = {word: index+2 for index, word in enumerate(vocab)}
  EMBEDDING_MATRIX = np.pad(matrix, [[2,0],[0,0]], mode='constant', constant_values =0.0)
  np.save("GloVe_embedding_matrix.npy", EMBEDDING_MATRIX)
  with open("GloVe_word_to_index.json", "w") as f:
    json.dump(WORD2INDEX, f)
else:
  EMBEDDING_MATRIX = np.load("GloVe_embedding_matrix.npy")
  with open("GloVe_word_to_index.json", "r") as f:
    WORD2INDEX = json.load(f)
EMBEDDING_MATRIX = torch.tensor(EMBEDDING_MATRIX)
HIDDEN_SIZE = EMBEDDING_MATRIX.shape[1]

def glove_tokenizer(sentences):
  tokenized_texts = [tokenizer.encode(text).tokens for text in sentences]
  X = []
  for text in tokenized_texts:
    cur_text_indices = []
    for word in text:
      if word in WORD2INDEX:
          cur_text_indices.append(WORD2INDEX[word])
      else:
          cur_text_indices.append(__UNKNOWN_WORD__)
    X.append(cur_text_indices)
  return X

# %% [markdown]
# # Load data

# %%
train_links = pd.read_csv(
    f"data/{PROJECT_NAME}/train_links.csv", keep_default_na=False)
train_links['label'] = train_links['label'].map(lambda x: int(x!=0))
issues = pd.read_csv(
    f"data/{PROJECT_NAME}/preprocessed_attributes.csv", index_col="key")
issues['created'] = pd.to_datetime(issues['created'], utc=True)
issues['updated'] = pd.to_datetime(issues['updated'], utc=True)
issues = issues.fillna(" ")
first_feature = TEXT_FEATURES[0]
issues["text"] = issues[first_feature]
if len(TEXT_FEATURES)>1:
  for feature in TEXT_FEATURES[1:]:
    issues["text"] = issues["text"] + " " + issues[feature]

# %% [markdown]
# #Training

# %%
from pydantic import BaseModel

class ModelConfig(BaseModel):
  generate_batch_size: int
  mul: int
  adding_time_features: list
  mean_time_features: float
  std_time_features: float
  value_maxlen: int
  hidden_size: int
  number_units: int
  model_name: str
  learning_rate: float
  steps_per_epoch: int
  epochs: int

def generate_input(issues, train_links, config: ModelConfig):
    match_data = train_links[train_links["label"] != 0]
    none_data = train_links[train_links["label"] == 0]
    match_data = match_data[['key_1', "key_2"]].values
    none_data = none_data[['key_1', "key_2"]].values

    while True:
        each_size = int(config.generate_batch_size/2)

        # Shuffle index of match data
        shuffle_index = [index for index in np.random.choice(
            len(match_data), len(match_data), replace=False)]
        match_data = [match_data[index] for index in shuffle_index]

        for iter in range(int(len(match_data)/each_size)):
            # Split data by batch size and randomly select non_match_links: 1/2 for match data, 1/2 for non-match data

            # Get index
            match_index = np.array(range(iter*each_size, (iter+1)*each_size))
            none_index = np.array([index for index in np.random.choice(
                len(none_data), each_size*config.mul, replace=False)])

            match_links = [match_data[i] for i in match_index]
            none_links = [none_data[i] for i in none_index]

            # Create X by tokenizing and padding X
            index_pairs = np.array(match_links + none_links)
            text_1 = glove_tokenizer(issues["text"].loc[index_pairs[:,0]].values)
            text_1 = tf.keras.utils.pad_sequences(sequences=text_1, padding='post', truncating="post", maxlen=MAXLEN)
            text_2 = glove_tokenizer(issues["text"].loc[index_pairs[:,1]].values)
            text_2 = tf.keras.utils.pad_sequences(sequences=text_2, padding='post', truncating="post", maxlen=MAXLEN)

            # Create label y
            match_y = np.vstack(
                [np.zeros(len(match_links)), np.ones(len(match_links))]).T
            none_y = np.vstack([np.ones(len(none_links)), np.zeros(len(none_links))]).T
            y = np.concatenate([match_y, none_y])

            cre_1 = issues["created"].loc[index_pairs[:, 0]].values
            cre_2 = issues["created"].loc[index_pairs[:, 1]].values
            update = issues["updated"].loc[index_pairs[:, 1]].values
            cre_cre = np.array(
                (cre_1-cre_2) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)
            cre_up =  np.array(
                (cre_1-update) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)
            if len(config.adding_time_features) == 2:
                time_features = np.array(
                    [[cre_cre[i][0], cre_up[i][0]] for i in range(len(cre_cre))])
            elif "CC" in config.adding_time_features:
                time_features = cre_cre
            elif "CU" in config.adding_time_features:
                time_features = cre_up
            index = np.random.choice(len(index_pairs), config.generate_batch_size, replace=False)
            if len(config.adding_time_features) == 0:
                yield [text_1[index], text_2[index]], y[index]
            else:
                time_features = np.array(
                [(time_features[i]-config.mean_time_features)/config.std_time_features for i in range(len(time_features))])
                yield [text_1[index], text_2[index], time_features[index]], y[index]
    return 0

def return_model(config: ModelConfig):
  inputs_A = tf.keras.Input(shape=(config.value_maxlen), name="input_a")
  inputs_B = tf.keras.Input(shape=(config.value_maxlen), name="input_b")

  embedding_layer = tf.keras.layers.Embedding(input_dim=EMBEDDING_MATRIX.shape[0],
                 output_dim=EMBEDDING_MATRIX.shape[1],
                  embeddings_initializer = tf.keras.initializers.Constant(value=EMBEDDING_MATRIX),
                 mask_zero=True)
  embedding_layer.trainable=False
  # Embedding
  emb_A = embedding_layer(inputs_A)
  emb_B = embedding_layer(inputs_B)

  if len(ADDING_TIME_FEATURES)==1:
    inputs_C = tf.keras.Input(shape=(1), name="input_c")
  elif len(ADDING_TIME_FEATURES)==2:
    inputs_C = tf.keras.Input(shape=(2), name="input_c")

  # Deep Learning model's structure
  flatten_layer = tf.keras.layers.Flatten(name="flatten")
  dense_1_layer = tf.keras.layers.Dense(config.number_units, activation="relu", name="dense_1")
  output_layer = tf.keras.layers.Dense(2, activation="softmax", name="dense_output")

  if config.model_name=="CNN":
    core_layer = tf.keras.layers.Conv1D(config.number_units, 3, activation='relu')
  elif config.model_name=="LSTM":
    core_layer = tf.keras.layers.LSTM(config.number_units)
  else:
    core_layer = tf.keras.layers.GRU(config.number_units, name="gru")

  core_A = core_layer(emb_A)
  core_B = core_layer(emb_B)

  if len(ADDING_TIME_FEATURES)==0:

    # Concat two embedded inputs
    X = tf.concat([flatten_layer(core_A), flatten_layer(core_B)], axis=1)

    dense_1_X = dense_1_layer(X)

    outputs = output_layer(dense_1_X)

    model = tf.keras.Model(inputs=[inputs_A, inputs_B], outputs=outputs)

  else:

    # Concat two embedded inputs
    X = tf.concat([flatten_layer(core_A), flatten_layer(core_B), inputs_C], axis=1)

    dense_1_X = dense_1_layer(X)

    outputs = output_layer(dense_1_X)

    model = tf.keras.Model(inputs=[inputs_A, inputs_B, inputs_C], outputs=outputs)

  model.compile(tf.keras.optimizers.Adam(learning_rate=config.learning_rate), loss="mse", metrics=["categorical_accuracy"])
  model.summary()

  return model

def train_model(issues, train_links, config):
  model = return_model(config)
  history = model.fit(generate_input(issues, train_links, config),
              steps_per_epoch=config.steps_per_epoch,
              epochs=config.epochs,
              shuffle=False,
              verbose = 1)
  return model

# %%
def get_normalize_parameter(issues, train_links):
    index_pairs = train_links[["key_1", "key_2"]].values
    cre_1 = issues["created"].loc[index_pairs[:, 0]].values
    cre_2 = issues["created"].loc[index_pairs[:, 1]].values
    update = issues["updated"].loc[index_pairs[:, 1]].values
    cre_cre = np.array((cre_1-cre_2) / np.timedelta64(1,
                       'D'), dtype=int).reshape(-1, 1)
    cre_up = np.array((cre_1-update) / np.timedelta64(1, 'D'),
                      dtype=int).reshape(-1, 1)
    if len(ADDING_TIME_FEATURES) == 2:
        time_features = np.array([[cre_cre[i][0], cre_up[i][0]]
                                 for i in range(len(cre_cre))])
    elif "CC" in ADDING_TIME_FEATURES:
        time_features = cre_cre
    elif "CU" in ADDING_TIME_FEATURES:
        time_features = cre_up
    else:
      time_features = [0]
    mean = np.mean(time_features)
    std = np.std(time_features)
    return mean, std

# %%
MEAN_TIME_FEATURES, STD_TIME_FEATURES = get_normalize_parameter(
    issues, train_links)
print(MEAN_TIME_FEATURES, STD_TIME_FEATURES)
# Out:
# -239.13518612407353 1354.9751217063258

# %%
model_config = ModelConfig(
  model_name = MODEL_NAME,
  generate_batch_size = 128,
  mul = 3,
  adding_time_features = ADDING_TIME_FEATURES,
  mean_time_features = MEAN_TIME_FEATURES,
  std_time_features = STD_TIME_FEATURES,
  value_maxlen = MAXLEN,
  hidden_size = HIDDEN_SIZE,
  number_units = 256,
  learning_rate = 1e-3,
  steps_per_epoch = 5,
  epochs = 200)
model = train_model(issues, train_links, model_config)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_a (InputLayer)        [(None, 256)]                0         []
#
#  input_b (InputLayer)        [(None, 256)]                0         []
#
#  embedding (Embedding)       (None, 256, 300)             5752488   ['input_a[0][0]',
#                                                           00         'input_b[0][0]']
#
#  lstm (LSTM)                 (None, 256)                  570368    ['embedding[0][0]',
#                                                                      'embedding[1][0]']
#
#  flatten (Flatten)           (None, 256)                  0         ['lstm[0][0]',
#                                                                      'lstm[1][0]']
#
#  input_c (InputLayer)        [(None, 2)]                  0         []
#
#  tf.concat (TFOpLambda)      (None, 514)                  0         ['flatten[0][0]',
#                                                                      'flatten[1][0]',
#                                                                      'input_c[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  131840    ['tf.concat[0][0]']
#
#  dense_output (Dense)        (None, 2)                    514       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 575951522 (2.15 GB)
# Trainable params: 702722 (2.68 MB)
# Non-trainable params: 575248800 (2.14 GB)
# __________________________________________________________________________________________________
# Epoch 1/200
# 5/5 [==============================] - 12s 114ms/step - loss: 0.2143 - categorical_accuracy: 0.6687
# Epoch 2/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.1851 - categorical_accuracy: 0.7453
# Epoch 3/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.1723 - categorical_accuracy: 0.7578
# Epoch 4/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.1656 - categorical_accuracy: 0.7766
# Epoch 5/200
# 5/5 [==============================] - 1s 129ms/step - loss: 0.1698 - categorical_accuracy: 0.7719
# Epoch 6/200
# 5/5 [==============================] - 1s 178ms/step - loss: 0.1499 - categorical_accuracy: 0.7797
# Epoch 7/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.1507 - categorical_accuracy: 0.7969
# Epoch 8/200
# 5/5 [==============================] - 1s 218ms/step - loss: 0.1421 - categorical_accuracy: 0.8031
# Epoch 9/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.1233 - categorical_accuracy: 0.8172
# Epoch 10/200
# 5/5 [==============================] - 1s 235ms/step - loss: 0.1288 - categorical_accuracy: 0.8203
# Epoch 11/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.1252 - categorical_accuracy: 0.8266
# Epoch 12/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.1206 - categorical_accuracy: 0.8109
# Epoch 13/200
# 5/5 [==============================] - 1s 125ms/step - loss: 0.1095 - categorical_accuracy: 0.8484
# Epoch 14/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.1095 - categorical_accuracy: 0.8406
# Epoch 15/200
# 5/5 [==============================] - 1s 152ms/step - loss: 0.1132 - categorical_accuracy: 0.8516
# Epoch 16/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0952 - categorical_accuracy: 0.8750
# Epoch 17/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0904 - categorical_accuracy: 0.8875
# Epoch 18/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0977 - categorical_accuracy: 0.8687
# Epoch 19/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0824 - categorical_accuracy: 0.8953
# Epoch 20/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0846 - categorical_accuracy: 0.8906
# Epoch 21/200
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0859 - categorical_accuracy: 0.8891
# Epoch 22/200
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0867 - categorical_accuracy: 0.8766
# Epoch 23/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0829 - categorical_accuracy: 0.8969
# Epoch 24/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0758 - categorical_accuracy: 0.8969
# Epoch 25/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.0685 - categorical_accuracy: 0.9156
# Epoch 26/200
# 5/5 [==============================] - 1s 151ms/step - loss: 0.0644 - categorical_accuracy: 0.9219
# Epoch 27/200
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0472 - categorical_accuracy: 0.9453
# Epoch 28/200
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0584 - categorical_accuracy: 0.9281
# Epoch 29/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0580 - categorical_accuracy: 0.9266
# Epoch 30/200
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0502 - categorical_accuracy: 0.9422
# Epoch 31/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0587 - categorical_accuracy: 0.9266
# Epoch 32/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0515 - categorical_accuracy: 0.9297
# Epoch 33/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0484 - categorical_accuracy: 0.9375
# Epoch 34/200
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0531 - categorical_accuracy: 0.9312
# Epoch 35/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0396 - categorical_accuracy: 0.9563
# Epoch 36/200
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0451 - categorical_accuracy: 0.9578
# Epoch 37/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0380 - categorical_accuracy: 0.9656
# Epoch 38/200
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0406 - categorical_accuracy: 0.9531
# Epoch 39/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0387 - categorical_accuracy: 0.9625
# Epoch 40/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0394 - categorical_accuracy: 0.9594
# Epoch 41/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0348 - categorical_accuracy: 0.9688
# Epoch 42/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0412 - categorical_accuracy: 0.9547
# Epoch 43/200
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0417 - categorical_accuracy: 0.9484
# Epoch 44/200
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0307 - categorical_accuracy: 0.9656
# Epoch 45/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0387 - categorical_accuracy: 0.9609
# Epoch 46/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0265 - categorical_accuracy: 0.9703
# Epoch 47/200
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0328 - categorical_accuracy: 0.9578
# Epoch 48/200
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0280 - categorical_accuracy: 0.9688
# Epoch 49/200
# 5/5 [==============================] - 1s 273ms/step - loss: 0.0297 - categorical_accuracy: 0.9641
# Epoch 50/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0221 - categorical_accuracy: 0.9703
# Epoch 51/200
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0277 - categorical_accuracy: 0.9750
# Epoch 52/200
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0261 - categorical_accuracy: 0.9719
# Epoch 53/200
# 5/5 [==============================] - 1s 260ms/step - loss: 0.0298 - categorical_accuracy: 0.9641
# Epoch 54/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0268 - categorical_accuracy: 0.9734
# Epoch 55/200
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0255 - categorical_accuracy: 0.9719
# Epoch 56/200
# 5/5 [==============================] - 0s 103ms/step - loss: 0.0277 - categorical_accuracy: 0.9719
# Epoch 57/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0176 - categorical_accuracy: 0.9797
# Epoch 58/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0250 - categorical_accuracy: 0.9766
# Epoch 59/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0212 - categorical_accuracy: 0.9797
# Epoch 60/200
# 5/5 [==============================] - 1s 143ms/step - loss: 0.0174 - categorical_accuracy: 0.9828
# Epoch 61/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0142 - categorical_accuracy: 0.9875
# Epoch 62/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0214 - categorical_accuracy: 0.9750
# Epoch 63/200
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0136 - categorical_accuracy: 0.9891
# Epoch 64/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.0243 - categorical_accuracy: 0.9719
# Epoch 65/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.0175 - categorical_accuracy: 0.9828
# Epoch 66/200
# 5/5 [==============================] - 1s 232ms/step - loss: 0.0228 - categorical_accuracy: 0.9812
# Epoch 67/200
# 5/5 [==============================] - 1s 227ms/step - loss: 0.0149 - categorical_accuracy: 0.9891
# Epoch 68/200
# 5/5 [==============================] - 2s 207ms/step - loss: 0.0163 - categorical_accuracy: 0.9828
# Epoch 69/200
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0154 - categorical_accuracy: 0.9844
# Epoch 70/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0170 - categorical_accuracy: 0.9844
# Epoch 71/200
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0152 - categorical_accuracy: 0.9828
# Epoch 72/200
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0150 - categorical_accuracy: 0.9828
# Epoch 73/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0166 - categorical_accuracy: 0.9828
# Epoch 74/200
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0188 - categorical_accuracy: 0.9812
# Epoch 75/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0173 - categorical_accuracy: 0.9797
# Epoch 76/200
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0133 - categorical_accuracy: 0.9859
# Epoch 77/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0141 - categorical_accuracy: 0.9891
# Epoch 78/200
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0149 - categorical_accuracy: 0.9875
# Epoch 79/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0132 - categorical_accuracy: 0.9797
# Epoch 80/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0155 - categorical_accuracy: 0.9844
# Epoch 81/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0139 - categorical_accuracy: 0.9859
# Epoch 82/200
# 5/5 [==============================] - 1s 148ms/step - loss: 0.0117 - categorical_accuracy: 0.9906
# Epoch 83/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0163 - categorical_accuracy: 0.9812
# Epoch 84/200
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0139 - categorical_accuracy: 0.9844
# Epoch 85/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0146 - categorical_accuracy: 0.9812
# Epoch 86/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0133 - categorical_accuracy: 0.9844
# Epoch 87/200
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0193 - categorical_accuracy: 0.9766
# Epoch 88/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0146 - categorical_accuracy: 0.9844
# Epoch 89/200
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0148 - categorical_accuracy: 0.9828
# Epoch 90/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0138 - categorical_accuracy: 0.9844
# Epoch 91/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0163 - categorical_accuracy: 0.9797
# Epoch 92/200
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0186 - categorical_accuracy: 0.9781
# Epoch 93/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0089 - categorical_accuracy: 0.9922
# Epoch 94/200
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0166 - categorical_accuracy: 0.9812
# Epoch 95/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0098 - categorical_accuracy: 0.9891
# Epoch 96/200
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0103 - categorical_accuracy: 0.9906
# Epoch 97/200
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0133 - categorical_accuracy: 0.9844
# Epoch 98/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0093 - categorical_accuracy: 0.9875
# Epoch 99/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0139 - categorical_accuracy: 0.9828
# Epoch 100/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0129 - categorical_accuracy: 0.9859
# Epoch 101/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0123 - categorical_accuracy: 0.9906
# Epoch 102/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0095 - categorical_accuracy: 0.9891
# Epoch 103/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0096 - categorical_accuracy: 0.9875
# Epoch 104/200
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0081 - categorical_accuracy: 0.9906
# Epoch 105/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0096 - categorical_accuracy: 0.9875
# Epoch 106/200
# 5/5 [==============================] - 1s 143ms/step - loss: 0.0113 - categorical_accuracy: 0.9844
# Epoch 107/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0111 - categorical_accuracy: 0.9891
# Epoch 108/200
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0130 - categorical_accuracy: 0.9875
# Epoch 109/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0094 - categorical_accuracy: 0.9875
# Epoch 110/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0076 - categorical_accuracy: 0.9937
# Epoch 111/200
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0119 - categorical_accuracy: 0.9891
# Epoch 112/200
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0092 - categorical_accuracy: 0.9922
# Epoch 113/200
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0087 - categorical_accuracy: 0.9891
# Epoch 114/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0099 - categorical_accuracy: 0.9891
# Epoch 115/200
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0100 - categorical_accuracy: 0.9859
# Epoch 116/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0067 - categorical_accuracy: 0.9922
# Epoch 117/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0170 - categorical_accuracy: 0.9812
# Epoch 118/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0069 - categorical_accuracy: 0.9922
# Epoch 119/200
# 5/5 [==============================] - 1s 148ms/step - loss: 0.0076 - categorical_accuracy: 0.9906
# Epoch 120/200
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0045 - categorical_accuracy: 0.9969
# Epoch 121/200
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0111 - categorical_accuracy: 0.9875
# Epoch 122/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0096 - categorical_accuracy: 0.9906
# Epoch 123/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0050 - categorical_accuracy: 0.9953
# Epoch 124/200
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0062 - categorical_accuracy: 0.9937
# Epoch 125/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0091 - categorical_accuracy: 0.9891
# Epoch 126/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.0079 - categorical_accuracy: 0.9937
# Epoch 127/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0083 - categorical_accuracy: 0.9891
# Epoch 128/200
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0059 - categorical_accuracy: 0.9906
# Epoch 129/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0100 - categorical_accuracy: 0.9891
# Epoch 130/200
# 5/5 [==============================] - 1s 229ms/step - loss: 0.0106 - categorical_accuracy: 0.9891
# Epoch 131/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0134 - categorical_accuracy: 0.9844
# Epoch 132/200
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0078 - categorical_accuracy: 0.9922
# Epoch 133/200
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0119 - categorical_accuracy: 0.9828
# Epoch 134/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0094 - categorical_accuracy: 0.9922
# Epoch 135/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0094 - categorical_accuracy: 0.9906
# Epoch 136/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0139 - categorical_accuracy: 0.9828
# Epoch 137/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0070 - categorical_accuracy: 0.9937
# Epoch 138/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0085 - categorical_accuracy: 0.9906
# Epoch 139/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0055 - categorical_accuracy: 0.9937
# Epoch 140/200
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0150 - categorical_accuracy: 0.9828
# Epoch 141/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0066 - categorical_accuracy: 0.9937
# Epoch 142/200
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0063 - categorical_accuracy: 0.9969
# Epoch 143/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0056 - categorical_accuracy: 0.9937
# Epoch 144/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0072 - categorical_accuracy: 0.9922
# Epoch 145/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0093 - categorical_accuracy: 0.9875
# Epoch 146/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0058 - categorical_accuracy: 0.9953
# Epoch 147/200
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0078 - categorical_accuracy: 0.9953
# Epoch 148/200
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0041 - categorical_accuracy: 0.9953
# Epoch 149/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0090 - categorical_accuracy: 0.9875
# Epoch 150/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0097 - categorical_accuracy: 0.9875
# Epoch 151/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0050 - categorical_accuracy: 0.9953
# Epoch 152/200
# 5/5 [==============================] - 1s 231ms/step - loss: 0.0043 - categorical_accuracy: 0.9953
# Epoch 153/200
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0028 - categorical_accuracy: 0.9969
# Epoch 154/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0064 - categorical_accuracy: 0.9891
# Epoch 155/200
# 5/5 [==============================] - 1s 151ms/step - loss: 0.0060 - categorical_accuracy: 0.9906
# Epoch 156/200
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0086 - categorical_accuracy: 0.9906
# Epoch 157/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0062 - categorical_accuracy: 0.9922
# Epoch 158/200
# 5/5 [==============================] - 1s 151ms/step - loss: 0.0091 - categorical_accuracy: 0.9906
# Epoch 159/200
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0064 - categorical_accuracy: 0.9922
# Epoch 160/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0060 - categorical_accuracy: 0.9969
# Epoch 161/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0090 - categorical_accuracy: 0.9922
# Epoch 162/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0086 - categorical_accuracy: 0.9891
# Epoch 163/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0046 - categorical_accuracy: 0.9953
# Epoch 164/200
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0092 - categorical_accuracy: 0.9906
# Epoch 165/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.0064 - categorical_accuracy: 0.9906
# Epoch 166/200
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0039 - categorical_accuracy: 0.9953
# Epoch 167/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0057 - categorical_accuracy: 0.9937
# Epoch 168/200
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0071 - categorical_accuracy: 0.9922
# Epoch 169/200
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0051 - categorical_accuracy: 0.9937
# Epoch 170/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0053 - categorical_accuracy: 0.9937
# Epoch 171/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0055 - categorical_accuracy: 0.9937
# Epoch 172/200
# 5/5 [==============================] - 1s 225ms/step - loss: 0.0055 - categorical_accuracy: 0.9922
# Epoch 173/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0047 - categorical_accuracy: 0.9953
# Epoch 174/200
# 5/5 [==============================] - 1s 156ms/step - loss: 0.0091 - categorical_accuracy: 0.9922
# Epoch 175/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0087 - categorical_accuracy: 0.9891
# Epoch 176/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.0060 - categorical_accuracy: 0.9953
# Epoch 177/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0063 - categorical_accuracy: 0.9953
# Epoch 178/200
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0078 - categorical_accuracy: 0.9891
# Epoch 179/200
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0062 - categorical_accuracy: 0.9953
# Epoch 180/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0079 - categorical_accuracy: 0.9906
# Epoch 181/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0046 - categorical_accuracy: 0.9937
# Epoch 182/200
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0066 - categorical_accuracy: 0.9953
# Epoch 183/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0081 - categorical_accuracy: 0.9875
# Epoch 184/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0063 - categorical_accuracy: 0.9937
# Epoch 185/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0076 - categorical_accuracy: 0.9922
# Epoch 186/200
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0071 - categorical_accuracy: 0.9937
# Epoch 187/200
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0061 - categorical_accuracy: 0.9937
# Epoch 188/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0077 - categorical_accuracy: 0.9906
# Epoch 189/200
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0047 - categorical_accuracy: 0.9953
# Epoch 190/200
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0046 - categorical_accuracy: 0.9922
# Epoch 191/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0019 - categorical_accuracy: 0.9984
# Epoch 192/200
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0074 - categorical_accuracy: 0.9906
# Epoch 193/200
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0068 - categorical_accuracy: 0.9922
# Epoch 194/200
# 5/5 [==============================] - 1s 312ms/step - loss: 0.0050 - categorical_accuracy: 0.9969
# Epoch 195/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0076 - categorical_accuracy: 0.9906
# Epoch 196/200
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0044 - categorical_accuracy: 0.9922
# Epoch 197/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0053 - categorical_accuracy: 0.9937
# Epoch 198/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.0084 - categorical_accuracy: 0.9906
# Epoch 199/200
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0060 - categorical_accuracy: 0.9937
# Epoch 200/200
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0053 - categorical_accuracy: 0.9937

# %%
model.save_weights(f"{EMBEDDING_METHOD}_{MODEL_NAME}.h5")

# %% [markdown]
# # Test

# %%
test_links = pd.read_csv(
    f"data/{PROJECT_NAME}/test_links.csv", keep_default_na=False)
test_links['label'] = test_links['label'].map(lambda x: int(x!=0))

# %%
from torch.utils.data import Dataset,  DataLoader
class TestDataset(Dataset):
    def __init__(self, index_pairs, labels):
        self.index_pairs = index_pairs
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
      return [self.index_pairs[idx,0], self.index_pairs[idx,1]], self.labels[idx]

# %%
def get_predict(issues, index_pairs, config, model):
  text_1 = glove_tokenizer(issues["text"].loc[index_pairs[0]].values)
  text_1 = tf.keras.utils.pad_sequences(sequences=text_1, padding='post', truncating="post", maxlen=MAXLEN)
  text_2 = glove_tokenizer(issues["text"].loc[index_pairs[1]].values)
  text_2 = tf.keras.utils.pad_sequences(sequences=text_2, padding='post', truncating="post", maxlen=MAXLEN)
  cre_1 = issues["created"].loc[index_pairs[0]].values
  cre_2 = issues["created"].loc[index_pairs[1]].values
  update = issues["updated"].loc[index_pairs[1]].values
  cre_cre = np.array(
      (cre_1-cre_2) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)
  cre_up =  np.array(
      (cre_1-update) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)

  if len(config.adding_time_features) == 2:
      time_features = np.array(
          [[cre_cre[i][0], cre_up[i][0]] for i in range(len(cre_cre))])
  elif "CC" in config.adding_time_features:
      time_features = cre_cre
  elif "CU" in config.adding_time_features:
      time_features = cre_up
  else:
    return model([text_1, text_2])
  if len(config.adding_time_features) > 0:
    time_features = np.array(
        [(time_features[i]-config.mean_time_features)/config.std_time_features for i in range(len(time_features))])
  return model([text_1, text_2, time_features])

# %%
labels = []
for i in test_links["label"].values:
  if i==0:
    labels.append([1,0])
  else:
    labels.append([0,1])
test_data = TestDataset(test_links[["key_1", "key_2"]].values, labels)

# %%
test_dataloader = DataLoader(test_data, batch_size=2048)
len(test_dataloader)
# Out:
# 243

# %%
if not os.path.exists(f"results_{EMBEDDING_METHOD}_{PROJECT_NAME}"):
  os.mkdir(f"results_{EMBEDDING_METHOD}_{PROJECT_NAME}")

# %%
for index, i in enumerate(test_dataloader):
  index_pairs, label = i
  index_pairs[0] = np.array( index_pairs[0])
  index_pairs[1] = np.array( index_pairs[1])
  proba = get_predict(issues, index_pairs, model_config, model)
  torch.save(proba, f"results_{EMBEDDING_METHOD}_{PROJECT_NAME}/result_{index}.pt")
  torch.cuda.empty_cache()
  print(f"{index}/{len(test_dataloader)}")
# Out:
# 0/243
# 1/243
# 2/243
# 3/243
# 4/243
# 5/243
# 6/243
# 7/243
# 8/243
# 9/243
# 10/243
# 11/243
# 12/243
# 13/243
# 14/243
# 15/243
# 16/243
# 17/243
# 18/243
# 19/243
# 20/243
# 21/243
# 22/243
# 23/243
# 24/243
# 25/243
# 26/243
# 27/243
# 28/243
# 29/243
# 30/243
# 31/243
# 32/243
# 33/243
# 34/243
# 35/243
# 36/243
# 37/243
# 38/243
# 39/243
# 40/243
# 41/243
# 42/243
# 43/243
# 44/243
# 45/243
# 46/243
# 47/243
# 48/243
# 49/243
# 50/243
# 51/243
# 52/243
# 53/243
# 54/243
# 55/243
# 56/243
# 57/243
# 58/243
# 59/243
# 60/243
# 61/243
# 62/243
# 63/243
# 64/243
# 65/243
# 66/243
# 67/243
# 68/243
# 69/243
# 70/243
# 71/243
# 72/243
# 73/243
# 74/243
# 75/243
# 76/243
# 77/243
# 78/243
# 79/243
# 80/243
# 81/243
# 82/243
# 83/243
# 84/243
# 85/243
# 86/243
# 87/243
# 88/243
# 89/243
# 90/243
# 91/243
# 92/243
# 93/243
# 94/243
# 95/243
# 96/243
# 97/243
# 98/243
# 99/243
# 100/243
# 101/243
# 102/243
# 103/243
# 104/243
# 105/243
# 106/243
# 107/243
# 108/243
# 109/243
# 110/243
# 111/243
# 112/243
# 113/243
# 114/243
# 115/243
# 116/243
# 117/243
# 118/243
# 119/243
# 120/243
# 121/243
# 122/243
# 123/243
# 124/243
# 125/243
# 126/243
# 127/243
# 128/243
# 129/243
# 130/243
# 131/243
# 132/243
# 133/243
# 134/243
# 135/243
# 136/243
# 137/243
# 138/243
# 139/243
# 140/243
# 141/243
# 142/243
# 143/243
# 144/243
# 145/243
# 146/243
# 147/243
# 148/243
# 149/243
# 150/243
# 151/243
# 152/243
# 153/243
# 154/243
# 155/243
# 156/243
# 157/243
# 158/243
# 159/243
# 160/243
# 161/243
# 162/243
# 163/243
# 164/243
# 165/243
# 166/243
# 167/243
# 168/243
# 169/243
# 170/243
# 171/243
# 172/243
# 173/243
# 174/243
# 175/243
# 176/243
# 177/243
# 178/243
# 179/243
# 180/243
# 181/243
# 182/243
# 183/243
# 184/243
# 185/243
# 186/243
# 187/243
# 188/243
# 189/243
# 190/243
# 191/243
# 192/243
# 193/243
# 194/243
# 195/243
# 196/243
# 197/243
# 198/243
# 199/243
# 200/243
# 201/243
# 202/243
# 203/243
# 204/243
# 205/243
# 206/243
# 207/243
# 208/243
# 209/243
# 210/243
# 211/243
# 212/243
# 213/243
# 214/243
# 215/243
# 216/243
# 217/243
# 218/243
# 219/243
# 220/243
# 221/243
# 222/243
# 223/243
# 224/243
# 225/243
# 226/243
# 227/243
# 228/243
# 229/243
# 230/243
# 231/243
# 232/243
# 233/243
# 234/243
# 235/243
# 236/243
# 237/243
# 238/243
# 239/243
# 240/243
# 241/243
# 242/243

# %%
pred_proba = torch.tensor([])
for index, _ in tqdm(enumerate(test_dataloader)):
  proba = torch.load(f"results_{EMBEDDING_METHOD}_{PROJECT_NAME}/result_{index}.pt")
  if index==0:
    pred_proba = proba
  else:
    pred_proba=tf.concat([pred_proba, proba],axis=0)
# Out:
# 243it [00:02, 91.52it/s]

# %%
y_s = [np.argmax(i) for i in labels]
pred_s = np.argmax(pred_proba.numpy(),axis=1)

# %%
len(pred_proba)
# Out:
# 496524

# %%
from sklearn.metrics import confusion_matrix, classification_report
print("Confusion maxtrix")
print(confusion_matrix(y_s, pred_s))
print(classification_report(y_s, pred_s, digits= 2))
# Out:
# Confusion maxtrix
# [[493784   2517]
#  [   141     82]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    496301
#            1       0.03      0.37      0.06       223
#
#     accuracy                           0.99    496524
#    macro avg       0.52      0.68      0.53    496524
# weighted avg       1.00      0.99      1.00    496524

# %% [markdown]
# # Recommend

# %%
match_test_links = test_links[test_links["label"]!=0]

# %%
test_issues = pd.read_csv(f"data/{PROJECT_NAME}/test_issues.csv", index_col="key").index

y_test = []
filter_test_issues = []
for test_issue in tqdm(test_issues):
  filter_links = match_test_links[(match_test_links["key_1"]==test_issue)|(match_test_links["key_2"]==test_issue)]
  if len(filter_links)>0:
    match_issues = set(list(filter_links["key_1"].values) + list(filter_links["key_2"].values))
    match_issues.remove(test_issue)
    y_test.append(list(match_issues))
    filter_test_issues.append(test_issue)
test_issues = filter_test_issues
# Out:
# 100%|██████████| 276/276 [00:00<00:00, 996.40it/s]

# %%
len(test_issues)
# Out:
# 276

# %%
def get_accuracy(pred, gt):
	acc = 0
	for i, item in enumerate(pred):
		if item in gt:
			acc += 1.0
			break
	return acc

def get_MRR(pred, gt):
	mrr = 0
	for i, item in enumerate(pred):
		if item in gt:
			mrr += 1.0/(i+1)
	return mrr

def get_precision_recall(pred, gt):
	right = 0

	for item in gt:
		if item in pred: # relevant
			right+=1

	if len(pred) == 0:
		precision = 0
	else:
		precision = right/len(pred)
	recall = right/len(gt)

	return precision, recall

def get_f1_score(precision, recall):
    if precision + recall == 0:
        return 0
    f1_score = 2 * (precision * recall) / (precision + recall)
    return f1_score

def get_f0_5_score(precision, recall):
    beta = 0.5
    if precision + recall == 0:
        return 0
    f0_5_score = (1 + beta**2) * (precision * recall) / (beta**2 * precision + recall)
    return f0_5_score

def get_f2_score(precision, recall):
    beta = 2
    if precision + recall == 0:
        return 0
    f2_score = (1 + beta**2) * (precision * recall) / (beta**2 * precision + recall)
    return f2_score

def get_metrics(recommend, label):
	acc = 0
	mrr = 0
	precision = 0
	recall = 0
	f1 = 0
	f0_5 = 0
	f2 = 0
	for i in range(0, len(recommend)):
		if len(label[i])!=0:
			acc += get_accuracy(recommend[i], label[i])
			mrr += get_MRR(recommend[i], label[i])
			precision_recall = get_precision_recall(recommend[i], label[i])
			precision += precision_recall[0]
			recall += precision_recall[1]
			f1 = get_f1_score(precision_recall[0], precision_recall[1])
			f0_5 = get_f0_5_score(precision_recall[0], precision_recall[1])
			f2 = get_f2_score(precision_recall[0], precision_recall[1])

	acc = acc/(len(recommend))
	mrr = mrr/(len(recommend))
	precision = precision/(len(recommend))
	recall = recall/(len(recommend))
	f1 = f1/(len(recommend))
	f0_5 = f0_5/(len(recommend))
	f2 = f2/(len(recommend))
	return acc, mrr, precision, recall, f1, f0_5, f2

# %%
def get_recommendation(test_issue, issues, test_links):
  all_issues = list(issues.index)
  all_issues.remove(test_issue)

  test_links_1 = pd.DataFrame(
      {"key_1": [test_issue]*len(all_issues), "key_2": all_issues})
  test_links_1["link_id"] = test_links_1["key_1"] + "-" + test_links_1["key_2"]
  test_links_1 = test_links[test_links["link_id"].isin(test_links_1["link_id"].values)]
  pred_proba_1 = [(pred, issue) for pred, issue in zip(test_links_1["proba"].values, test_links_1["key_2"].values)]

  test_links_2 = pd.DataFrame(
      {"key_1": all_issues, "key_2": [test_issue]*len(all_issues)})
  test_links_2["link_id"] = test_links_2["key_1"] + "-" + test_links_2["key_2"]
  test_links_2 = test_links[test_links["link_id"].isin(test_links_2["link_id"].values)]
  pred_proba_2 = [(pred, issue) for pred, issue in zip(test_links_2["proba"].values, test_links_2["key_1"].values)]

  pred_proba_3 = pred_proba_1 + pred_proba_2
  preprocess_pred_proba = {}
  for pred, issue in pred_proba_3:
    if issue not in preprocess_pred_proba:
      preprocess_pred_proba[issue] = pred
    else:
      preprocess_pred_proba[issue] = max(pred, preprocess_pred_proba[issue])
  preprocess_pred_proba = [(pred, issue) for issue, pred in preprocess_pred_proba.items()]

  return [pair[1] for pair in sorted(preprocess_pred_proba, reverse=True)]

def filter_time(issues, test_issue, recommend_issues, days: int):
    cre_1 = issues["created"].loc[[test_issue]*len(recommend_issues)].values
    cre_2 = issues["created"].loc[recommend_issues].values
    cre_cre = np.abs(
        np.array((cre_1-cre_2) / np.timedelta64(1, 'D'), dtype=int))
    recommend_issues = [i for index, i in enumerate(
        recommend_issues) if cre_cre[index] <= days]
    return recommend_issues

# %%
test_links["proba"] = pred_proba[:,1]

# %%
test_links["link_id"] = test_links["key_1"] + "-" + test_links["key_2"]

# %%
recommend_results = []
for test_issue in tqdm(test_issues):
    recommend_results.append(get_recommendation(
        test_issue, issues, test_links))
# Out:
# 100%|██████████| 276/276 [00:16<00:00, 16.54it/s]

# %%
print("---No filter---")
for k in [1,2,3,5,10]:
  recommend_list = [i[:k] for i in recommend_results]
  acc, mrr, precision, recall, f1, f0_5, f2 = get_metrics(recommend_list, y_test)
  print(f"Top {k}:")
  print(f"Acc = {acc}")
  print(f"MRR = {mrr}")
  print(f"Recall = {recall}")
  print(f"F1 = {f1}")
  print(f"F0.5 = {f0_5}")
  print(f"F2 = {f2}")
# Out:
# ---No filter---
# Top 1:
# Acc = 0.13768115942028986
# MRR = 0.13768115942028986
# Recall = 0.13768115942028986
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 2:
# Acc = 0.213768115942029
# MRR = 0.17572463768115942
# Recall = 0.20954106280193238
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 3:
# Acc = 0.2753623188405797
# MRR = 0.19746376811594205
# Recall = 0.27113526570048313
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 5:
# Acc = 0.322463768115942
# MRR = 0.20815217391304353
# Recall = 0.31823671497584544
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 10:
# Acc = 0.38768115942028986
# MRR = 0.21875431331953074
# Recall = 0.3804347826086957
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0

# %%
print("---60 days filter---")
filter_recommend_results = []
for test_issue, recommend_issues in zip(test_issues, recommend_results):
    filter_recommend_results.append(
        filter_time(issues, test_issue, recommend_issues, 60))
for k in [1,2,3,5,10]:
  recommend_list = [i[:k] for i in filter_recommend_results]
  acc, mrr, precision, recall, f1, f0_5, f2 = get_metrics(recommend_list, y_test)
  print(f"Top {k}:")
  print(f"Acc = {acc}")
  print(f"MRR = {mrr}")
  print(f"Recall = {recall}")
  print(f"F1 = {f1}")
  print(f"F0.5 = {f0_5}")
  print(f"F2 = {f2}")

print("---30 days filter---")
filter_recommend_results = []
for test_issue, recommend_issues in zip(test_issues, recommend_results):
    filter_recommend_results.append(
        filter_time(issues, test_issue, recommend_issues, 30))
for k in [1,2,3,5,10]:
  recommend_list = [i[:k] for i in filter_recommend_results]
  acc, mrr, precision, recall, f1, f0_5, f2 = get_metrics(recommend_list, y_test)
  print(f"Top {k}:")
  print(f"Acc = {acc}")
  print(f"MRR = {mrr}")
  print(f"Recall = {recall}")
  print(f"F1 = {f1}")
  print(f"F0.5 = {f0_5}")
  print(f"F2 = {f2}")
# Out:
# ---60 days filter---
# Top 1:
# Acc = 0.2427536231884058
# MRR = 0.2427536231884058
# Recall = 0.23671497584541065
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 2:
# Acc = 0.2971014492753623
# MRR = 0.2717391304347826
# Recall = 0.2892512077294686
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 3:
# Acc = 0.33695652173913043
# MRR = 0.285024154589372
# Recall = 0.3272946859903382
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 5:
# Acc = 0.3695652173913043
# MRR = 0.29317632850241554
# Recall = 0.35688405797101447
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 10:
# Acc = 0.463768115942029
# MRR = 0.30744191396365317
# Recall = 0.45169082125603865
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# ---30 days filter---
# Top 1:
# Acc = 0.2427536231884058
# MRR = 0.2427536231884058
# Recall = 0.23671497584541065
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 2:
# Acc = 0.3007246376811594
# MRR = 0.27355072463768115
# Recall = 0.2928743961352657
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 3:
# Acc = 0.33695652173913043
# MRR = 0.28562801932367143
# Recall = 0.3291062801932367
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 5:
# Acc = 0.39492753623188404
# MRR = 0.30084541062801934
# Recall = 0.38405797101449274
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 10:
# Acc = 0.4420289855072464
# MRR = 0.3089817690361169
# Recall = 0.43417874396135264
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
