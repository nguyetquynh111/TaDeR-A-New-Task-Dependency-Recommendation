# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My Drive/IssuesManagement
# Out:
# /content/drive/.shortcut-targets-by-id/1Hgps4QuC_8w15htjlDJJFgm2WyvBtk5Y/IssuesManagement

# %%
PROJECT_NAME = "FLUME"

TEXT_FEATURES = ["title", "description", "summary"]
ADDING_TIME_FEATURES = ["CC", "CU"]

MAXLEN = 256
MODEL_NAME = "LSTM"
EMBEDDING_METHOD = "GloVe"

# %% [markdown]
# # Train Tokenizers

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)

# %%
import sentencepiece as spm

# Train SentencePiece model
spm.SentencePieceTrainer.train(input='train.txt', model_prefix='my_model', vocab_size=8420)

# %%
# Load SentencePiece model
sp = spm.SentencePieceProcessor(model_file='my_model.model')

# %%
vocab = [sp.id_to_piece(i) for i in range(sp.get_piece_size())]
sorted_vocab = list(sorted(vocab))

# %%
len(sorted_vocab)
# Out:
# 8000

# %%
def find_words_containing_token(token, vocab_list):
    matching_words = [word for word in vocab_list if token in word]
    return matching_words

# %%
for token in vocab:
  matching_words = find_words_containing_token(token, sorted_vocab)
  if len(matching_words)>1:
    print("\n------------\n")
    print(token)
    for word in matching_words:
      if word!=token:
        print(word)
# Out:
# Streaming output truncated to the last 5000 lines.
# ▁kno
# ▁know
#
# ------------
#
# arrie
# ▁carrie
#
# ------------
#
# ▁320
# ▁3209
#
# ------------
#
# ▁aris
# ▁arise
#
# ------------
#
# ven
# ableevent
# avroevent
# driven
# esthdfseventsink
# event
# eventqueue
# eventread
# eventreader
# events
# eventserializer
# eventsink
# eventso
# eventsource
# fileeventreader
# flumeevent
# flumeeventqueue
# hdfseventsink
# hrifteventsource
# maven
# stampedevent
# steven
# thriftevent
# totalevent
# vent
# ▁addtoevent
# ▁avroevents
# ▁conven
# ▁convention
# ▁even
# ▁event
# ▁eventbu
# ▁eventd
# ▁eventdelivery
# ▁eventdrain
# ▁eventdriven
# ▁eventgroup
# ▁eventput
# ▁eventqueue
# ▁events
# ▁eventserializer
# ▁eventsink
# ▁eventtake
# ▁eventual
# ▁eventvalidator
# ▁execeventsource
# ▁flumeevent
# ▁flumeeventqueue
# ▁given
# ▁hdfseven
# ▁hdfsevent
# ▁hdfseventsink
# ▁interven
# ▁jsonevent
# ▁jsonevents
# ▁maven
# ▁mavenize
# ▁prevent
# ▁processevent
# ▁readevent
# ▁readevents
# ▁simpleevent
# ▁testevent
# ▁testflumeevent
# ▁thriftevent
# ▁thriftevents
# ▁totalevent
# ▁vendor
#
# ------------
#
# ▁fold
# ▁folder
#
# ------------
#
# ▁beha
# ▁behave
# ▁behavior
# ▁behaviors
# ▁behaviour
#
# ------------
#
# 643
# 6432
# ▁643
#
# ------------
#
# ynch
# asynchbase
# asynchbasesink
# synchronizer
# ynchronizer
# ▁asynch
# ▁asynchbase
# ▁asynchbasesink
# ▁asynchronous
# ▁synchroni
# ▁synchronization
# ▁synchronized
# ▁synchronous
#
# ------------
#
# ▁configura
# ▁configurable
# ▁configurat
# ▁configuration
# ▁configurations
#
# ------------
#
# ints
# points
# ▁prints
#
# ------------
#
# stop
# ▁stop
# ▁stopped
# ▁stopping
# ▁stops
#
# ------------
#
# ▁struc
# ▁structur
# ▁structure
#
# ------------
#
# bot
# ▁bott
#
# ------------
#
# apache
# ▁apache
# ▁apachesolrsink
#
# ------------
#
# ality
# ▁functionality
#
# ------------
#
# ando
# random
# randomaccessfile
# ▁random
# ▁randomaccess
# ▁randomly
#
# ------------
#
# ponses
# ▁responses
#
# ------------
#
# validates
# ▁validates
#
# ------------
#
# ndo
# ando
# endof
# random
# randomaccessfile
# window
# windows
# ▁isendof
# ▁random
# ▁randomaccess
# ▁randomly
# ▁vendor
# ▁window
# ▁windows
#
# ------------
#
# ydata
# ▁mydata
#
# ------------
#
# ▁rela
# ▁relat
# ▁relate
# ▁relative
#
# ------------
#
# 4288
# ▁42889
#
# ------------
#
# ups
# groups
# unixgroups
# upstream
# ▁groups
# ▁lookups
#
# ------------
#
# dirsource
# ▁taildirsource
#
# ------------
#
# ques
# indexrequest
# request
# ▁bulkrequest
# ▁indexrequest
# ▁question
# ▁questions
# ▁request
#
# ------------
#
# ntify
# ▁identify
#
# ------------
#
# uncher
# ▁launcher
#
# ------------
#
# ong
# long
# longbuffer
# ▁along
# ▁belong
# ▁long
# ▁wrong
#
# ------------
#
# ▁eve
# ▁even
# ▁event
# ▁eventbu
# ▁eventd
# ▁eventdelivery
# ▁eventdrain
# ▁eventdriven
# ▁eventgroup
# ▁eventput
# ▁eventqueue
# ▁events
# ▁eventserializer
# ▁eventsink
# ▁eventtake
# ▁eventual
# ▁eventvalidator
# ▁ever
# ▁every
# ▁everyt
#
# ------------
#
# 782
# ▁13057822
#
# ------------
#
# ▁reliabl
# ▁reliable
#
# ------------
#
# nopadding
# ▁aesctrnopadding
#
# ------------
#
# agents
# agentsink
# ▁agents
# ▁testagentsink
#
# ------------
#
# ues
# gues
# indexrequest
# ques
# request
# ▁bulkrequest
# ▁guess
# ▁indexrequest
# ▁issues
# ▁memoryqueues
# ▁question
# ▁questions
# ▁queues
# ▁request
# ▁values
#
# ------------
#
# ision
# collision
# ▁collision
# ▁decision
# ▁revision
#
# ------------
#
# post
# ▁httppost
# ▁post
# ▁poster
#
# ------------
#
# ▁minim
# ▁minimal
# ▁minimiz
# ▁minimum
#
# ------------
#
# rea
# already
# create
# created
# datastream
# decrease
# dthreadpool
# duledthreadpool
# edthreadpool
# eduledthreadpool
# erthread
# ethreadexecutor
# eventread
# eventreader
# fileeventreader
# fileinputstream
# filelinereader
# filereader
# increase
# inputstream
# inthreadscrazily
# linereader
# putstream
# reach
# reached
# read
# readbufferbytes
# reader
# reading
# readpo
# ready
# reason
# reated
# singlethreadedbu
# stream
# tcpsourcethreads
# testbatchedreads
# thread
# threadedserver
# threadfactory
# threadpool
# threads
# tream
# tthreadseverpool
# upstream
# utstream
# ▁already
# ▁break
# ▁breaking
# ▁crea
# ▁creat
# ▁create
# ▁created
# ▁createindex
# ▁creates
# ▁creati
# ▁creation
# ▁datastream
# ▁decrease
# ▁filereader
# ▁great
# ▁increa
# ▁increas
# ▁increase
# ▁inputstream
# ▁multithread
# ▁newsinglethread
# ▁rea
# ▁reach
# ▁reache
# ▁reached
# ▁reactivate
# ▁read
# ▁readall
# ▁reader
# ▁readevent
# ▁readevents
# ▁readi
# ▁reading
# ▁readint
# ▁readline
# ▁readme
# ▁readmessage
# ▁reads
# ▁real
# ▁realize
# ▁realm
# ▁reason
# ▁recreat
# ▁spread
# ▁stream
# ▁streaming
# ▁streams
# ▁testthreaded
# ▁threa
# ▁thread
# ▁threaded
# ▁threadfactory
# ▁threadpool
# ▁threads
# ▁threadsafe
# ▁treat
# ▁tthreadedselect
# ▁unrea
#
# ------------
#
# ▁pat
# ▁patch
# ▁path
# ▁paths
# ▁pattern
#
# ------------
#
# chars
# charset
# ▁chars
# ▁charsequence
# ▁charset
#
# ------------
#
# pol
# policy
# pollablesource
# ▁epollselector
# ▁poli
# ▁polic
# ▁policy
# ▁poll
# ▁pollable
# ▁pollablesource
# ▁polling
# ▁pollute
# ▁testpolling
# ▁topolog
#
# ------------
#
# 002
# 00002
# 0002
# ▁0000002
#
# ------------
#
# lint
# doclint
# ▁doclint
#
# ------------
#
# 158
# ▁158
#
# ------------
#
# ains
# ▁chains
# ▁contains
#
# ------------
#
# ▁mit
# ▁mitigat
#
# ------------
#
# 1718
# ▁12921718
#
# ------------
#
# tes
# ates
# atest
# bytes
# ites
# latest
# notes
# readbufferbytes
# test
# testbatchedreads
# testdiskfailover
# testhttps
# testinflight
# testing
# testingutility
# testmini
# testnaivefilewal
# tests
# testse
# testsuccess
# testthriftlegacy
# validates
# writebytes
# ▁attributes
# ▁bytes
# ▁bytestr
# ▁certificates
# ▁creates
# ▁dates
# ▁dotest
# ▁duplicates
# ▁minutes
# ▁notes
# ▁printgcdates
# ▁routes
# ▁test
# ▁testagentsink
# ▁testapp
# ▁testavro
# ▁testavrosink
# ▁testba
# ▁testbasic
# ▁testbatchtime
# ▁testca
# ▁testcapacity
# ▁testch
# ▁testcheckpoint
# ▁testconcurrent
# ▁teste
# ▁tested
# ▁testempty
# ▁testevent
# ▁testexec
# ▁testfile
# ▁testfilechannel
# ▁testflume
# ▁testflumeevent
# ▁testflumenode
# ▁testhbasesink
# ▁testhdfs
# ▁testhttp
# ▁testhttps
# ▁testin
# ▁testinflight
# ▁testing
# ▁testkafka
# ▁testkafkasource
# ▁testlifecycle
# ▁testlog
# ▁testmaster
# ▁testmini
# ▁testmulti
# ▁testmultip
# ▁testname
# ▁testne
# ▁testnet
# ▁testno
# ▁testnode
# ▁testpolling
# ▁testremove
# ▁tests
# ▁testserver
# ▁testspool
# ▁testsyslog
# ▁testthreaded
# ▁testthrift
# ▁testthriftsink
# ▁testus
# ▁testversioninfo
# ▁testwith
# ▁testzk
# ▁updates
# ▁validates
# ▁writebytes
# ▁writes
#
# ------------
#
# gp
# ▁gp
# ▁gpl
# ▁lgpl
#
# ------------
#
# hostnames
# ▁hostnames
#
# ------------
#
# nal
# additional
# analyze
# external
# internal
# nally
# rational
# ternalhttpserver
# ▁additional
# ▁analys
# ▁analytic
# ▁analyze
# ▁analyzer
# ▁bidirectional
# ▁experimenal
# ▁external
# ▁final
# ▁functional
# ▁functionalit
# ▁functionality
# ▁internal
# ▁internally
# ▁occasional
# ▁optional
# ▁original
# ▁signal
# ▁unconditionally
#
# ------------
#
# ▁2044
# ▁20445
#
# ------------
#
# rep
# blockreplica
# grep
# hriftflumereport
# keystorepassword
# keystoreprovider
# repeat
# repeate
# replace
# replay
# replica
# replication
# reply
# report
# repository
# storepass
# underreplicat
# underreplication
# ▁discrepancy
# ▁getreport
# ▁prepar
# ▁prepare
# ▁prepares
# ▁prepende
# ▁rep
# ▁repeat
# ▁repeate
# ▁repeated
# ▁repeatedly
# ▁repetiti
# ▁replac
# ▁replace
# ▁replaced
# ▁replacement
# ▁replaces
# ▁replay
# ▁replayed
# ▁replays
# ▁replica
# ▁replicat
# ▁replicate
# ▁replicating
# ▁repo
# ▁report
# ▁reporte
# ▁reporting
# ▁reports
# ▁repos
# ▁repositor
# ▁repository
# ▁represent
# ▁reproduc
# ▁reproduce
#
# ------------
#
# send
# ▁isendof
# ▁resend
# ▁send
#
# ------------
#
# ▁ski
# ▁skip
# ▁skipp
# ▁skipped
#
# ------------
#
# ▁mal
# ▁malformed
#
# ------------
#
# ▁marke
# ▁marker
#
# ------------
#
# ▁unfo
# ▁unfortunate
#
# ------------
#
# ories
# ▁directories
# ▁subdirectories
#
# ------------
#
# men
# argument
# arguments
# chment
# comment
# commenti
# deployment
# documented
# element
# ement
# implement
# implementation
# increment
# incrementchannel
# increments
# ment
# mentioned
# ments
# namenodeprotocol
# omen
# placement
# plement
# rgumentexception
# startfromend
# uments
# ▁agreement
# ▁argument
# ▁arguments
# ▁atomicincrement
# ▁attachment
# ▁attachments
# ▁comment
# ▁comments
# ▁deployment
# ▁deployments
# ▁development
# ▁document
# ▁documentation
# ▁documented
# ▁element
# ▁elements
# ▁enhancement
# ▁environment
# ▁environments
# ▁experimenal
# ▁experiment
# ▁flumeng
# ▁flumenode
# ▁flumenodew
# ▁fundamental
# ▁implement
# ▁implementation
# ▁improvement
# ▁improvements
# ▁improvments
# ▁increment
# ▁incremental
# ▁increments
# ▁instrument
# ▁men
# ▁mention
# ▁mentioned
# ▁moment
# ▁nameno
# ▁namenode
# ▁recommend
# ▁recommendation
# ▁replacement
# ▁requirement
# ▁restartfromend
# ▁statement
# ▁testflumenode
# ▁xmen
#
# ------------
#
# ▁wrapp
# ▁wrappe
# ▁wrapper
#
# ------------
#
# ▁orc
# ▁orchestra
# ▁orchestrat
#
# ------------
#
# tting
# committing
# itting
# utting
# ▁getting
# ▁setting
# ▁settings
# ▁shutting
#
# ------------
#
# 605
# 5605
#
# ------------
#
# uments
# arguments
# ▁arguments
#
# ------------
#
# eld
# field
# fields
# ield
# keepfields
# ▁field
# ▁fieldname
# ▁fields
#
# ------------
#
# pom
# ▁pom
# ▁poms
#
# ------------
#
# 419
# ▁14419
# ▁1441903874
#
# ------------
#
# kar
# ▁workaround
#
# ------------
#
# ugg
# ▁debugg
# ▁debugging
# ▁plugg
# ▁suggest
# ▁suggestion
#
# ------------
#
# xc
# alstateexception
# castexception
# channelexception
# dexception
# eexception
# exceeded
# exceeds
# exception
# exceptions
# ionexception
# otfoundexception
# pointerexception
# rgumentexception
# runtimeexception
# tfoundexception
# xception
# ▁exc
# ▁exce
# ▁exceed
# ▁exceeded
# ▁except
# ▁exception
# ▁exceptions
# ▁excer
# ▁exces
# ▁exclud
# ▁exclude
# ▁excludes
# ▁exclusi
# ▁ioexception
# ▁maxconnections
# ▁mojofailureexc
# ▁xc
# ▁xcontent
#
# ------------
#
# 169
# ▁169
#
# ------------
#
# ei
# ceive
# ceiver
# fileinputstream
# receive
# received
# receiver
# transceiver
# xei
# ▁createindex
# ▁ei
# ▁hei
# ▁morphlineid
# ▁morphlineids
# ▁recei
# ▁receiv
# ▁receive
# ▁received
# ▁receiver
# ▁reinstall
# ▁transceiver
# ▁wei
#
# ------------
#
# he
# ahead
# apache
# atcher
# atches
# ather
# authenticat
# authenticated
# authentication
# batches
# cache
# cached
# check
# checked
# checker
# checkpoint
# checkpointbackup
# checks
# checksum
# checksums
# cheduledexecutor
# cipher
# ether
# fetcher
# finishe
# head
# header
# headerkey
# headers
# hel
# hello
# help
# helper
# helpful
# hem
# hen
# her
# here
# hex
# kafkaheader
# matche
# other
# overhead
# phen
# pushe
# reached
# refreshe
# rther
# scheduled
# schem
# schema
# she
# shell
# sthead
# testbatchedreads
# the
# ther
# uncher
# watcher
# where
# withemptyfile
# ▁ackchecksum
# ▁addhead
# ▁apache
# ▁apachesolrsink
# ▁attached
# ▁authen
# ▁authenticate
# ▁authenticated
# ▁authentication
# ▁badcheckpoint
# ▁batches
# ▁cache
# ▁che
# ▁check
# ▁checkout
# ▁checkpoint
# ▁checks
# ▁checksum
# ▁checksumed
# ▁checksums
# ▁cipher
# ▁crashe
# ▁fetche
# ▁fileheader
# ▁finishe
# ▁flushe
# ▁gather
# ▁hashes
# ▁he
# ▁head
# ▁headache
# ▁header
# ▁headerkey
# ▁headername
# ▁headers
# ▁headervalue
# ▁headervalueon
# ▁health
# ▁healthy
# ▁heap
# ▁hear
# ▁heart
# ▁heartbeat
# ▁heav
# ▁heavy
# ▁hei
# ▁hel
# ▁hello
# ▁helloworld
# ▁help
# ▁helper
# ▁helpful
# ▁hen
# ▁hex
# ▁highe
# ▁idlefilechecker
# ▁inherent
# ▁inherit
# ▁kafkaheaders
# ▁launche
# ▁launcher
# ▁matche
# ▁orchestra
# ▁orchestrat
# ▁other
# ▁publishe
# ▁ratcheck
# ▁reache
# ▁reached
# ▁reschedule
# ▁sche
# ▁schedul
# ▁schedule
# ▁scheduled
# ▁scheduledfuture
# ▁scheduler
# ▁schem
# ▁schema
# ▁she
# ▁shel
# ▁shell
# ▁somewhere
# ▁squelched
# ▁testcheckpoint
# ▁the
# ▁there
# ▁together
# ▁unchecked
# ▁watcher
# ▁whe
# ▁where
#
# ------------
#
# rows
# ▁brows
# ▁browse
# ▁throws
#
# ------------
#
# voke
# invoke
# ▁invoke
# ▁invokemethod
#
# ------------
#
# ▁trusts
# ▁truststore
#
# ------------
#
# plement
# implement
# implementation
# ▁implement
# ▁implementation
#
# ------------
#
# ▁testno
# ▁testnode
#
# ------------
#
# groupi
# groupin
# ▁groupi
#
# ------------
#
# ress
# address
# addresses
# compress
# compressed
# compression
# compressor
# gress
# press
# ▁address
# ▁addresses
# ▁compress
# ▁compressed
# ▁compression
# ▁compressor
# ▁decompress
# ▁express
# ▁expression
# ▁expressions
# ▁press
# ▁regression
# ▁stress
# ▁stresssource
#
# ------------
#
# ▁licen
# ▁licens
# ▁license
# ▁licenses
#
# ------------
#
# ▁getn
# ▁getnext
#
# ------------
#
# wq
# wqf
#
# ------------
#
# cle
# cleanly
# cles
# etlifecyclestate
# lifecycle
# lifecycleaware
# lifecyclestate
# ▁clean
# ▁cleane
# ▁cleanly
# ▁cleanup
# ▁clear
# ▁cycle
# ▁lifecycle
# ▁lifecycles
# ▁testlifecycle
# ▁unclear
#
# ------------
#
# bd
# ▁subdirectories
#
# ------------
#
# mappings
# ▁mappings
#
# ------------
#
# idden
# hidden
#
# ------------
#
# try
# entry
# ntry
# retry
# ▁entry
# ▁retry
# ▁retryin
# ▁try
#
# ------------
#
# etw
# etwork
# network
# ▁bucketwriter
# ▁bucketwriters
# ▁network
# ▁retweet
#
# ------------
#
# tx
# txn
# txns
# ▁tx
# ▁txn
#
# ------------
#
# nders
# appenders
# ▁appenders
# ▁misunderstand
# ▁unders
# ▁understand
# ▁understandabl
#
# ------------
#
# mped
# stampedevent
# ▁timestamped
#
# ------------
#
# filereader
# ▁filereader
#
# ------------
#
# sses
# addresses
# asses
# classes
# ▁addresses
# ▁classes
#
# ------------
#
# ssage
# jmsmessage
# message
# messageconsumer
# remessage
# ▁abstractmessage
# ▁message
# ▁messages
# ▁readmessage
# ▁writemessage
#
# ------------
#
# efa
# default
# defaulthttp
# efact
# ▁defa
# ▁defaul
# ▁default
# ▁defaultartifact
# ▁defaultchannel
# ▁defaults
# ▁defaultsink
# ▁getdefault
# ▁getdefaultin
# ▁refactor
# ▁refactored
# ▁refactoring
# ▁setdefault
#
# ------------
#
# ▁df
# ▁dflu
# ▁dfo
# ▁dfs
# ▁dfsclient
#
# ------------
#
# person
# persona
# ▁person
#
# ------------
#
# ialization
# serialization
# ▁serialization
#
# ------------
#
# processors
# ▁processors
#
# ------------
#
# ▁don
# ▁done
#
# ------------
#
# rty
# property
# roperty
# ▁property
#
# ------------
#
# ▁ob
# ▁obfuscat
# ▁obfuscate
# ▁obj
# ▁object
# ▁objects
# ▁obs
# ▁observ
# ▁observe
# ▁obtain
# ▁obvious
#
# ------------
#
# 249
# ▁249
#
# ------------
#
# 438
# 1438
#
# ------------
#
# ▁reve
# ▁reverse
# ▁revert
#
# ------------
#
# 428
# 4288
# ▁428
# ▁42889
#
# ------------
#
# 269
# ▁269
#
# ------------
#
# ▁spo
# ▁spoo
# ▁spool
# ▁spooldir
# ▁spooldirectory
# ▁spooling
# ▁spoolingdir
# ▁spot
#
# ------------
#
# 540
# ▁540
# ▁5400
#
# ------------
#
# stage
# ▁staged
# ▁testagentsink
#
# ------------
#
# lpr
# lprocess
#
# ------------
#
# processing
# ▁processing
#
# ------------
#
# ▁men
# ▁mention
# ▁mentioned
#
# ------------
#
# tted
# formatted
# ▁preformatted
#
# ------------
#
# ▁rollin
# ▁rolling
# ▁rollingfile
# ▁rollingfilesink
#
# ------------
#
# ▁aa
# ▁aaa
#
# ------------
#
# ported
# ▁supported
# ▁unsupported
#
# ------------
#
# ▁fut
# ▁future
#
# ------------
#
# rim
# ▁experimenal
# ▁experiment
# ▁prim
# ▁primar
# ▁primary
# ▁trim
#
# ------------
#
# ▁had
# ▁hadoop
#
# ------------
#
# illa
# spillablememory
# ▁spillab
# ▁spillable
# ▁spillablememory
#
# ------------
#
# readpo
# dthreadpool
# duledthreadpool
# edthreadpool
# eduledthreadpool
# threadpool
# ▁threadpool
#
# ------------
#
# sted
# ested
# ▁exhausted
# ▁listed
# ▁tested
#
# ------------
#
# 115
# ▁115
# ▁115112
#
# ------------
#
# 311
# ▁12966311
#
# ------------
#
# cefile
# sequencefile
# ▁sequencefile
# ▁sequencefiles
#
# ------------
#
# aba
# database
# ▁database
#
# ------------
#
# jv
# jvm
# ▁jvm
#
# ------------
#
# mult
# multi
# multic
# multima
# multiple
# multiport
# multiportsyslog
# ▁mult
# ▁multi
# ▁multiconfig
# ▁multiline
# ▁multimaster
# ▁multiple
# ▁multiplex
# ▁multiplexing
# ▁multiport
# ▁multithread
# ▁testmulti
# ▁testmultip
#
# ------------
#
# ▁techn
# ▁techni
# ▁technical
#
# ------------
#
# yh
# ▁myhost
# ▁yh
#
# ------------
#
# nice
# ▁nice
#
# ------------
#
# lon
# lone
# long
# longbuffer
# ▁along
# ▁belong
# ▁clone
# ▁colon
# ▁long
#
# ------------
#
# ▁cate
# ▁categor
# ▁category
#
# ------------
#
# ▁jen
# ▁jenkins
#
# ------------
#
# pic
# pick
# topic
# ▁mytopic
# ▁pick
# ▁picture
# ▁topic
# ▁topics
# ▁typical
#
# ------------
#
# ifie
# ified
# ifier
# modifie
# notifie
# qualified
# specified
# unverified
# verifie
# verified
# ▁identifie
# ▁modifie
# ▁qualifier
# ▁qualifiers
# ▁specifie
# ▁specified
# ▁unified
# ▁verifie
#
# ------------
#
# yy
# ▁yyy
#
# ------------
#
# she
# finishe
# pushe
# refreshe
# shell
# ▁crashe
# ▁finishe
# ▁flushe
# ▁hashes
# ▁publishe
# ▁she
# ▁shel
# ▁shell
#
# ------------
#
# lob
# blob
# ▁blob
# ▁clobber
#
# ------------
#
# reason
# ▁reason
#
# ------------
#
# 216
# ▁216
# ▁21600
#
# ------------
#
# 254
# ▁254
#
# ------------
#
# ties
# ities
# properties
# ▁capabilties
# ▁capacities
# ▁properties
#
# ------------
#
# wan
# want
# ▁wan
# ▁want
#
# ------------
#
# reed
# ▁freed
#
# ------------
#
# ▁val
# ▁valid
# ▁validat
# ▁validate
# ▁validates
# ▁validati
# ▁valu
# ▁value
# ▁values
#
# ------------
#
# ton
# tono
# ▁informaiton
#
# ------------
#
# manag
# manage
# manager
# walmanager
# ▁manag
# ▁manage
# ▁manageable
# ▁manager
# ▁trustmanager
#
# ------------
#
# erson
# ersona
# person
# persona
# ▁person
#
# ------------
#
# checksums
# ▁checksums
#
# ------------
#
# ails
# details
# etails
# getobjectdetails
# tailsource
# ▁fails
# ▁tails
# ▁tailsource
#
# ------------
#
# 745
# ▁745
#
# ------------
#
# had
# hadoop
# ▁had
# ▁hadoop
# ▁shad
# ▁wraphadoopconf
#
# ------------
#
# _10
# _107376192
#
# ------------
#
# tely
# ately
# definitely
# ▁accurately
# ▁appropriately
# ▁indefinitely
#
# ------------
#
# 460
# 6460
#
# ------------
#
# ▁plu
# ▁plug
# ▁plugg
# ▁plugin
# ▁plugins
# ▁plus
#
# ------------
#
# ▁pas
# ▁pass
# ▁passe
# ▁passed
# ▁passw
# ▁password
# ▁past
# ▁paste
#
# ------------
#
# ob
# blob
# getobjectdetails
# job
# lob
# obal
# object
# objectde
# robin
# roundrobin
# ▁blob
# ▁clobber
# ▁cronjob
# ▁getobject
# ▁job
# ▁ob
# ▁obfuscat
# ▁obfuscate
# ▁obj
# ▁object
# ▁objects
# ▁obs
# ▁observ
# ▁observe
# ▁obtain
# ▁obvious
# ▁prob
# ▁proba
# ▁probab
# ▁probabl
# ▁problem
# ▁problems
# ▁protobuf
# ▁protobufrpc
# ▁rob
# ▁robin
# ▁robust
# ▁tob
#
# ------------
#
# roved
# proved
# ▁improved
#
# ------------
#
# 181
# 2181
# ▁181
#
# ------------
#
# 220
# ▁220
# ▁2209
#
# ------------
#
# 10737
# _107376192
#
# ------------
#
# 483
# ▁214748364
#
# ------------
#
# nab
# enabled
# nable
# ownable
# runnable
# ▁enabl
# ▁enable
# ▁enabled
# ▁runnable
#
# ------------
#
# ▁functionalit
# ▁functionality
#
# ------------
#
# defin
# define
# definitely
# redefine
# ▁defin
# ▁define
# ▁defines
# ▁definition
# ▁definitions
# ▁indefinite
# ▁indefinitely
#
# ------------
#
# factored
# ▁refactored
#
# ------------
#
# vl
# customizeservlet
# httpservlet
# servlet
# ▁httpservlet
# ▁servlet
# ▁servleth
# ▁servlets
#
# ------------
#
# 141
# 14120
# ▁141
# ▁1417521
# ▁4141
#
# ------------
#
# ▁liv
# ▁live
#
# ------------
#
# 564
# ▁162319564
# ▁6564613
#
# ------------
#
# ▁mat
# ▁match
# ▁matche
# ▁materials
#
# ------------
#
# elf
# channelfactory
#
# ------------
#
# tpath
# bucketpath
# ▁bucketpath
#
# ------------
#
# nn
# ablesourcerunner
# annot
# cassandrachannel
# channel
# channelexception
# channelfactory
# channelhandler
# channels
# channelselector
# conn
# connect
# connected
# connection
# connector
# dconn
# echannel
# filechannel
# incrementchannel
# jdbcchannel
# lememorychannel
# lingsourcerunner
# memorychannel
# nner
# nnot
# runnable
# runner
# running
# socketchannel
# sourcerunner
# ▁annotate
# ▁annotation
# ▁annotations
# ▁announce
# ▁annoy
# ▁beginn
# ▁cann
# ▁channel
# ▁channelname
# ▁channels
# ▁channelselector
# ▁closedchannel
# ▁conn
# ▁conne
# ▁connect
# ▁connection
# ▁connections
# ▁connectivity
# ▁connector
# ▁connectto
# ▁defaultchannel
# ▁disconnect
# ▁disconnected
# ▁filechann
# ▁filechannel
# ▁getchannel
# ▁inner
# ▁innerrun
# ▁maxconnections
# ▁memorychannel
# ▁mychannel
# ▁newconnection
# ▁onno
# ▁openconnection
# ▁plann
# ▁reconnect
# ▁reqchannel
# ▁runn
# ▁runnable
# ▁runner
# ▁running
# ▁scann
# ▁simplechannel
# ▁sinkrunner
# ▁socketchannel
# ▁sourcerunner
# ▁testfilechannel
# ▁unnecessa
# ▁unnecessar
#
# ------------
#
# forms
# ▁platforms
#
# ------------
#
# ope
# developerguide
# invalidoperation
# oopen
# open
# openfile
# operation
# operator
# proper
# properties
# property
# rope
# roperty
# ▁develope
# ▁developer
# ▁developerguide
# ▁hope
# ▁improper
# ▁insistentopen
# ▁lazyopen
# ▁maxopenfile
# ▁open
# ▁openconnection
# ▁opened
# ▁opens
# ▁operat
# ▁operate
# ▁operation
# ▁operations
# ▁operator
# ▁proper
# ▁properly
# ▁properties
# ▁property
# ▁reopen
# ▁scope
#
# ------------
#
# ▁hun
# ▁hundred
#
# ------------
#
# ▁impli
# ▁implication
# ▁implicit
# ▁implie
#
# ------------
#
# complet
# complete
# incomplete
# ncomplet
# ▁complet
# ▁complete
# ▁incomplete
#
# ------------
#
# ows
# rows
# windows
# ▁brows
# ▁browse
# ▁throws
# ▁windows
#
# ------------
#
# lew
# testnaivefilewal
# ▁naivefilewal
#
# ------------
#
# ▁nee
# ▁need
# ▁needed
#
# ------------
#
# efore
# before
# ▁before
#
# ------------
#
# plete
# complete
# incomplete
# ▁complete
# ▁incomplete
#
# ------------
#
# 335
# ▁3335
# ▁335
#
# ------------
#
# mc
# ▁mc
# ▁rmc
# ▁tomcat
#
# ------------
#
# ▁supervis
# ▁supervise
# ▁supervising
# ▁supervisor
#
# ------------
#
# ference
# reference
# ▁difference
# ▁reference
#
# ------------
#
# adoc
# javadoc
# ▁javadoc
#
# ------------
#
# starte
# ▁restarted
# ▁started
#
# ------------
#
# pancy
# ▁discrepancy
#
# ------------
#
# ▁gre
# ▁great
#
# ------------
#
# 151
# 1517
# 1518
# 5151
# ▁115112
# ▁151
# ▁15122
# ▁151384320283
#
# ------------
#
# pender
# appender
# appenders
# jappender
# ▁appender
# ▁appenders
#
# ------------
#
# ai
# again
# aid
# aik
# ail
# ailing
# ails
# aily
# ain
# ains
# avail
# availability
# available
# chain
# claime
# container
# details
# dfochain
# drain
# echain
# etails
# fail
# failchain
# failed
# failover
# failoversink
# failure
# failures
# fair
# getobjectdetails
# ionfailed
# mail
# main
# maintain
# pair
# rainattemptcount
# remaining
# siccommitfailure
# tail
# taildir
# tailfile
# tailsource
# tain
# testdiskfailover
# testnaivefilewal
# wait
# waiting
# ▁abortremain
# ▁addtail
# ▁agentfai
# ▁avail
# ▁available
# ▁await
# ▁certain
# ▁chain
# ▁chaindeco
# ▁chains
# ▁complain
# ▁contain
# ▁containe
# ▁container
# ▁contains
# ▁daily
# ▁detail
# ▁diskfailover
# ▁drain
# ▁drainorder
# ▁email
# ▁eventdrain
# ▁explain
# ▁fail
# ▁failed
# ▁failing
# ▁failover
# ▁failovers
# ▁fails
# ▁failure
# ▁failures
# ▁fair
# ▁informaiton
# ▁mail
# ▁mailbox
# ▁mailboxes
# ▁main
# ▁maintain
# ▁maintainer
# ▁mojofailureexc
# ▁nai
# ▁naive
# ▁naivefile
# ▁naivefilewal
# ▁obtain
# ▁pain
# ▁pair
# ▁plain
# ▁plaintext
# ▁rais
# ▁raise
# ▁remain
# ▁remaining
# ▁straight
# ▁tai
# ▁tail
# ▁taildir
# ▁taildirsource
# ▁tailfile
# ▁tails
# ▁tailsource
# ▁unavailability
# ▁unavailable
# ▁wait
# ▁waitfor
#
# ------------
#
# ention
# mentioned
# rentention
# retention
# tention
# ▁convention
# ▁intention
# ▁mention
# ▁mentioned
# ▁retention
#
# ------------
#
# 178
# 2178
# ▁178
#
# ------------
#
# ▁director
# ▁directories
# ▁directory
#
# ------------
#
# ety
# ▁filetype
# ▁safety
# ▁sometyp
# ▁sourcetype
#
# ------------
#
# servers
# serversocket
# ▁nioserversocket
# ▁servers
# ▁serversocket
#
# ------------
#
# gist
# register
# ▁regist
# ▁register
# ▁registr
# ▁unregister
#
# ------------
#
# ▁alo
# ▁along
#
# ------------
#
# econfiguration
# ileconfiguration
# ▁reconfiguration
#
# ------------
#
# 3857
# ▁12258542385799
# ▁122585423857995
#
# ------------
#
# cef
# cefile
# sequencefile
# ▁graceful
# ▁gracefully
# ▁sequencefile
# ▁sequencefiles
#
# ------------
#
# 461
# 0461
# 6461
# 858461891_436734
# ▁6564613
#
# ------------
#
# eal
# ▁deal
# ▁health
# ▁healthy
# ▁ideal
# ▁real
# ▁realize
# ▁realm
# ▁steal
#
# ------------
#
# lic
# application
# blockreplica
# cliclient
# duplicate
# licit
# olici
# policy
# replica
# replication
# underreplicat
# underreplication
# ▁applicable
# ▁application
# ▁applications
# ▁avroclicilent
# ▁avrocliclient
# ▁click
# ▁clickhouse
# ▁clickhousesink
# ▁complicate
# ▁conflict
# ▁conflicts
# ▁cyclic
# ▁duplicat
# ▁duplicate
# ▁duplicates
# ▁duplication
# ▁explicit
# ▁implication
# ▁implicit
# ▁licen
# ▁licens
# ▁license
# ▁licenses
# ▁polic
# ▁policy
# ▁public
# ▁publications
# ▁replica
# ▁replicat
# ▁replicate
# ▁replicating
# ▁webapplication
#
# ------------
#
# ice
# ervice
# nice
# service
# vice
# ▁advice
# ▁choice
# ▁device
# ▁licen
# ▁licens
# ▁license
# ▁licenses
# ▁nice
# ▁notice
# ▁practice
# ▁service
#
# ------------
#
# versioninfo
# ▁testversioninfo
#
# ------------
#
# espec
# ▁flumespec
# ▁respect
# ▁respected
# ▁respective
#
# ------------
#
# ncing
# loadbalancing
# ▁balancing
# ▁loadbalancing
# ▁rebalancing
#
# ------------
#
# eda
# deda
# edaf
# embeddedagent
# flumedata
# ▁embeddedagent
# ▁flumedata
# ▁sampledata
#
# ------------
#
# rough
# hroughputcounter
# through
# throughput
# ▁brough
# ▁through
# ▁throughput
#
# ------------
#
# cker
# checker
# tracker
# ▁hacker
# ▁idlefilechecker
# ▁tracker
#
# ------------
#
# atcher
# watcher
# ▁watcher
#
# ------------
#
# ▁bea
# ▁bean
# ▁beat
#
# ------------
#
# nstruction
# ▁instruction
# ▁instructions
#
# ------------
#
# ▁cent
# ▁center
# ▁centos
# ▁central
# ▁centralize
#
# ------------
#
# 173
# 9173
# ▁173
#
# ------------
#
# giv
# ▁giv
# ▁give
# ▁given
#
# ------------
#
# 752
# ▁1417521
#
# ------------
#
# tal
# atal
# catalog
# install
# tall
# totalevent
# ▁accidental
# ▁capital
# ▁catalog
# ▁fundamental
# ▁incremental
# ▁install
# ▁installation
# ▁installed
# ▁installer
# ▁reinstall
# ▁stale
# ▁talk
# ▁total
# ▁totalevent
# ▁totalwrite
#
# ------------
#
# ▁sor
# ▁sort
# ▁sorted
#
# ------------
#
# ica
# application
# atically
# authenticat
# authenticated
# authentication
# blockreplica
# duplicate
# enticate
# erica
# fication
# ical
# ically
# icate
# ication
# ification
# logical
# logicalnode
# logicalnodes
# matically
# modification
# peercertificate
# replica
# replication
# underreplicat
# underreplication
# ▁applicable
# ▁application
# ▁applications
# ▁authenticate
# ▁authenticated
# ▁authentication
# ▁automatically
# ▁certificate
# ▁certificates
# ▁communicat
# ▁communication
# ▁complicate
# ▁duplicat
# ▁duplicate
# ▁duplicates
# ▁duplication
# ▁getlogicalnode
# ▁implication
# ▁indicat
# ▁indicate
# ▁indicati
# ▁indicator
# ▁logical
# ▁logicalnode
# ▁logicalsource
# ▁modification
# ▁notification
# ▁physical
# ▁physicalnode
# ▁publications
# ▁replica
# ▁replicat
# ▁replicate
# ▁replicating
# ▁significant
# ▁specification
# ▁technical
# ▁typical
# ▁verification
# ▁webapplication
#
# ------------
#
# ▁too
# ▁tool
#
# ------------
#
# lets
# ▁servlets
#
# ------------
#
# restarts
# ▁restarts
#
# ------------
#
# spi
# spillablememory
# ▁spi
# ▁spike
# ▁spill
# ▁spillab
# ▁spillable
# ▁spillablememory
# ▁spin
#
# ------------
#
# 294
# ▁294
#
# ------------
#
# als
# also
# alstateexception
# equals
# false
# ▁false
# ▁illegalstate
# ▁locals
# ▁logicalsource
# ▁materials
# ▁wals
# ▁walsource
#
# ------------
#
# ▁httpso
# ▁httpsource
#
# ------------
#
# placement
# ▁replacement
#
# ------------
#
# cks
# acks
# checks
# checksum
# checksums
# ▁ackchecksum
# ▁blocks
# ▁callbacks
# ▁checks
# ▁checksum
# ▁checksumed
# ▁checksums
# ▁locks
# ▁rollbacks
#
# ------------
#
# nnot
# annot
# ▁annotate
# ▁annotation
# ▁annotations
#
# ------------
#
# agentsink
# ▁testagentsink
#
# ------------
#
# loads
# downloads
# ▁loads
# ▁loadsolr
#
# ------------
#
# jon
# ▁jon
# ▁jona
#
# ------------
#
# kf
# sinkfactory
# testdiskfailover
# ▁diskfailover
# ▁kakfa
# ▁workflow
#
# ------------
#
# 184
# 1840
# ▁184
#
# ------------
#
# 953
# ▁12953732
#
# ------------
#
# ▁wit
# ▁with
#
# ------------
#
# yb
# ybe
#
# ------------
#
# 264
# ▁264
#
# ------------
#
# angel
# ▁changelog
#
# ------------
#
# 352
# 1352
# ▁13036352
# ▁352
#
# ------------
#
# ors
# ators
# collectors
# collectorsink
# collectorsource
# constructors
# executors
# interceptors
# orserv
# processors
# ▁autocollectors
# ▁behaviors
# ▁collectors
# ▁collectorsink
# ▁decorators
# ▁descriptors
# ▁errors
# ▁executors
# ▁interceptors
# ▁monitors
# ▁processors
#
# ------------
#
# ▁tran
# ▁trans
# ▁transaction
# ▁transactions
# ▁transceiver
# ▁transfer
# ▁transferr
# ▁transform
# ▁transformation
# ▁transition
# ▁transitive
# ▁translate
# ▁translated
# ▁translating
# ▁translation
# ▁transmit
# ▁transparent
# ▁transparently
# ▁transport
# ▁transportclient
# ▁transports
#
# ------------
#
# 571
# 9571
#
# ------------
#
# rg
# args
# argument
# arguments
# developerguide
# ergroup
# large
# org
# organ
# rge
# rgumentexception
# target
# ▁arg
# ▁args
# ▁argu
# ▁arguabl
# ▁argument
# ▁arguments
# ▁developerguide
# ▁flumeuserguide
# ▁kwarg
# ▁kwargs
# ▁large
# ▁merge
# ▁merged
# ▁organiz
# ▁organize
# ▁purge
# ▁target
# ▁userguide
#
# ------------
#
# arn
# harness
# warn
# ▁barnode
# ▁harness
# ▁warn
# ▁warning
#
# ------------
#
# olde
# folder
# older
# ▁folder
#
# ------------
#
# formed
# malformed
# ▁malformed
#
# ------------
#
# ▁ill
# ▁illegal
# ▁illegalstate
#
# ------------
#
# xb
# ▁maxbackoff
# ▁maxbatch
#
# ------------
#
# ▁synta
# ▁syntax
#
# ------------
#
# ▁unsu
# ▁unsupported
#
# ------------
#
# ▁poli
# ▁polic
# ▁policy
#
# ------------
#
# dap
# adapt
# adapter
# ▁adapt
#
# ------------
#
# ▁dea
# ▁dead
# ▁deadlock
# ▁deal
#
# ------------
#
# rify
# verify
# ▁verify
#
# ------------
#
# download
# downloads
# ▁download
#
# ------------
#
# ▁overwrit
# ▁overwrite
#
# ------------
#
# 663
# ▁12966308
# ▁12966311
# ▁12966312
#
# ------------
#
# ych
# lememorychannel
# memorychannel
# ▁memorychannel
# ▁mychannel
#
# ------------
#
# aste
# castexception
# master
# ▁faster
# ▁flumemaster
# ▁master
# ▁masters
# ▁multimaster
# ▁paste
# ▁testmaster
#
# ------------
#
# 452
# ▁452
#
# ------------
#
# oop
# hadoop
# loop
# oopen
# ▁hadoop
# ▁loop
# ▁noop
# ▁wraphadoopconf
#
# ------------
#
# ▁tho
# ▁thou
# ▁though
# ▁thought
#
# ------------
#
# ctic
# actic
# ▁practic
# ▁practice
#
# ------------
#
# ▁requ
# ▁request
# ▁requi
# ▁requir
# ▁require
# ▁required
# ▁requirement
#
# ------------
#
# ▁filed
# ▁filedelete
#
# ------------
#
# tracthdfswriter
# stracthdfswriter
#
# ------------
#
# ened
# ▁opened
#
# ------------
#
# ▁193
# ▁1938
#
# ------------
#
# rby
# erby
# readbufferbytes
#
# ------------
#
# cell
# ▁cancell
# ▁cancellation
# ▁miscellan
#
# ------------
#
# ▁tha
# ▁thank
#
# ------------
#
# pre
# compress
# compressed
# compression
# compressor
# fersizepredictor
# mapreduce
# precise
# preconditions
# prefix
# present
# presentation
# press
# sizepredictor
# ▁appreciate
# ▁compre
# ▁compress
# ▁compressed
# ▁compression
# ▁compressor
# ▁decompress
# ▁deprec
# ▁deprecat
# ▁deprecate
# ▁deprecation
# ▁express
# ▁expression
# ▁expressions
# ▁interpret
# ▁mapred
# ▁mapreduce
# ▁pre
# ▁precise
# ▁precompile
# ▁precompiled
# ▁precondition
# ▁prefer
# ▁preferabl
# ▁prefix
# ▁prefixe
# ▁preform
# ▁preformatted
# ▁prepar
# ▁prepare
# ▁prepares
# ▁prepende
# ▁presen
# ▁presenc
# ▁present
# ▁preserv
# ▁preserve
# ▁press
# ▁prev
# ▁prevent
# ▁previous
# ▁represent
# ▁spread
#
# ------------
#
# executors
# ▁executors
#
# ------------
#
# commands
# ▁commands
#
# ------------
#
# ▁defi
# ▁defin
# ▁define
# ▁defines
# ▁definition
# ▁definitions
#
# ------------
#
# 6461
# ▁6564613
#
# ------------
#
# ▁shel
# ▁shell
#
# ------------
#
# ▁reproduc
# ▁reproduce
#
# ------------
#
# ves
# vestig
# ▁investigat
# ▁investigate
# ▁investigati
#
# ------------
#
# ounds
# outofbounds
#
# ------------
#
# 0002
# 00002
# ▁0000002
#
# ------------
#
# ▁sud
# ▁sudden
#
# ------------
#
# sci
# ▁ascii
# ▁discipline
#
# ------------
#
# fication
# ification
# modification
# ▁modification
# ▁notification
# ▁specification
# ▁verification
#
# ------------
#
# kerb
# kerberos
# ▁kerberiz
# ▁kerberos
#
# ------------
#
# ▁containe
# ▁container
#
# ------------
#
# objectde
# getobjectdetails
#
# ------------
#
# 486
# 4862
#
# ------------
#
# eof
# ▁eof
#
# ------------
#
# ass
# asses
# cassandra
# cassandrachannel
# class
# classes
# classloader
# classpath
# keystorepassword
# lass
# lassi
# pass
# password
# storepass
# ▁ass
# ▁assembl
# ▁assert
# ▁assertion
# ▁assertions
# ▁assertno
# ▁assign
# ▁assum
# ▁assume
# ▁cassandra
# ▁class
# ▁classes
# ▁classloader
# ▁classnotfound
# ▁classpath
# ▁classpaths
# ▁keypass
# ▁mass
# ▁noclassdef
# ▁pass
# ▁passe
# ▁passed
# ▁passw
# ▁password
#
# ------------
#
# oad
# classloader
# download
# downloads
# load
# loadbalance
# loadbalancing
# loader
# loads
# oader
# ▁broad
# ▁classloader
# ▁download
# ▁load
# ▁loadbalancers
# ▁loadbalancing
# ▁loadconfig
# ▁loading
# ▁loads
# ▁loadsolr
# ▁payload
# ▁reload
# ▁upload
#
# ------------
#
# ites
# ▁writes
#
# ------------
#
# hor
# authoriz
# hort
# short
# ▁author
# ▁authoring
# ▁authorization
# ▁semaphore
# ▁short
#
# ------------
#
# ground
# background
# ▁background
#
# ------------
#
# perate
# ▁operate
#
# ------------
#
# aily
# ▁daily
#
# ------------
#
# tm
# directmemory
# getmatchingfiles
# html
# testmini
# tmp
# ▁abstractmessage
# ▁atm
# ▁getmap
# ▁htm
# ▁html
# ▁rabbitmq
# ▁startmini
# ▁testmaster
# ▁testmini
# ▁testmulti
# ▁testmultip
# ▁tm
# ▁tmp
# ▁trustmanager
#
# ------------
#
# onfigure
# configure
# configured
# ▁configure
# ▁configured
# ▁configurehost
# ▁methodconfigure
# ▁misconfigured
# ▁reconfigure
# ▁reconfigured
#
# ------------
#
# nding
# ending
# extending
# ▁binding
# ▁corresponding
# ▁finding
# ▁rounding
#
# ------------
#
# yp
# encryption
# type
# ▁clienttype
# ▁crypto
# ▁cryptographic
# ▁encrypt
# ▁encryption
# ▁encryptionkey
# ▁enryption
# ▁filetype
# ▁keypass
# ▁sometyp
# ▁sourcetype
# ▁typ
# ▁type
# ▁types
# ▁typical
# ▁typo
# ▁typos
#
# ------------
#
# lder
# builder
# contentbuilder
# ebuilder
# folder
# indexnamebuilder
# older
# ▁builder
# ▁folder
#
# ------------
#
# rel
# relate
# release
# reliable
# ▁rel
# ▁rela
# ▁relat
# ▁relate
# ▁relative
# ▁rele
# ▁release
# ▁releases
# ▁reli
# ▁relia
# ▁reliab
# ▁reliabl
# ▁reliable
# ▁reload
# ▁rely
#
# ------------
#
# ▁recon
# ▁reconfig
# ▁reconfigur
# ▁reconfiguration
# ▁reconfigure
# ▁reconfigured
# ▁reconfiguring
# ▁reconnect
#
# ------------
#
# oss
# across
# boss
# cross
# gossip
# loss
# ossible
# possible
# ross
# ▁boss
# ▁gossip
# ▁loss
# ▁possib
# ▁possibl
# ▁possible
#
# ------------
#
# ▁hands
# ▁handshake
#
# ------------
#
# vin
# ving
# ▁saving
#
# ------------
#
# sol
# absolute
# console
# orphlinesolrsink
# resolved
# resolver
# solr
# solution
# solved
# ▁absolute
# ▁apachesolrsink
# ▁console
# ▁consolidat
# ▁isolat
# ▁isolate
# ▁loadsolr
# ▁morphlinesolr
# ▁resolv
# ▁resolve
# ▁resolveartifact
# ▁sol
# ▁solace
# ▁solacevpn
# ▁solid
# ▁solr
# ▁solution
# ▁solv
# ▁solve
# ▁unresolved
#
# ------------
#
# tle
# stle
# testthriftlegacy
# throttle
# title
# ttle
# ▁getlease
# ▁thriftlegacy
# ▁throttle
# ▁title
#
# ------------
#
# 574
# 5744
#
# ------------
#
# rl
# arl
# irl
# rly
# url
# world
# worlds
# ▁curl
# ▁earl
# ▁helloworld
# ▁overl
# ▁properly
# ▁providerurl
# ▁recoverlease
# ▁underl
# ▁url
#
# ------------
#
# nted
# documented
# ▁documented
#
# ------------
#
# 490
# 4909
# ▁149088
# ▁149088718531
# ▁490
#
# ------------
#
# lgo
# algorithm
# ▁algorithm
#
# ------------
#
# ▁ic
# ▁icon
#
# ------------
#
# ▁nam
# ▁name
# ▁nameno
# ▁namenode
# ▁names
# ▁namespace
# ▁naming
#
# ------------
#
# 521
# 5212
# ▁1417521
#
# ------------
#
# ctor
# actor
# channelfactory
# channelselector
# clientfactory
# collector
# collectors
# collectorsink
# collectorsource
# connector
# constructor
# constructors
# director
# directory
# directorysource
# ector
# ectorysource
# emptydirectory
# erfactory
# extractor
# factor
# factored
# factory
# fersizepredictor
# ldirectorysource
# lector
# loggerfactory
# orderselector
# poolingdirectory
# rfactory
# rpcclientfactory
# selector
# sinkfactory
# sizepredictor
# threadfactory
# ▁autocollector
# ▁autocollectors
# ▁channelselector
# ▁collector
# ▁collectors
# ▁collectorsink
# ▁connector
# ▁constructor
# ▁director
# ▁directories
# ▁directory
# ▁epollselector
# ▁extractor
# ▁factor
# ▁getconstructor
# ▁loggerfactory
# ▁orderselector
# ▁refactor
# ▁refactored
# ▁refactoring
# ▁regexextractor
# ▁selector
# ▁spooldirectory
# ▁subdirectories
# ▁threadfactory
#
# ------------
#
# ▁wil
# ▁wildcard
#
# ------------
#
# tie
# ities
# properties
# tier
# ties
# ▁capabilties
# ▁capacities
# ▁properties
# ▁tie
# ▁tier
#
# ------------
#
# ources
# sources
# ▁sources
#
# ------------
#
# sock
# serversocket
# socket
# socketchannel
# ssocket
# ▁nioclientsocket
# ▁nioserversocket
# ▁serversocket
# ▁sock
# ▁socket
# ▁socketchannel
# ▁sockets
# ▁socketse
# ▁websocket
#
# ------------
#
# nally
# ▁internally
# ▁unconditionally
#
# ------------
#
# figured
# configured
# ▁configured
# ▁misconfigured
# ▁reconfigured
#
# ------------
#
# ▁news
# ▁newsinglethread
#
# ------------
#
# ▁colli
# ▁collision
#
# ------------
#
# ece
# necessary
# receive
# received
# receiver
# ▁execeventsource
# ▁necessar
# ▁necessary
# ▁necessit
# ▁piece
# ▁recei
# ▁receiv
# ▁receive
# ▁received
# ▁receiver
# ▁recent
# ▁unnecessa
# ▁unnecessar
#
# ------------
#
# uz
# uzl
# uzz
# ▁tuzla
#
# ------------
#
# ▁00000
# ▁000000
# ▁0000001
# ▁0000002
# ▁000001
#
# ------------
#
# ▁vo
# ▁vol
# ▁volu
# ▁vote
#
# ------------
#
# eexception
# alstateexception
# runtimeexception
#
# ------------
#
# ▁unk
# ▁unknown
#
# ------------
#
# ▁filech
# ▁filechann
# ▁filechannel
#
# ------------
#
# ▁deci
# ▁decide
# ▁decision
#
# ------------
#
# ▁rebalanc
# ▁rebalancing
#
# ------------
#
# ultima
# multima
# ▁multimaster
#
# ------------
#
# reated
# created
# ▁created
#
# ------------
#
# estin
# destination
# testinflight
# testing
# testingutility
# ▁destination
# ▁testin
# ▁testinflight
# ▁testing
#
# ------------
#
# ▁consu
# ▁consum
# ▁consume
# ▁consumed
# ▁consumer
# ▁consumeranditer
# ▁consumers
#
# ------------
#
# ▁safet
# ▁safety
#
# ------------
#
# ▁ce
# ▁cent
# ▁center
# ▁centos
# ▁central
# ▁centralize
# ▁cert
# ▁certain
# ▁certifi
# ▁certificate
# ▁certificates
#
# ------------
#
# 234
# 1234567890123
# 901234567890123
# ▁1234
# ▁12345
# ▁123456
#
# ------------
#
# nch
# asynchbase
# asynchbasesink
# benchmark
# synchronizer
# unch
# uncher
# ynch
# ynchronizer
# ▁asynch
# ▁asynchbase
# ▁asynchbasesink
# ▁asynchronous
# ▁benchmark
# ▁branch
# ▁launch
# ▁launche
# ▁launcher
# ▁runchild
# ▁synchroni
# ▁synchronization
# ▁synchronized
# ▁synchronous
# ▁unchecked
#
# ------------
#
# hs
# batchsize
# earchsink
# ghs
# hsi
# lasticsearchsink
# ▁batchsize
# ▁classpaths
# ▁graphs
# ▁hs
# ▁hsync
# ▁paths
#
# ------------
#
# 757
# 1757
# 3757
#
# ------------
#
# cif
# cific
# specified
# ▁specifi
# ▁specific
# ▁specification
# ▁specifie
# ▁specified
# ▁specify
#
# ------------
#
# cet
# tcpsourcethreads
# ▁confluencet
# ▁sourcetype
#
# ------------
#
# sting
# existing
# testing
# testingutility
# ▁distinguish
# ▁existing
# ▁testing
#
# ------------
#
# ▁webp
# ▁webpage
#
# ------------
#
# ud
# cloud
# syslogudpsource
# udp
# udpsource
# yslogudpsource
# ▁audi
# ▁cloud
# ▁exclud
# ▁exclude
# ▁excludes
# ▁includ
# ▁include
# ▁judge
# ▁pseudo
# ▁sud
# ▁sudden
# ▁syslogudp
# ▁syslogudpsource
#
# ------------
#
# fluen
# ▁confluen
# ▁confluence
# ▁confluencet
#
# ------------
#
# 579
# ▁12258542385799
# ▁122585423857995
#
# ------------
#
# 658
# ▁658
#
# ------------
#
# 652
# 8652
#
# ------------
#
# ▁own
# ▁owne
# ▁owner
#
# ------------
#
# ani
# ▁compani
# ▁daniel
# ▁faninsource
# ▁juhani
# ▁mani
# ▁manifest
# ▁meaning
# ▁mechanics
# ▁mechanism
# ▁mechanisms
# ▁organiz
# ▁organize
# ▁sanit
# ▁sanitize
#
# ------------
#
# iling
# ailing
# ▁failing
#
# ------------
#
# ontent
# content
# contentbuilder
# ▁content
# ▁contents
# ▁contentsas
# ▁contentsasd
# ▁xcontent
#
# ------------
#
# tri
# attribute
# metrics
# restrict
# roundtrip
# string
# tring
# trips
# triv
# ttri
# ▁attribute
# ▁attributes
# ▁contrib
# ▁contribut
# ▁contribute
# ▁contributor
# ▁distribut
# ▁distribute
# ▁distributed
# ▁distribution
# ▁metric
# ▁metrics
# ▁parametriz
# ▁parametrizable
# ▁restrict
# ▁retrie
# ▁retrieve
# ▁roundtrips
# ▁sizetrigger
# ▁stri
# ▁strict
# ▁string
# ▁tri
# ▁trick
# ▁trie
# ▁trigger
# ▁trim
#
# ------------
#
# tring
# string
# ▁string
#
# ------------
#
# etwork
# network
# ▁network
#
# ------------
#
# onfiguration
# configuration
# configurations
# econfiguration
# ileconfiguration
# misconfiguration
# ▁configuration
# ▁configurations
# ▁reconfiguration
#
# ------------
#
# ▁fre
# ▁free
# ▁freebsd
# ▁freed
# ▁frenzy
# ▁frequen
# ▁frequent
# ▁frequently
#
# ------------
#
# socketchannel
# ▁socketchannel
#
# ------------
#
# ▁balanc
# ▁balance
# ▁balancing
#
# ------------
#
# ully
# fully
# ▁fully
# ▁gracefully
#
# ------------
#
# xed
# fixed
# ixed
#
# ------------
#
# bles
# ablesourcerunner
# pollablesource
# tables
# ▁disables
# ▁pollablesource
#
# ------------
#
# ▁runn
# ▁runnable
# ▁runner
# ▁running
#
# ------------
#
# rge
# large
# target
# ▁large
# ▁merge
# ▁merged
# ▁purge
# ▁target
#
# ------------
#
# 957
# 9571
# 95780
#
# ------------
#
# ▁creati
# ▁creation
#
# ------------
#
# ici
# ffici
# licit
# olici
# sufficient
# ▁atomicincrement
# ▁atomicity
# ▁avroclicilent
# ▁efficien
# ▁efficient
# ▁explicit
# ▁implicit
# ▁inefficient
# ▁insufficient
# ▁sufficient
#
# ------------
#
# ▁gr
# ▁grab
# ▁grace
# ▁graceful
# ▁gracefully
# ▁gran
# ▁granular
# ▁graph
# ▁graphs
# ▁gre
# ▁great
# ▁grok
# ▁group
# ▁groupi
# ▁groups
# ▁grow
#
# ------------
#
# ▁capab
# ▁capabilties
#
# ------------
#
# ▁depe
# ▁depend
# ▁depende
# ▁dependen
# ▁dependencies
# ▁dependency
#
# ------------
#
# dency
# dependency
# ▁dependency
#
# ------------
#
# ▁rf
# ▁rfc
#
# ------------
#
# lot
# ▁lot
#
# ------------
#
# endof
# ▁isendof
#
# ------------
#
# ▁not
# ▁notabl
# ▁note
# ▁notes
# ▁nothing
# ▁notic
# ▁notice
# ▁notifi
# ▁notification
#
# ------------
#
# ▁mig
# ▁migrat
# ▁migrate
# ▁migrati
#
# ------------
#
# 60000
# ▁60000
# ▁600000
#
# ------------
#
# park
# spark
# ▁park
#
# ------------
#
# 112
# 1123
# 1126
# 2112
# _2112
# ▁112
# ▁115112
#
# ------------
#
# 309
# 3096
# ▁309
#
# ------------
#
# orr
# correctly
# corresponds
# corrupt
# corruptinflight
# incorrect
# ▁corr
# ▁corre
# ▁correct
# ▁correction
# ▁corrections
# ▁correctly
# ▁correctness
# ▁correspond
# ▁corresponding
# ▁corrupt
# ▁corrupte
# ▁corruption
# ▁incorrect
# ▁incorrectly
#
# ------------
#
# 274
# ▁13022749
#
# ------------
#
# ▁intr
# ▁introduc
# ▁introduce
#
# ------------
#
# maintain
# ▁maintain
# ▁maintainer
#
# ------------
#
# ▁gs
# ▁gss
# ▁gssk
#
# ------------
#
# verifi
# unverified
# verifie
# verified
# ▁verification
# ▁verifie
#
# ------------
#
# 036
# ▁13036350
# ▁13036351
# ▁13036352
#
# ------------
#
# world
# worlds
# ▁helloworld
#
# ------------
#
# relate
# ▁relate
#
# ------------
#
# estart
# restart
# restarts
# ▁restart
# ▁restarted
# ▁restartfromend
# ▁restartin
# ▁restarts
#
# ------------
#
# ▁ty
# ▁typ
# ▁type
# ▁types
# ▁typical
# ▁typo
# ▁typos
#
# ------------
#
# ving
# ▁saving
#
# ------------
#
# con
# conc
# concurrent
# concurrentdfoman
# conf
# confi
# config
# configstore
# configu
# configur
# configura
# configurat
# configuration
# configurations
# configure
# configured
# configuring
# confirm
# conn
# connect
# connected
# connection
# connector
# cons
# console
# constants
# construct
# constructor
# constructors
# consume
# consumer
# consumerand
# consumeranditer
# container
# content
# contentbuilder
# context
# continue
# controll
# controlle
# conver
# convert
# dconn
# econds
# econfiguration
# ileconfiguration
# initialcontext
# messageconsumer
# misconfiguration
# pcon
# pperconfigstore
# preconditions
# seconds
# zookeeperconfig
# ▁con
# ▁conc
# ▁concatenat
# ▁concern
# ▁concurren
# ▁concurrent
# ▁condition
# ▁conditions
# ▁conf
# ▁config
# ▁configs
# ▁configu
# ▁configur
# ▁configura
# ▁configurable
# ▁configurat
# ▁configuration
# ▁configurations
# ▁configure
# ▁configured
# ▁configurehost
# ▁confirm
# ▁conflict
# ▁conflicts
# ▁confluen
# ▁confluence
# ▁confluencet
# ▁confus
# ▁confuse
# ▁confused
# ▁conn
# ▁conne
# ▁connect
# ▁connection
# ▁connections
# ▁connectivity
# ▁connector
# ▁connectto
# ▁cons
# ▁consecutive
# ▁consequen
# ▁consequence
# ▁consider
# ▁considerabl
# ▁consideration
# ▁consist
# ▁consisten
# ▁consistent
# ▁consistently
# ▁console
# ▁consolidat
# ▁constant
# ▁constants
# ▁constr
# ▁constru
# ▁construct
# ▁constructor
# ▁consu
# ▁consum
# ▁consume
# ▁consumed
# ▁consumer
# ▁consumeranditer
# ▁consumers
# ▁contact
# ▁contain
# ▁containe
# ▁container
# ▁contains
# ▁content
# ▁contents
# ▁contentsas
# ▁contentsasd
# ▁context
# ▁contin
# ▁continu
# ▁continue
# ▁continuous
# ▁contr
# ▁contrib
# ▁contribut
# ▁contribute
# ▁contributor
# ▁control
# ▁controll
# ▁conv
# ▁conven
# ▁convention
# ▁conversion
# ▁convert
# ▁converte
# ▁convi
# ▁dataconsumer
# ▁disconnect
# ▁disconnected
# ▁emoticon
# ▁flumeconfig
# ▁flumeconfigdata
# ▁getconfig
# ▁getconstructor
# ▁icon
# ▁inconsisten
# ▁inconsistent
# ▁initialcontext
# ▁loadconfig
# ▁maxconnections
# ▁methodconfigure
# ▁microsecond
# ▁microseconds
# ▁misconfigured
# ▁multiconfig
# ▁newconnection
# ▁openconnection
# ▁precondition
# ▁recon
# ▁reconfig
# ▁reconfigur
# ▁reconfiguration
# ▁reconfigure
# ▁reconfigured
# ▁reconfiguring
# ▁reconnect
# ▁second
# ▁seconds
# ▁testconcurrent
# ▁unconditionally
# ▁unconfig
# ▁unconfigur
# ▁wraphadoopconf
# ▁xcontent
#
# ------------
#
# repeat
# repeate
# ▁repeat
# ▁repeate
# ▁repeated
# ▁repeatedly
#
# ------------
#
# ark
# benchmark
# mark
# park
# spark
# ▁benchmark
# ▁mark
# ▁marke
# ▁marker
# ▁park
#
# ------------
#
# ersink
# failoversink
# oversink
#
# ------------
#
# tually
# ▁actually
#
# ------------
#
# ▁ts
# ▁tsasl
#
# ------------
#
# inputstr
# fileinputstream
# inputstream
# ▁inputstream
#
# ------------
#
# ▁neg
# ▁negat
# ▁negative
#
# ------------
#
# 368
# ▁368
# ▁3684769
# ▁3689
#
# ------------
#
# sto
# backingstore
# backingstorefile
# configstore
# customdfssink
# customizeservlet
# dcustomdfssink
# escapedcustom
# escapedcustomdfs
# keystore
# keystorepassword
# keystoreprovider
# pperconfigstore
# stop
# storage
# store
# storepass
# truststore
# ▁accesstoken
# ▁custom
# ▁customdfs
# ▁customer
# ▁customis
# ▁customiz
# ▁customize
# ▁histor
# ▁historic
# ▁keystore
# ▁metastore
# ▁mycustom
# ▁restore
# ▁stop
# ▁stopped
# ▁stopping
# ▁stops
# ▁stor
# ▁storage
# ▁store
# ▁truststore
#
# ------------
#
# endbatch
# appendbatch
# ▁appendbatch
#
# ------------
#
# rly
# ▁properly
#
# ------------
#
# ▁gi
# ▁gibberish
# ▁git
# ▁github
# ▁gitignore
# ▁giv
# ▁give
# ▁given
#
# ------------
#
# mys
# mysink
# myst
# ▁mys
#
# ------------
#
# 331
# 5331
# ▁331
#
# ------------
#
# 585
# ▁12258542385799
# ▁122585423857995
# ▁3585
#
# ------------
#
# ▁getde
# ▁getdefault
# ▁getdefaultin
#
# ------------
#
# git
# ▁git
# ▁github
# ▁gitignore
#
# ------------
#
# ▁flumeconfig
# ▁flumeconfigdata
#
# ------------
#
# lid
# invalidoperation
# valid
# validates
# validator
# ▁consolidat
# ▁eventvalidator
# ▁invalid
# ▁solid
# ▁valid
# ▁validat
# ▁validate
# ▁validates
# ▁validati
#
# ------------
#
# ou
# ablesourcerunner
# aneous
# attemptcount
# avrolegacysource
# avrosource
# background
# bound
# boundar
# cious
# cloud
# collectorsource
# count
# counter
# counts
# dataoutput
# directorysource
# dirsource
# dout
# doutput
# ectorysource
# edcount
# eous
# ergroup
# erous
# eventsource
# execsource
# eyou
# fileoutput
# found
# founde
# fsout
# ground
# group
# groupi
# groupin
# groups
# hour
# house
# hrifteventsource
# hroughputcounter
# httpsource
# ious
# layout
# ldirectorysource
# legacysource
# lingsourcerunner
# neous
# netcatsource
# notfound
# otfoundexception
# ouble
# ough
# ought
# ould
# ound
# ounds
# ount
# our
# ource
# ources
# ous
# out
# outofbounds
# outp
# output
# outputformat
# outputs
# pollablesource
# putattemptcount
# rainattemptcount
# rious
# rough
# round
# rounddown
# roundrobin
# roundtrip
# route
# source
# sourcecounter
# sourcerunner
# sources
# syslogtcpsource
# syslogudpsource
# tailsource
# tcpsource
# tcpsourcethreads
# tfoundexception
# though
# through
# throughput
# timeout
# tputattemptcount
# twittersource
# udpsource
# unixgroups
# without
# you
# yout
# yslogudpsource
# ▁amount
# ▁announce
# ▁around
# ▁asynchronous
# ▁avrosource
# ▁background
# ▁behaviour
# ▁bounc
# ▁bound
# ▁boundar
# ▁brough
# ▁calltimeout
# ▁checkout
# ▁classnotfound
# ▁clickhouse
# ▁clickhousesink
# ▁cloud
# ▁continuous
# ▁cou
# ▁couch
# ▁count
# ▁countdown
# ▁counter
# ▁counters
# ▁counting
# ▁couple
# ▁dangerous
# ▁decouple
# ▁doub
# ▁doubl
# ▁doubt
# ▁encounter
# ▁encountered
# ▁eventgroup
# ▁execeventsource
# ▁execsou
# ▁execsource
# ▁faninsource
# ▁fanout
# ▁favour
# ▁filegroup
# ▁filenotfound
# ▁found
# ▁getgroup
# ▁group
# ▁groupi
# ▁groups
# ▁hour
# ▁httpsource
# ▁jmssource
# ▁kafkasource
# ▁layout
# ▁logicalsource
# ▁netcatsource
# ▁obvious
# ▁ou
# ▁out
# ▁outage
# ▁outofmemory
# ▁outofmemorye
# ▁output
# ▁outputformat
# ▁outputs
# ▁outs
# ▁outst
# ▁pollablesource
# ▁previous
# ▁resource
# ▁round
# ▁rounddown
# ▁rounding
# ▁roundtrips
# ▁rout
# ▁route
# ▁routes
# ▁routine
# ▁rpcsource
# ▁scribesource
# ▁shou
# ▁should
# ▁sinkgroup
# ▁sou
# ▁sound
# ▁sourc
# ▁source
# ▁sourcecounter
# ▁sourcerunner
# ▁sources
# ▁sourcetype
# ▁stresssource
# ▁synchronous
# ▁syslogtcpsource
# ▁syslogudpsource
# ▁taildirsource
# ▁tailsource
# ▁testkafkasource
# ▁thou
# ▁though
# ▁thought
# ▁throu
# ▁through
# ▁throughput
# ▁timeout
# ▁timeouts
# ▁touch
# ▁trouble
# ▁twittersource
# ▁unbound
# ▁walsource
# ▁workaround
# ▁wou
# ▁xaresource
# ▁you

# %% [markdown]
# # Global

# %%
import os
import pandas as pd
import numpy as np
import json
from tqdm import tqdm
import tensorflow as tf
import torch
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
PROJECT_NAME = "FLUME"

TEXT_FEATURES = ["title", "description", "summary"]
ADDING_TIME_FEATURES = ["CC", "CU"]

MAXLEN = 256
MODEL_NAME = "LSTM"
EMBEDDING_METHOD = "GloVe"
DEVICE = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
import sentencepiece as spm
sp = spm.SentencePieceProcessor(model_file='my_model.model')

# %%
# Load GloVe pretrained model
__PADDED_INDEX__ = 0
__UNKNOWN_WORD__ = 1

def load_word_embeddings(fname):
    wordvecs = {}
    with open(fname, 'r') as file:
        lines = file.readlines()
        for line in lines:
            tokens = line.split(' ')
            vec = np.array(tokens[1:], dtype=np.float32)
            wordvecs[tokens[0]] = vec

    return wordvecs

if not os.path.exists("GloVe_embedding_matrix.npy"):
  wordvecs = load_word_embeddings("glove.42B.300d.txt")
  vocab = wordvecs.keys()
  matrix = list(wordvecs.values())
  WORD2INDEX = {word: index+2 for index, word in enumerate(vocab)}
  EMBEDDING_MATRIX = np.pad(matrix, [[2,0],[0,0]], mode='constant', constant_values =0.0)
  np.save("GloVe_embedding_matrix.npy", EMBEDDING_MATRIX)
  with open("GloVe_word_to_index.json", "w") as f:
    json.dump(WORD2INDEX, f)
else:
  EMBEDDING_MATRIX = np.load("GloVe_embedding_matrix.npy")
  with open("GloVe_word_to_index.json", "r") as f:
    WORD2INDEX = json.load(f)
EMBEDDING_MATRIX = torch.tensor(EMBEDDING_MATRIX)
HIDDEN_SIZE = EMBEDDING_MATRIX.shape[1]

def get_tokens(sentence):
  tokens = sp.encode_as_pieces(sentence)
  formatted_tokens = []
  for token in tokens:
    if token[0]=='_':
      token = token[1:]
    formatted_tokens.append(token)
  return formatted_tokens

def glove_tokenizer(sentences):
  tokenized_texts = [get_tokens(text) for text in sentences]
  X = []
  for text in tokenized_texts:
    cur_text_indices = []
    for word in text:
      if word in WORD2INDEX:
          cur_text_indices.append(WORD2INDEX[word])
      else:
          cur_text_indices.append(__UNKNOWN_WORD__)
    X.append(cur_text_indices)
  return X

# %% [markdown]
# # Load data

# %%
train_links = pd.read_csv(
    f"data/{PROJECT_NAME}/train_links.csv", keep_default_na=False)
train_links['label'] = train_links['label'].map(lambda x: int(x!=0))
issues = pd.read_csv(
    f"data/{PROJECT_NAME}/preprocessed_attributes.csv", index_col="key")
issues['created'] = pd.to_datetime(issues['created'], utc=True)
issues['updated'] = pd.to_datetime(issues['updated'], utc=True)
issues = issues.fillna(" ")
first_feature = TEXT_FEATURES[0]
issues["text"] = issues[first_feature]
if len(TEXT_FEATURES)>1:
  for feature in TEXT_FEATURES[1:]:
    issues["text"] = issues["text"] + " " + issues[feature]

# %% [markdown]
# #Training

# %%
from pydantic import BaseModel

class ModelConfig(BaseModel):
  generate_batch_size: int
  mul: int
  adding_time_features: list
  mean_time_features: float
  std_time_features: float
  value_maxlen: int
  hidden_size: int
  number_units: int
  model_name: str
  learning_rate: float
  steps_per_epoch: int
  epochs: int

def generate_input(issues, train_links, config: ModelConfig):
    match_data = train_links[train_links["label"] != 0]
    none_data = train_links[train_links["label"] == 0]
    match_data = match_data[['key_1', "key_2"]].values
    none_data = none_data[['key_1', "key_2"]].values

    while True:
        each_size = int(config.generate_batch_size/2)

        # Shuffle index of match data
        shuffle_index = [index for index in np.random.choice(
            len(match_data), len(match_data), replace=False)]
        match_data = [match_data[index] for index in shuffle_index]

        for iter in range(int(len(match_data)/each_size)):
            # Split data by batch size and randomly select non_match_links: 1/2 for match data, 1/2 for non-match data

            # Get index
            match_index = np.array(range(iter*each_size, (iter+1)*each_size))
            none_index = np.array([index for index in np.random.choice(
                len(none_data), each_size*config.mul, replace=False)])

            match_links = [match_data[i] for i in match_index]
            none_links = [none_data[i] for i in none_index]

            # Create X by tokenizing and padding X
            index_pairs = np.array(match_links + none_links)
            text_1 = glove_tokenizer(issues["text"].loc[index_pairs[:,0]].values)
            text_1 = tf.keras.utils.pad_sequences(sequences=text_1, padding='post', truncating="post", maxlen=MAXLEN)
            text_2 = glove_tokenizer(issues["text"].loc[index_pairs[:,1]].values)
            text_2 = tf.keras.utils.pad_sequences(sequences=text_2, padding='post', truncating="post", maxlen=MAXLEN)

            # Create label y
            match_y = np.vstack(
                [np.zeros(len(match_links)), np.ones(len(match_links))]).T
            none_y = np.vstack([np.ones(len(none_links)), np.zeros(len(none_links))]).T
            y = np.concatenate([match_y, none_y])

            cre_1 = issues["created"].loc[index_pairs[:, 0]].values
            cre_2 = issues["created"].loc[index_pairs[:, 1]].values
            update = issues["updated"].loc[index_pairs[:, 1]].values
            cre_cre = np.array(
                (cre_1-cre_2) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)
            cre_up =  np.array(
                (cre_1-update) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)
            if len(config.adding_time_features) == 2:
                time_features = np.array(
                    [[cre_cre[i][0], cre_up[i][0]] for i in range(len(cre_cre))])
            elif "CC" in config.adding_time_features:
                time_features = cre_cre
            elif "CU" in config.adding_time_features:
                time_features = cre_up
            index = np.random.choice(len(index_pairs), config.generate_batch_size, replace=False)
            if len(config.adding_time_features) == 0:
                yield [text_1[index], text_2[index]], y[index]
            else:
                time_features = np.array(
                [(time_features[i]-config.mean_time_features)/config.std_time_features for i in range(len(time_features))])
                yield [text_1[index], text_2[index], time_features[index]], y[index]
    return 0

def return_model(config: ModelConfig):
  inputs_A = tf.keras.Input(shape=(config.value_maxlen), name="input_a")
  inputs_B = tf.keras.Input(shape=(config.value_maxlen), name="input_b")

  embedding_layer = tf.keras.layers.Embedding(input_dim=EMBEDDING_MATRIX.shape[0],
                 output_dim=EMBEDDING_MATRIX.shape[1],
                  embeddings_initializer = tf.keras.initializers.Constant(value=EMBEDDING_MATRIX),
                 mask_zero=True)
  embedding_layer.trainable=False
  # Embedding
  emb_A = embedding_layer(inputs_A)
  emb_B = embedding_layer(inputs_B)

  if len(ADDING_TIME_FEATURES)==1:
    inputs_C = tf.keras.Input(shape=(1), name="input_c")
  elif len(ADDING_TIME_FEATURES)==2:
    inputs_C = tf.keras.Input(shape=(2), name="input_c")

  # Deep Learning model's structure
  flatten_layer = tf.keras.layers.Flatten(name="flatten")
  dense_1_layer = tf.keras.layers.Dense(config.number_units, activation="relu", name="dense_1")
  output_layer = tf.keras.layers.Dense(2, activation="softmax", name="dense_output")

  if config.model_name=="CNN":
    core_layer = tf.keras.layers.Conv1D(config.number_units, 3, activation='relu')
  elif config.model_name=="LSTM":
    core_layer = tf.keras.layers.LSTM(config.number_units)
  else:
    core_layer = tf.keras.layers.GRU(config.number_units, name="gru")

  core_A = core_layer(emb_A)
  core_B = core_layer(emb_B)

  if len(ADDING_TIME_FEATURES)==0:

    # Concat two embedded inputs
    X = tf.concat([flatten_layer(core_A), flatten_layer(core_B)], axis=1)

    dense_1_X = dense_1_layer(X)

    outputs = output_layer(dense_1_X)

    model = tf.keras.Model(inputs=[inputs_A, inputs_B], outputs=outputs)

  else:

    # Concat two embedded inputs
    X = tf.concat([flatten_layer(core_A), flatten_layer(core_B), inputs_C], axis=1)

    dense_1_X = dense_1_layer(X)

    outputs = output_layer(dense_1_X)

    model = tf.keras.Model(inputs=[inputs_A, inputs_B, inputs_C], outputs=outputs)

  model.compile(tf.keras.optimizers.Adam(learning_rate=config.learning_rate), loss="mse", metrics=["categorical_accuracy"])
  model.summary()

  return model

def train_model(issues, train_links, config):
  model = return_model(config)
  history = model.fit(generate_input(issues, train_links, config),
              steps_per_epoch=config.steps_per_epoch,
              epochs=config.epochs,
              shuffle=False,
              verbose = 1)
  return model

# %%
def get_normalize_parameter(issues, train_links):
    index_pairs = train_links[["key_1", "key_2"]].values
    cre_1 = issues["created"].loc[index_pairs[:, 0]].values
    cre_2 = issues["created"].loc[index_pairs[:, 1]].values
    update = issues["updated"].loc[index_pairs[:, 1]].values
    cre_cre = np.array((cre_1-cre_2) / np.timedelta64(1,
                       'D'), dtype=int).reshape(-1, 1)
    cre_up = np.array((cre_1-update) / np.timedelta64(1, 'D'),
                      dtype=int).reshape(-1, 1)
    if len(ADDING_TIME_FEATURES) == 2:
        time_features = np.array([[cre_cre[i][0], cre_up[i][0]]
                                 for i in range(len(cre_cre))])
    elif "CC" in ADDING_TIME_FEATURES:
        time_features = cre_cre
    elif "CU" in ADDING_TIME_FEATURES:
        time_features = cre_up
    else:
      time_features = [0]
    mean = np.mean(time_features)
    std = np.std(time_features)
    return mean, std

# %%
MEAN_TIME_FEATURES, STD_TIME_FEATURES = get_normalize_parameter(
    issues, train_links)
print(MEAN_TIME_FEATURES, STD_TIME_FEATURES)
# Out:
# -239.13518612407353 1354.9751217063258

# %%
model_config = ModelConfig(
  model_name = MODEL_NAME,
  generate_batch_size = 128,
  mul = 3,
  adding_time_features = ADDING_TIME_FEATURES,
  mean_time_features = MEAN_TIME_FEATURES,
  std_time_features = STD_TIME_FEATURES,
  value_maxlen = MAXLEN,
  hidden_size = HIDDEN_SIZE,
  number_units = 256,
  learning_rate = 1e-3,
  steps_per_epoch = 5,
  epochs = 200)
model = train_model(issues, train_links, model_config)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_a (InputLayer)        [(None, 256)]                0         []
#
#  input_b (InputLayer)        [(None, 256)]                0         []
#
#  embedding (Embedding)       (None, 256, 300)             5752488   ['input_a[0][0]',
#                                                           00         'input_b[0][0]']
#
#  lstm (LSTM)                 (None, 256)                  570368    ['embedding[0][0]',
#                                                                      'embedding[1][0]']
#
#  flatten (Flatten)           (None, 256)                  0         ['lstm[0][0]',
#                                                                      'lstm[1][0]']
#
#  input_c (InputLayer)        [(None, 2)]                  0         []
#
#  tf.concat (TFOpLambda)      (None, 514)                  0         ['flatten[0][0]',
#                                                                      'flatten[1][0]',
#                                                                      'input_c[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  131840    ['tf.concat[0][0]']
#
#  dense_output (Dense)        (None, 2)                    514       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 575951522 (2.15 GB)
# Trainable params: 702722 (2.68 MB)
# Non-trainable params: 575248800 (2.14 GB)
# __________________________________________________________________________________________________
# Epoch 1/200
# 5/5 [==============================] - 11s 115ms/step - loss: 0.2141 - categorical_accuracy: 0.6906
# Epoch 2/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.1909 - categorical_accuracy: 0.7516
# Epoch 3/200
# 5/5 [==============================] - 1s 150ms/step - loss: 0.1771 - categorical_accuracy: 0.7500
# Epoch 4/200
# 5/5 [==============================] - 1s 203ms/step - loss: 0.1732 - categorical_accuracy: 0.7734
# Epoch 5/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.1673 - categorical_accuracy: 0.7703
# Epoch 6/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.1485 - categorical_accuracy: 0.7984
# Epoch 7/200
# 5/5 [==============================] - 1s 228ms/step - loss: 0.1661 - categorical_accuracy: 0.7594
# Epoch 8/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.1662 - categorical_accuracy: 0.7609
# Epoch 9/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.1480 - categorical_accuracy: 0.7812
# Epoch 10/200
# 5/5 [==============================] - 1s 124ms/step - loss: 0.1491 - categorical_accuracy: 0.7656
# Epoch 11/200
# 5/5 [==============================] - 1s 143ms/step - loss: 0.1478 - categorical_accuracy: 0.7781
# Epoch 12/200
# 5/5 [==============================] - 1s 124ms/step - loss: 0.1436 - categorical_accuracy: 0.7969
# Epoch 13/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.1426 - categorical_accuracy: 0.7922
# Epoch 14/200
# 5/5 [==============================] - 1s 144ms/step - loss: 0.1320 - categorical_accuracy: 0.8109
# Epoch 15/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.1375 - categorical_accuracy: 0.7969
# Epoch 16/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.1198 - categorical_accuracy: 0.8266
# Epoch 17/200
# 5/5 [==============================] - 1s 144ms/step - loss: 0.1255 - categorical_accuracy: 0.8188
# Epoch 18/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.1218 - categorical_accuracy: 0.8125
# Epoch 19/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.1248 - categorical_accuracy: 0.8219
# Epoch 20/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.1177 - categorical_accuracy: 0.8375
# Epoch 21/200
# 5/5 [==============================] - 1s 146ms/step - loss: 0.1247 - categorical_accuracy: 0.8281
# Epoch 22/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.1123 - categorical_accuracy: 0.8281
# Epoch 23/200
# 5/5 [==============================] - 1s 121ms/step - loss: 0.1209 - categorical_accuracy: 0.8172
# Epoch 24/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.1023 - categorical_accuracy: 0.8578
# Epoch 25/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.1115 - categorical_accuracy: 0.8547
# Epoch 26/200
# 5/5 [==============================] - 1s 216ms/step - loss: 0.1091 - categorical_accuracy: 0.8500
# Epoch 27/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.1067 - categorical_accuracy: 0.8516
# Epoch 28/200
# 5/5 [==============================] - 1s 187ms/step - loss: 0.1034 - categorical_accuracy: 0.8594
# Epoch 29/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.1045 - categorical_accuracy: 0.8594
# Epoch 30/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.1053 - categorical_accuracy: 0.8453
# Epoch 31/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.1140 - categorical_accuracy: 0.8406
# Epoch 32/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.1042 - categorical_accuracy: 0.8578
# Epoch 33/200
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0999 - categorical_accuracy: 0.8625
# Epoch 34/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0925 - categorical_accuracy: 0.8828
# Epoch 35/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0990 - categorical_accuracy: 0.8656
# Epoch 36/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.1125 - categorical_accuracy: 0.8297
# Epoch 37/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0870 - categorical_accuracy: 0.8875
# Epoch 38/200
# 5/5 [==============================] - 1s 129ms/step - loss: 0.1032 - categorical_accuracy: 0.8531
# Epoch 39/200
# 5/5 [==============================] - 1s 144ms/step - loss: 0.1013 - categorical_accuracy: 0.8656
# Epoch 40/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0899 - categorical_accuracy: 0.8859
# Epoch 41/200
# 5/5 [==============================] - 1s 147ms/step - loss: 0.0976 - categorical_accuracy: 0.8500
# Epoch 42/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0833 - categorical_accuracy: 0.8984
# Epoch 43/200
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0848 - categorical_accuracy: 0.8844
# Epoch 44/200
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0903 - categorical_accuracy: 0.8813
# Epoch 45/200
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0839 - categorical_accuracy: 0.8906
# Epoch 46/200
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0876 - categorical_accuracy: 0.8750
# Epoch 47/200
# 5/5 [==============================] - 1s 198ms/step - loss: 0.0856 - categorical_accuracy: 0.8922
# Epoch 48/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0736 - categorical_accuracy: 0.9031
# Epoch 49/200
# 5/5 [==============================] - 1s 147ms/step - loss: 0.0810 - categorical_accuracy: 0.8953
# Epoch 50/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.0835 - categorical_accuracy: 0.8844
# Epoch 51/200
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0695 - categorical_accuracy: 0.9078
# Epoch 52/200
# 5/5 [==============================] - 1s 143ms/step - loss: 0.0713 - categorical_accuracy: 0.9062
# Epoch 53/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0846 - categorical_accuracy: 0.8891
# Epoch 54/200
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0772 - categorical_accuracy: 0.9078
# Epoch 55/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0840 - categorical_accuracy: 0.8922
# Epoch 56/200
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0758 - categorical_accuracy: 0.9078
# Epoch 57/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0763 - categorical_accuracy: 0.9016
# Epoch 58/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0840 - categorical_accuracy: 0.8797
# Epoch 59/200
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0807 - categorical_accuracy: 0.8906
# Epoch 60/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0968 - categorical_accuracy: 0.8703
# Epoch 61/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0734 - categorical_accuracy: 0.9078
# Epoch 62/200
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0664 - categorical_accuracy: 0.9172
# Epoch 63/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0752 - categorical_accuracy: 0.8938
# Epoch 64/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0764 - categorical_accuracy: 0.8875
# Epoch 65/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0759 - categorical_accuracy: 0.8969
# Epoch 66/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0724 - categorical_accuracy: 0.9078
# Epoch 67/200
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0672 - categorical_accuracy: 0.9172
# Epoch 68/200
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0675 - categorical_accuracy: 0.9141
# Epoch 69/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0677 - categorical_accuracy: 0.9078
# Epoch 70/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0660 - categorical_accuracy: 0.9094
# Epoch 71/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0582 - categorical_accuracy: 0.9391
# Epoch 72/200
# 5/5 [==============================] - 1s 143ms/step - loss: 0.0641 - categorical_accuracy: 0.9234
# Epoch 73/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0718 - categorical_accuracy: 0.9094
# Epoch 74/200
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0699 - categorical_accuracy: 0.9125
# Epoch 75/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0627 - categorical_accuracy: 0.9141
# Epoch 76/200
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0633 - categorical_accuracy: 0.9172
# Epoch 77/200
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0622 - categorical_accuracy: 0.9234
# Epoch 78/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0574 - categorical_accuracy: 0.9359
# Epoch 79/200
# 5/5 [==============================] - 1s 147ms/step - loss: 0.0549 - categorical_accuracy: 0.9234
# Epoch 80/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0581 - categorical_accuracy: 0.9312
# Epoch 81/200
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0533 - categorical_accuracy: 0.9234
# Epoch 82/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0585 - categorical_accuracy: 0.9297
# Epoch 83/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0694 - categorical_accuracy: 0.9187
# Epoch 84/200
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0457 - categorical_accuracy: 0.9516
# Epoch 85/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0595 - categorical_accuracy: 0.9203
# Epoch 86/200
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0527 - categorical_accuracy: 0.9359
# Epoch 87/200
# 5/5 [==============================] - 1s 198ms/step - loss: 0.0501 - categorical_accuracy: 0.9438
# Epoch 88/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0608 - categorical_accuracy: 0.9172
# Epoch 89/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0567 - categorical_accuracy: 0.9344
# Epoch 90/200
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0455 - categorical_accuracy: 0.9516
# Epoch 91/200
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0500 - categorical_accuracy: 0.9422
# Epoch 92/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0518 - categorical_accuracy: 0.9375
# Epoch 93/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0617 - categorical_accuracy: 0.9281
# Epoch 94/200
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0560 - categorical_accuracy: 0.9344
# Epoch 95/200
# 5/5 [==============================] - 1s 143ms/step - loss: 0.0483 - categorical_accuracy: 0.9516
# Epoch 96/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0456 - categorical_accuracy: 0.9484
# Epoch 97/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0453 - categorical_accuracy: 0.9484
# Epoch 98/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0474 - categorical_accuracy: 0.9484
# Epoch 99/200
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0511 - categorical_accuracy: 0.9328
# Epoch 100/200
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0381 - categorical_accuracy: 0.9594
# Epoch 101/200
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0540 - categorical_accuracy: 0.9344
# Epoch 102/200
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0466 - categorical_accuracy: 0.9516
# Epoch 103/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0507 - categorical_accuracy: 0.9375
# Epoch 104/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0404 - categorical_accuracy: 0.9594
# Epoch 105/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0390 - categorical_accuracy: 0.9594
# Epoch 106/200
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0402 - categorical_accuracy: 0.9609
# Epoch 107/200
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0444 - categorical_accuracy: 0.9469
# Epoch 108/200
# 5/5 [==============================] - 1s 227ms/step - loss: 0.0422 - categorical_accuracy: 0.9484
# Epoch 109/200
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0402 - categorical_accuracy: 0.9516
# Epoch 110/200
# 5/5 [==============================] - 1s 143ms/step - loss: 0.0408 - categorical_accuracy: 0.9453
# Epoch 111/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0587 - categorical_accuracy: 0.9312
# Epoch 112/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0438 - categorical_accuracy: 0.9500
# Epoch 113/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0374 - categorical_accuracy: 0.9594
# Epoch 114/200
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0355 - categorical_accuracy: 0.9578
# Epoch 115/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0427 - categorical_accuracy: 0.9422
# Epoch 116/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0465 - categorical_accuracy: 0.9422
# Epoch 117/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0391 - categorical_accuracy: 0.9578
# Epoch 118/200
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0418 - categorical_accuracy: 0.9531
# Epoch 119/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.0432 - categorical_accuracy: 0.9531
# Epoch 120/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0403 - categorical_accuracy: 0.9469
# Epoch 121/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0364 - categorical_accuracy: 0.9563
# Epoch 122/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0377 - categorical_accuracy: 0.9563
# Epoch 123/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.0415 - categorical_accuracy: 0.9516
# Epoch 124/200
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0369 - categorical_accuracy: 0.9578
# Epoch 125/200
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0406 - categorical_accuracy: 0.9484
# Epoch 126/200
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0319 - categorical_accuracy: 0.9625
# Epoch 127/200
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0350 - categorical_accuracy: 0.9625
# Epoch 128/200
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0339 - categorical_accuracy: 0.9594
# Epoch 129/200
# 5/5 [==============================] - 1s 195ms/step - loss: 0.0355 - categorical_accuracy: 0.9609
# Epoch 130/200
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0350 - categorical_accuracy: 0.9516
# Epoch 131/200
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0339 - categorical_accuracy: 0.9594
# Epoch 132/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0440 - categorical_accuracy: 0.9453
# Epoch 133/200
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0344 - categorical_accuracy: 0.9578
# Epoch 134/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0333 - categorical_accuracy: 0.9609
# Epoch 135/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0376 - categorical_accuracy: 0.9625
# Epoch 136/200
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0381 - categorical_accuracy: 0.9578
# Epoch 137/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0439 - categorical_accuracy: 0.9500
# Epoch 138/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0325 - categorical_accuracy: 0.9609
# Epoch 139/200
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0443 - categorical_accuracy: 0.9484
# Epoch 140/200
# 5/5 [==============================] - 1s 143ms/step - loss: 0.0348 - categorical_accuracy: 0.9594
# Epoch 141/200
# 5/5 [==============================] - 1s 99ms/step - loss: 0.0374 - categorical_accuracy: 0.9547
# Epoch 142/200
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0351 - categorical_accuracy: 0.9563
# Epoch 143/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0366 - categorical_accuracy: 0.9563
# Epoch 144/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0311 - categorical_accuracy: 0.9641
# Epoch 145/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0352 - categorical_accuracy: 0.9625
# Epoch 146/200
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0296 - categorical_accuracy: 0.9672
# Epoch 147/200
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0238 - categorical_accuracy: 0.9750
# Epoch 148/200
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0360 - categorical_accuracy: 0.9563
# Epoch 149/200
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0437 - categorical_accuracy: 0.9422
# Epoch 150/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0345 - categorical_accuracy: 0.9641
# Epoch 151/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0297 - categorical_accuracy: 0.9656
# Epoch 152/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0364 - categorical_accuracy: 0.9609
# Epoch 153/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0305 - categorical_accuracy: 0.9672
# Epoch 154/200
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0273 - categorical_accuracy: 0.9734
# Epoch 155/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0339 - categorical_accuracy: 0.9594
# Epoch 156/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0266 - categorical_accuracy: 0.9734
# Epoch 157/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0348 - categorical_accuracy: 0.9625
# Epoch 158/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0282 - categorical_accuracy: 0.9688
# Epoch 159/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0362 - categorical_accuracy: 0.9594
# Epoch 160/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0237 - categorical_accuracy: 0.9797
# Epoch 161/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0260 - categorical_accuracy: 0.9672
# Epoch 162/200
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0242 - categorical_accuracy: 0.9781
# Epoch 163/200
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0314 - categorical_accuracy: 0.9656
# Epoch 164/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0270 - categorical_accuracy: 0.9734
# Epoch 165/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.0229 - categorical_accuracy: 0.9719
# Epoch 166/200
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0370 - categorical_accuracy: 0.9484
# Epoch 167/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0282 - categorical_accuracy: 0.9656
# Epoch 168/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0340 - categorical_accuracy: 0.9672
# Epoch 169/200
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0283 - categorical_accuracy: 0.9703
# Epoch 170/200
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0277 - categorical_accuracy: 0.9656
# Epoch 171/200
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0278 - categorical_accuracy: 0.9656
# Epoch 172/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0327 - categorical_accuracy: 0.9594
# Epoch 173/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0227 - categorical_accuracy: 0.9781
# Epoch 174/200
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0292 - categorical_accuracy: 0.9656
# Epoch 175/200
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0368 - categorical_accuracy: 0.9531
# Epoch 176/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0275 - categorical_accuracy: 0.9672
# Epoch 177/200
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0189 - categorical_accuracy: 0.9797
# Epoch 178/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0310 - categorical_accuracy: 0.9578
# Epoch 179/200
# 5/5 [==============================] - 1s 148ms/step - loss: 0.0293 - categorical_accuracy: 0.9625
# Epoch 180/200
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0306 - categorical_accuracy: 0.9656
# Epoch 181/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0309 - categorical_accuracy: 0.9625
# Epoch 182/200
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0256 - categorical_accuracy: 0.9688
# Epoch 183/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0267 - categorical_accuracy: 0.9703
# Epoch 184/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0272 - categorical_accuracy: 0.9672
# Epoch 185/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0257 - categorical_accuracy: 0.9672
# Epoch 186/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0301 - categorical_accuracy: 0.9672
# Epoch 187/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0263 - categorical_accuracy: 0.9672
# Epoch 188/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0307 - categorical_accuracy: 0.9641
# Epoch 189/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0180 - categorical_accuracy: 0.9812
# Epoch 190/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0227 - categorical_accuracy: 0.9766
# Epoch 191/200
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0255 - categorical_accuracy: 0.9703
# Epoch 192/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0231 - categorical_accuracy: 0.9797
# Epoch 193/200
# 5/5 [==============================] - 1s 156ms/step - loss: 0.0220 - categorical_accuracy: 0.9734
# Epoch 194/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0227 - categorical_accuracy: 0.9750
# Epoch 195/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0254 - categorical_accuracy: 0.9719
# Epoch 196/200
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0270 - categorical_accuracy: 0.9703
# Epoch 197/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0252 - categorical_accuracy: 0.9750
# Epoch 198/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0214 - categorical_accuracy: 0.9781
# Epoch 199/200
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0206 - categorical_accuracy: 0.9766
# Epoch 200/200
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0296 - categorical_accuracy: 0.9594

# %%
model.save_weights(f"{EMBEDDING_METHOD}_{MODEL_NAME}.h5")

# %% [markdown]
# # Test

# %%
test_links = pd.read_csv(
    f"data/{PROJECT_NAME}/test_links.csv", keep_default_na=False)
test_links['label'] = test_links['label'].map(lambda x: int(x!=0))

# %%
from torch.utils.data import Dataset,  DataLoader
class TestDataset(Dataset):
    def __init__(self, index_pairs, labels):
        self.index_pairs = index_pairs
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
      return [self.index_pairs[idx,0], self.index_pairs[idx,1]], self.labels[idx]

# %%
def get_predict(issues, index_pairs, config, model):
  text_1 = glove_tokenizer(issues["text"].loc[index_pairs[0]].values)
  text_1 = tf.keras.utils.pad_sequences(sequences=text_1, padding='post', truncating="post", maxlen=MAXLEN)
  text_2 = glove_tokenizer(issues["text"].loc[index_pairs[1]].values)
  text_2 = tf.keras.utils.pad_sequences(sequences=text_2, padding='post', truncating="post", maxlen=MAXLEN)
  cre_1 = issues["created"].loc[index_pairs[0]].values
  cre_2 = issues["created"].loc[index_pairs[1]].values
  update = issues["updated"].loc[index_pairs[1]].values
  cre_cre = np.array(
      (cre_1-cre_2) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)
  cre_up =  np.array(
      (cre_1-update) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)

  if len(config.adding_time_features) == 2:
      time_features = np.array(
          [[cre_cre[i][0], cre_up[i][0]] for i in range(len(cre_cre))])
  elif "CC" in config.adding_time_features:
      time_features = cre_cre
  elif "CU" in config.adding_time_features:
      time_features = cre_up
  else:
    return model([text_1, text_2])
  if len(config.adding_time_features) > 0:
    time_features = np.array(
        [(time_features[i]-config.mean_time_features)/config.std_time_features for i in range(len(time_features))])
  return model([text_1, text_2, time_features])

# %%
labels = []
for i in test_links["label"].values:
  if i==0:
    labels.append([1,0])
  else:
    labels.append([0,1])
test_data = TestDataset(test_links[["key_1", "key_2"]].values, labels)

# %%
test_dataloader = DataLoader(test_data, batch_size=2048)
len(test_dataloader)
# Out:
# 243

# %%
if not os.path.exists(f"results_{EMBEDDING_METHOD}_{PROJECT_NAME}"):
  os.mkdir(f"results_{EMBEDDING_METHOD}_{PROJECT_NAME}")

# %%
for index, i in enumerate(test_dataloader):
  index_pairs, label = i
  index_pairs[0] = np.array( index_pairs[0])
  index_pairs[1] = np.array( index_pairs[1])
  proba = get_predict(issues, index_pairs, model_config, model)
  torch.save(proba, f"results_{EMBEDDING_METHOD}_{PROJECT_NAME}/result_{index}.pt")
  torch.cuda.empty_cache()
  print(f"{index}/{len(test_dataloader)}")
# Out:
# 0/243
# 1/243
# 2/243
# 3/243
# 4/243
# 5/243
# 6/243
# 7/243
# 8/243
# 9/243
# 10/243
# 11/243
# 12/243
# 13/243
# 14/243
# 15/243
# 16/243
# 17/243
# 18/243
# 19/243
# 20/243
# 21/243
# 22/243
# 23/243
# 24/243
# 25/243
# 26/243
# 27/243
# 28/243
# 29/243
# 30/243
# 31/243
# 32/243
# 33/243
# 34/243
# 35/243
# 36/243
# 37/243
# 38/243
# 39/243
# 40/243
# 41/243
# 42/243
# 43/243
# 44/243
# 45/243
# 46/243
# 47/243
# 48/243
# 49/243
# 50/243
# 51/243
# 52/243
# 53/243
# 54/243
# 55/243
# 56/243
# 57/243
# 58/243
# 59/243
# 60/243
# 61/243
# 62/243
# 63/243
# 64/243
# 65/243
# 66/243
# 67/243
# 68/243
# 69/243
# 70/243
# 71/243
# 72/243
# 73/243
# 74/243
# 75/243
# 76/243
# 77/243
# 78/243
# 79/243
# 80/243
# 81/243
# 82/243
# 83/243
# 84/243
# 85/243
# 86/243
# 87/243
# 88/243
# 89/243
# 90/243
# 91/243
# 92/243
# 93/243
# 94/243
# 95/243
# 96/243
# 97/243
# 98/243
# 99/243
# 100/243
# 101/243
# 102/243
# 103/243
# 104/243
# 105/243
# 106/243
# 107/243
# 108/243
# 109/243
# 110/243
# 111/243
# 112/243
# 113/243
# 114/243
# 115/243
# 116/243
# 117/243
# 118/243
# 119/243
# 120/243
# 121/243
# 122/243
# 123/243
# 124/243
# 125/243
# 126/243
# 127/243
# 128/243
# 129/243
# 130/243
# 131/243
# 132/243
# 133/243
# 134/243
# 135/243
# 136/243
# 137/243
# 138/243
# 139/243
# 140/243
# 141/243
# 142/243
# 143/243
# 144/243
# 145/243
# 146/243
# 147/243
# 148/243
# 149/243
# 150/243
# 151/243
# 152/243
# 153/243
# 154/243
# 155/243
# 156/243
# 157/243
# 158/243
# 159/243
# 160/243
# 161/243
# 162/243
# 163/243
# 164/243
# 165/243
# 166/243
# 167/243
# 168/243
# 169/243
# 170/243
# 171/243
# 172/243
# 173/243
# 174/243
# 175/243
# 176/243
# 177/243
# 178/243
# 179/243
# 180/243
# 181/243
# 182/243
# 183/243
# 184/243
# 185/243
# 186/243
# 187/243
# 188/243
# 189/243
# 190/243
# 191/243
# 192/243
# 193/243
# 194/243
# 195/243
# 196/243
# 197/243
# 198/243
# 199/243
# 200/243
# 201/243
# 202/243
# 203/243
# 204/243
# 205/243
# 206/243
# 207/243
# 208/243
# 209/243
# 210/243
# 211/243
# 212/243
# 213/243
# 214/243
# 215/243
# 216/243
# 217/243
# 218/243
# 219/243
# 220/243
# 221/243
# 222/243
# 223/243
# 224/243
# 225/243
# 226/243
# 227/243
# 228/243
# 229/243
# 230/243
# 231/243
# 232/243
# 233/243
# 234/243
# 235/243
# 236/243
# 237/243
# 238/243
# 239/243
# 240/243
# 241/243
# 242/243

# %%
pred_proba = torch.tensor([])
for index, _ in tqdm(enumerate(test_dataloader)):
  proba = torch.load(f"results_{EMBEDDING_METHOD}_{PROJECT_NAME}/result_{index}.pt")
  if index==0:
    pred_proba = proba
  else:
    pred_proba=tf.concat([pred_proba, proba],axis=0)
# Out:
# 243it [00:02, 82.52it/s]

# %%
y_s = [np.argmax(i) for i in labels]
pred_s = np.argmax(pred_proba.numpy(),axis=1)

# %%
from sklearn.metrics import confusion_matrix, classification_report
print("Confusion maxtrix")
print(confusion_matrix(y_s, pred_s))
print(classification_report(y_s, pred_s, digits= 2))
# Out:
# Confusion maxtrix
# [[485604  10697]
#  [   147     76]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    496301
#            1       0.01      0.34      0.01       223
#
#     accuracy                           0.98    496524
#    macro avg       0.50      0.66      0.50    496524
# weighted avg       1.00      0.98      0.99    496524

# %% [markdown]
# # Recommend

# %%
match_test_links = test_links[test_links["label"]!=0]

# %%
test_issues = pd.read_csv(f"data/{PROJECT_NAME}/test_issues.csv", index_col="key").index

y_test = []
filter_test_issues = []
for test_issue in tqdm(test_issues):
  filter_links = match_test_links[(match_test_links["key_1"]==test_issue)|(match_test_links["key_2"]==test_issue)]
  if len(filter_links)>0:
    match_issues = set(list(filter_links["key_1"].values) + list(filter_links["key_2"].values))
    match_issues.remove(test_issue)
    y_test.append(list(match_issues))
    filter_test_issues.append(test_issue)
test_issues = filter_test_issues
# Out:
# 100%|██████████| 276/276 [00:00<00:00, 1518.67it/s]

# %%
len(test_issues)
# Out:
# 276

# %%
def get_accuracy(pred, gt):
	acc = 0
	for i, item in enumerate(pred):
		if item in gt:
			acc += 1.0
			break
	return acc

def get_MRR(pred, gt):
	mrr = 0
	for i, item in enumerate(pred):
		if item in gt:
			mrr += 1.0/(i+1)
	return mrr

def get_precision_recall(pred, gt):
	right = 0

	for item in gt:
		if item in pred: # relevant
			right+=1

	if len(pred) == 0:
		precision = 0
	else:
		precision = right/len(pred)
	recall = right/len(gt)

	return precision, recall

def get_f1_score(precision, recall):
    if precision + recall == 0:
        return 0
    f1_score = 2 * (precision * recall) / (precision + recall)
    return f1_score

def get_f0_5_score(precision, recall):
    beta = 0.5
    if precision + recall == 0:
        return 0
    f0_5_score = (1 + beta**2) * (precision * recall) / (beta**2 * precision + recall)
    return f0_5_score

def get_f2_score(precision, recall):
    beta = 2
    if precision + recall == 0:
        return 0
    f2_score = (1 + beta**2) * (precision * recall) / (beta**2 * precision + recall)
    return f2_score

def get_metrics(recommend, label):
	acc = 0
	mrr = 0
	precision = 0
	recall = 0
	f1 = 0
	f0_5 = 0
	f2 = 0
	for i in range(0, len(recommend)):
		if len(label[i])!=0:
			acc += get_accuracy(recommend[i], label[i])
			mrr += get_MRR(recommend[i], label[i])
			precision_recall = get_precision_recall(recommend[i], label[i])
			precision += precision_recall[0]
			recall += precision_recall[1]
			f1 = get_f1_score(precision_recall[0], precision_recall[1])
			f0_5 = get_f0_5_score(precision_recall[0], precision_recall[1])
			f2 = get_f2_score(precision_recall[0], precision_recall[1])

	acc = acc/(len(recommend))
	mrr = mrr/(len(recommend))
	precision = precision/(len(recommend))
	recall = recall/(len(recommend))
	f1 = f1/(len(recommend))
	f0_5 = f0_5/(len(recommend))
	f2 = f2/(len(recommend))
	return acc, mrr, precision, recall, f1, f0_5, f2

# %%
def get_recommendation(test_issue, issues, test_links):
  all_issues = list(issues.index)
  all_issues.remove(test_issue)

  test_links_1 = pd.DataFrame(
      {"key_1": [test_issue]*len(all_issues), "key_2": all_issues})
  test_links_1["link_id"] = test_links_1["key_1"] + "-" + test_links_1["key_2"]
  test_links_1 = test_links[test_links["link_id"].isin(test_links_1["link_id"].values)]
  pred_proba_1 = [(pred, issue) for pred, issue in zip(test_links_1["proba"].values, test_links_1["key_2"].values)]

  test_links_2 = pd.DataFrame(
      {"key_1": all_issues, "key_2": [test_issue]*len(all_issues)})
  test_links_2["link_id"] = test_links_2["key_1"] + "-" + test_links_2["key_2"]
  test_links_2 = test_links[test_links["link_id"].isin(test_links_2["link_id"].values)]
  pred_proba_2 = [(pred, issue) for pred, issue in zip(test_links_2["proba"].values, test_links_2["key_1"].values)]

  pred_proba_3 = pred_proba_1 + pred_proba_2
  preprocess_pred_proba = {}
  for pred, issue in pred_proba_3:
    if issue not in preprocess_pred_proba:
      preprocess_pred_proba[issue] = pred
    else:
      preprocess_pred_proba[issue] = max(pred, preprocess_pred_proba[issue])
  preprocess_pred_proba = [(pred, issue) for issue, pred in preprocess_pred_proba.items()]

  return [pair[1] for pair in sorted(preprocess_pred_proba, reverse=True)]

def filter_time(issues, test_issue, recommend_issues, days: int):
    cre_1 = issues["created"].loc[[test_issue]*len(recommend_issues)].values
    cre_2 = issues["created"].loc[recommend_issues].values
    cre_cre = np.abs(
        np.array((cre_1-cre_2) / np.timedelta64(1, 'D'), dtype=int))
    recommend_issues = [i for index, i in enumerate(
        recommend_issues) if cre_cre[index] <= days]
    return recommend_issues

# %%
test_links["proba"] = pred_proba[:,1]

# %%
test_links["link_id"] = test_links["key_1"] + "-" + test_links["key_2"]

# %%
recommend_results = []
for test_issue in tqdm(test_issues):
    recommend_results.append(get_recommendation(
        test_issue, issues, test_links))
# Out:
# 100%|██████████| 276/276 [00:16<00:00, 17.16it/s]

# %%
print("---No filter---")
for k in [1,2,3,5,10]:
  recommend_list = [i[:k] for i in recommend_results]
  acc, mrr, precision, recall, f1, f0_5, f2 = get_metrics(recommend_list, y_test)
  print(f"Top {k}:")
  print(f"Acc = {acc}")
  print(f"MRR = {mrr}")
  print(f"Recall = {recall}")
  print(f"F1 = {f1}")
  print(f"F0.5 = {f0_5}")
  print(f"F2 = {f2}")
# Out:
# ---No filter---
# Top 1:
# Acc = 0.050724637681159424
# MRR = 0.050724637681159424
# Recall = 0.050724637681159424
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 2:
# Acc = 0.10507246376811594
# MRR = 0.07789855072463768
# Recall = 0.10507246376811594
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 3:
# Acc = 0.11956521739130435
# MRR = 0.08272946859903381
# Recall = 0.11956521739130435
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 5:
# Acc = 0.16304347826086957
# MRR = 0.09214975845410625
# Recall = 0.16304347826086957
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 10:
# Acc = 0.213768115942029
# MRR = 0.09864849321371061
# Recall = 0.20954106280193238
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0

# %%
print("---60 days filter---")
filter_recommend_results = []
for test_issue, recommend_issues in zip(test_issues, recommend_results):
    filter_recommend_results.append(
        filter_time(issues, test_issue, recommend_issues, 60))
for k in [1,2,3,5,10]:
  recommend_list = [i[:k] for i in filter_recommend_results]
  acc, mrr, precision, recall, f1, f0_5, f2 = get_metrics(recommend_list, y_test)
  print(f"Top {k}:")
  print(f"Acc = {acc}")
  print(f"MRR = {mrr}")
  print(f"Recall = {recall}")
  print(f"F1 = {f1}")
  print(f"F0.5 = {f0_5}")
  print(f"F2 = {f2}")

print("---30 days filter---")
filter_recommend_results = []
for test_issue, recommend_issues in zip(test_issues, recommend_results):
    filter_recommend_results.append(
        filter_time(issues, test_issue, recommend_issues, 30))
for k in [1,2,3,5,10]:
  recommend_list = [i[:k] for i in filter_recommend_results]
  acc, mrr, precision, recall, f1, f0_5, f2 = get_metrics(recommend_list, y_test)
  print(f"Top {k}:")
  print(f"Acc = {acc}")
  print(f"MRR = {mrr}")
  print(f"Recall = {recall}")
  print(f"F1 = {f1}")
  print(f"F0.5 = {f0_5}")
  print(f"F2 = {f2}")
# Out:
# ---60 days filter---
# Top 1:
# Acc = 0.13405797101449277
# MRR = 0.13405797101449277
# Recall = 0.13405797101449277
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 2:
# Acc = 0.17028985507246377
# MRR = 0.15217391304347827
# Recall = 0.16847826086956522
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 3:
# Acc = 0.21014492753623187
# MRR = 0.16545893719806765
# Recall = 0.20652173913043478
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 5:
# Acc = 0.2463768115942029
# MRR = 0.17379227053140098
# Recall = 0.24094202898550723
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 10:
# Acc = 0.30434782608695654
# MRR = 0.18170002300437085
# Recall = 0.2922705314009662
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# ---30 days filter---
# Top 1:
# Acc = 0.15217391304347827
# MRR = 0.15217391304347827
# Recall = 0.15217391304347827
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 2:
# Acc = 0.2210144927536232
# MRR = 0.18659420289855072
# Recall = 0.2167874396135266
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 3:
# Acc = 0.2536231884057971
# MRR = 0.19746376811594205
# Recall = 0.24758454106280198
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 5:
# Acc = 0.27898550724637683
# MRR = 0.20398550724637685
# Recall = 0.2729468599033817
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 10:
# Acc = 0.3442028985507246
# MRR = 0.21337847941108823
# Recall = 0.3351449275362319
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
