# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %% [markdown]
# # Global

# %%
cd /content/drive/My Drive/IssuesManagement
# Out:
# /content/drive/.shortcut-targets-by-id/1Hgps4QuC_8w15htjlDJJFgm2WyvBtk5Y/IssuesManagement

# %%
import os
import pandas as pd
import numpy as np
import json
from tqdm import tqdm
import tensorflow as tf
import torch
import nltk
nltk.download('punkt')
from transformers import GPT2Tokenizer, GPT2LMHeadModel
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
PROJECT_NAME = "FLUME"

TEXT_FEATURES = ["title", "description", "summary"]
ADDING_TIME_FEATURES = ['CC', 'CU']

MAXLEN = 256
MODEL_NAME = "CNN"
EMBEDDING_METHOD = "GPT2"
DEVICE = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
GPT2_TOKENIZER = GPT2Tokenizer.from_pretrained("gpt2")
GPT2_TOKENIZER.add_special_tokens({'pad_token': '[PAD]'})
GPT2_MODEL = GPT2LMHeadModel.from_pretrained("gpt2")
GPT2_MODEL.resize_token_embeddings(len(GPT2_TOKENIZER))

EMBEDDING_MATRIX = GPT2_MODEL.transformer.wte.weight
HIDDEN_SIZE = EMBEDDING_MATRIX.shape[1]
def gpt2_tokenizer(sentences):
  X = GPT2_TOKENIZER(list(sentences), truncation=True, return_tensors='pt',padding='max_length', max_length=MAXLEN)
  return X.get('input_ids').numpy()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %% [markdown]
# # Load data

# %%
train_links = pd.read_csv(
    f"data/{PROJECT_NAME}/train_links.csv", keep_default_na=False)
train_links['label'] = train_links['label'].map(lambda x: int(x!=0))
issues = pd.read_csv(
    f"data/{PROJECT_NAME}/preprocessed_attributes.csv", index_col="key")
issues['created'] = pd.to_datetime(issues['created'], utc=True)
issues['updated'] = pd.to_datetime(issues['updated'], utc=True)
issues = issues.fillna(" ")
first_feature = TEXT_FEATURES[0]
issues["text"] = issues[first_feature]
if len(TEXT_FEATURES)>1:
  for feature in TEXT_FEATURES[1:]:
    issues["text"] = issues["text"] + " " + issues[feature]

# %% [markdown]
# # Filter model

# %%
test_links = pd.read_csv(
    f"data/{PROJECT_NAME}/test_links.csv", keep_default_na=False)
test_links['label'] = test_links['label'].map(lambda x: int(x!=0))

# %%
def filter_data(issues, links):
  issues_1 = links["key_1"].values
  issues_2 = links["key_2"].values
  cre_1 = issues.loc[issues_1]['created'].values
  cre_2 = issues.loc[issues_2]['created'].values
  links['date_gap'] = np.abs(np.array(
        (cre_1-cre_2) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1))
  return links[links['date_gap']<=30]

# %%
train_links = filter_data(issues, train_links)
test_links = filter_data(issues, test_links)

# %% [markdown]
# #Training

# %%
from pydantic import BaseModel

class ModelConfig(BaseModel):
  generate_batch_size: int
  mul: int
  adding_time_features: list
  mean_time_features: float
  std_time_features: float
  value_maxlen: int
  hidden_size: int
  number_units: int
  model_name: str
  learning_rate: float
  steps_per_epoch: int
  epochs: int

def generate_input(issues, train_links, config: ModelConfig):
    match_data = train_links[train_links["label"] != 0]
    none_data = train_links[train_links["label"] == 0]
    match_data = match_data[['key_1', "key_2"]].values
    none_data = none_data[['key_1', "key_2"]].values

    while True:
        each_size = int(config.generate_batch_size/2)

        # Shuffle index of match data
        shuffle_index = [index for index in np.random.choice(
            len(match_data), len(match_data), replace=False)]
        match_data = [match_data[index] for index in shuffle_index]

        for iter in range(int(len(match_data)/each_size)):
            # Split data by batch size and randomly select non_match_links: 1/2 for match data, 1/2 for non-match data

            # Get index
            match_index = np.array(range(iter*each_size, (iter+1)*each_size))
            none_index = np.array([index for index in np.random.choice(
                len(none_data), each_size*config.mul, replace=False)])

            match_links = [match_data[i] for i in match_index]
            none_links = [none_data[i] for i in none_index]

            # Create X by tokenizing and padding X
            index_pairs = np.array(match_links + none_links)
            text_1 = gpt2_tokenizer(issues["text"].loc[index_pairs[:,0]].values)
            text_2 = gpt2_tokenizer(issues["text"].loc[index_pairs[:,1]].values)

            # Create label y
            match_y = np.vstack(
                [np.zeros(len(match_links)), np.ones(len(match_links))]).T
            none_y = np.vstack([np.ones(len(none_links)), np.zeros(len(none_links))]).T
            y = np.concatenate([match_y, none_y])

            cre_1 = issues["created"].loc[index_pairs[:, 0]].values
            cre_2 = issues["created"].loc[index_pairs[:, 1]].values
            update = issues["updated"].loc[index_pairs[:, 1]].values
            cre_cre = np.array(
                (cre_1-cre_2) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)
            cre_up =  np.array(
                (cre_1-update) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)
            if len(config.adding_time_features) == 2:
                time_features = np.array(
                    [[cre_cre[i][0], cre_up[i][0]] for i in range(len(cre_cre))])
            elif "CC" in config.adding_time_features:
                time_features = cre_cre
            elif "CU" in config.adding_time_features:
                time_features = cre_up
            index = np.random.choice(len(index_pairs), config.generate_batch_size, replace=False)
            if len(config.adding_time_features) == 0:
                yield [text_1[index], text_2[index]], y[index]
            else:
                time_features = np.array(
                [(time_features[i]-config.mean_time_features)/config.std_time_features for i in range(len(time_features))])
                yield [text_1[index], text_2[index], time_features[index]], y[index]
    return 0

def return_model(config: ModelConfig):
  inputs_A = tf.keras.Input(shape=(config.value_maxlen), name="input_a")
  inputs_B = tf.keras.Input(shape=(config.value_maxlen), name="input_b")

  embedding_layer = tf.keras.layers.Embedding(input_dim=EMBEDDING_MATRIX.shape[0],
                 output_dim=EMBEDDING_MATRIX.shape[1],
                  embeddings_initializer = tf.keras.initializers.Constant(value=EMBEDDING_MATRIX),
                 mask_zero=True)
  embedding_layer.trainable=False
  # Embedding
  emb_A = embedding_layer(inputs_A)
  emb_B = embedding_layer(inputs_B)

  if len(ADDING_TIME_FEATURES)==1:
    inputs_C = tf.keras.Input(shape=(1), name="input_c")
  elif len(ADDING_TIME_FEATURES)==2:
    inputs_C = tf.keras.Input(shape=(2), name="input_c")

  # Deep Learning model's structure
  flatten_layer = tf.keras.layers.Flatten(name="flatten")
  dense_1_layer = tf.keras.layers.Dense(config.number_units, activation="relu", name="dense_1")
  output_layer = tf.keras.layers.Dense(2, activation="softmax", name="dense_output")

  if config.model_name=="CNN":
    core_layer = tf.keras.layers.Conv1D(config.number_units, 3, activation='relu')
  elif config.model_name=="LSTM":
    core_layer = tf.keras.layers.LSTM(config.number_units)
  else:
    core_layer = tf.keras.layers.GRU(config.number_units, name="gru")

  core_A = core_layer(emb_A)
  core_B = core_layer(emb_B)

  if len(ADDING_TIME_FEATURES)==0:

    # Concat two embedded inputs
    X = tf.concat([flatten_layer(core_A), flatten_layer(core_B)], axis=1)

    dense_1_X = dense_1_layer(X)

    outputs = output_layer(dense_1_X)

    model = tf.keras.Model(inputs=[inputs_A, inputs_B], outputs=outputs)

  else:

    # Concat two embedded inputs
    X = tf.concat([flatten_layer(core_A), flatten_layer(core_B), inputs_C], axis=1)

    dense_1_X = dense_1_layer(X)

    outputs = output_layer(dense_1_X)

    model = tf.keras.Model(inputs=[inputs_A, inputs_B, inputs_C], outputs=outputs)

  model.compile(tf.keras.optimizers.Adam(learning_rate=config.learning_rate), loss="mse", metrics=["categorical_accuracy"])
  model.summary()

  return model

def train_model(issues, train_links, config):
  model = return_model(config)
  history = model.fit(generate_input(issues, train_links, config),
              steps_per_epoch=config.steps_per_epoch,
              epochs=config.epochs,
              shuffle=False,
              verbose = 1)
  return model
# Out:
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_fields.py:151: UserWarning: Field "model_name" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
def get_normalize_parameter(issues, train_links):
    index_pairs = train_links[["key_1", "key_2"]].values
    cre_1 = issues["created"].loc[index_pairs[:, 0]].values
    cre_2 = issues["created"].loc[index_pairs[:, 1]].values
    update = issues["updated"].loc[index_pairs[:, 1]].values
    cre_cre = np.array((cre_1-cre_2) / np.timedelta64(1,
                       'D'), dtype=int).reshape(-1, 1)
    cre_up = np.array((cre_1-update) / np.timedelta64(1, 'D'),
                      dtype=int).reshape(-1, 1)
    if len(ADDING_TIME_FEATURES) == 2:
        time_features = np.array([[cre_cre[i][0], cre_up[i][0]]
                                 for i in range(len(cre_cre))])
    elif "CC" in ADDING_TIME_FEATURES:
        time_features = cre_cre
    elif "CU" in ADDING_TIME_FEATURES:
        time_features = cre_up
    else:
      time_features = [0]
    mean = np.mean(time_features)
    std = np.std(time_features)
    return mean, std

# %%
MEAN_TIME_FEATURES, STD_TIME_FEATURES = get_normalize_parameter(
    issues, train_links)
print(MEAN_TIME_FEATURES, STD_TIME_FEATURES)
# Out:
# -233.00655826558267 542.4283763595195

# %%
model_config = ModelConfig(
  model_name = MODEL_NAME,
  generate_batch_size = 128,
  mul = 3,
  adding_time_features = ADDING_TIME_FEATURES,
  mean_time_features = MEAN_TIME_FEATURES,
  std_time_features = STD_TIME_FEATURES,
  value_maxlen = MAXLEN,
  hidden_size = HIDDEN_SIZE,
  number_units = 256,
  learning_rate = 1e-3,
  steps_per_epoch = 5,
  epochs = 200)
with torch.no_grad():
  model = train_model(issues, train_links, model_config)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_a (InputLayer)        [(None, 256)]                0         []
#
#  input_b (InputLayer)        [(None, 256)]                0         []
#
#  embedding (Embedding)       (None, 256, 768)             3859814   ['input_a[0][0]',
#                                                           4          'input_b[0][0]']
#
#  conv1d (Conv1D)             (None, 254, 256)             590080    ['embedding[0][0]',
#                                                                      'embedding[1][0]']
#
#  flatten (Flatten)           (None, 65024)                0         ['conv1d[0][0]',
#                                                                      'conv1d[1][0]']
#
#  input_c (InputLayer)        [(None, 2)]                  0         []
#
#  tf.concat (TFOpLambda)      (None, 130050)               0         ['flatten[0][0]',
#                                                                      'flatten[1][0]',
#                                                                      'input_c[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  3329305   ['tf.concat[0][0]']
#                                                           6
#
#  dense_output (Dense)        (None, 2)                    514       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 72481794 (276.50 MB)
# Trainable params: 33883650 (129.26 MB)
# Non-trainable params: 38598144 (147.24 MB)
# __________________________________________________________________________________________________
# Epoch 1/200
# 5/5 [==============================] - 12s 760ms/step - loss: 0.2313 - categorical_accuracy: 0.6844
# Epoch 2/200
# 5/5 [==============================] - 5s 924ms/step - loss: 0.2547 - categorical_accuracy: 0.7453
# Epoch 3/200
# 5/5 [==============================] - 4s 673ms/step - loss: 0.2812 - categorical_accuracy: 0.7188
# Epoch 4/200
# 5/5 [==============================] - 3s 585ms/step - loss: 0.2484 - categorical_accuracy: 0.7516
# Epoch 5/200
# 5/5 [==============================] - 2s 406ms/step - loss: 0.2250 - categorical_accuracy: 0.7750
# Epoch 6/200
# 5/5 [==============================] - 2s 373ms/step - loss: 0.2594 - categorical_accuracy: 0.7406
# Epoch 7/200
# 5/5 [==============================] - 2s 354ms/step - loss: 0.2484 - categorical_accuracy: 0.7516
# Epoch 8/200
# 5/5 [==============================] - 2s 360ms/step - loss: 0.2500 - categorical_accuracy: 0.7500
# Epoch 9/200
# 5/5 [==============================] - 2s 365ms/step - loss: 0.2453 - categorical_accuracy: 0.7547
# Epoch 10/200
# 5/5 [==============================] - 2s 394ms/step - loss: 0.2250 - categorical_accuracy: 0.7750
# Epoch 11/200
# 5/5 [==============================] - 3s 584ms/step - loss: 0.2406 - categorical_accuracy: 0.7594
# Epoch 12/200
# 5/5 [==============================] - 2s 381ms/step - loss: 0.2562 - categorical_accuracy: 0.7437
# Epoch 13/200
# 5/5 [==============================] - 2s 367ms/step - loss: 0.2438 - categorical_accuracy: 0.7563
# Epoch 14/200
# 5/5 [==============================] - 2s 350ms/step - loss: 0.2594 - categorical_accuracy: 0.7406
# Epoch 15/200
# 5/5 [==============================] - 2s 357ms/step - loss: 0.2453 - categorical_accuracy: 0.7547
# Epoch 16/200
# 5/5 [==============================] - 2s 368ms/step - loss: 0.2391 - categorical_accuracy: 0.7609
# Epoch 17/200
# 5/5 [==============================] - 3s 599ms/step - loss: 0.2359 - categorical_accuracy: 0.7641
# Epoch 18/200
# 5/5 [==============================] - 2s 370ms/step - loss: 0.2469 - categorical_accuracy: 0.7531
# Epoch 19/200
# 5/5 [==============================] - 2s 370ms/step - loss: 0.2438 - categorical_accuracy: 0.7563
# Epoch 20/200
# 5/5 [==============================] - 2s 354ms/step - loss: 0.2391 - categorical_accuracy: 0.7609
# Epoch 21/200
# 5/5 [==============================] - 2s 350ms/step - loss: 0.2531 - categorical_accuracy: 0.7469
# Epoch 22/200
# 5/5 [==============================] - 2s 353ms/step - loss: 0.2391 - categorical_accuracy: 0.7609
# Epoch 23/200
# 5/5 [==============================] - 2s 405ms/step - loss: 0.2328 - categorical_accuracy: 0.7672
# Epoch 24/200
# 5/5 [==============================] - 3s 598ms/step - loss: 0.2672 - categorical_accuracy: 0.7328
# Epoch 25/200
# 5/5 [==============================] - 2s 355ms/step - loss: 0.2422 - categorical_accuracy: 0.7578
# Epoch 26/200
# 5/5 [==============================] - 2s 391ms/step - loss: 0.2328 - categorical_accuracy: 0.7672
# Epoch 27/200
# 5/5 [==============================] - 2s 356ms/step - loss: 0.2500 - categorical_accuracy: 0.7500
# Epoch 28/200
# 5/5 [==============================] - 2s 366ms/step - loss: 0.2547 - categorical_accuracy: 0.7453
# Epoch 29/200
# 5/5 [==============================] - 2s 362ms/step - loss: 0.2516 - categorical_accuracy: 0.7484
# Epoch 30/200
# 5/5 [==============================] - 3s 635ms/step - loss: 0.2484 - categorical_accuracy: 0.7516
# Epoch 31/200
# 5/5 [==============================] - 2s 367ms/step - loss: 0.2531 - categorical_accuracy: 0.7469
# Epoch 32/200
# 5/5 [==============================] - 2s 388ms/step - loss: 0.2594 - categorical_accuracy: 0.7406
# Epoch 33/200
# 5/5 [==============================] - 2s 350ms/step - loss: 0.2609 - categorical_accuracy: 0.7391
# Epoch 34/200
# 5/5 [==============================] - 2s 366ms/step - loss: 0.2484 - categorical_accuracy: 0.7516
# Epoch 35/200
# 5/5 [==============================] - 2s 351ms/step - loss: 0.2500 - categorical_accuracy: 0.7500
# Epoch 36/200
# 5/5 [==============================] - 2s 462ms/step - loss: 0.2297 - categorical_accuracy: 0.7703
# Epoch 37/200
# 5/5 [==============================] - 3s 524ms/step - loss: 0.2656 - categorical_accuracy: 0.7344
# Epoch 38/200
# 5/5 [==============================] - 2s 383ms/step - loss: 0.2313 - categorical_accuracy: 0.7688
# Epoch 39/200
# 5/5 [==============================] - 2s 394ms/step - loss: 0.2719 - categorical_accuracy: 0.7281
# Epoch 40/200
# 5/5 [==============================] - 2s 363ms/step - loss: 0.2672 - categorical_accuracy: 0.7328
# Epoch 41/200
# 5/5 [==============================] - 2s 352ms/step - loss: 0.2719 - categorical_accuracy: 0.7281
# Epoch 42/200
# 5/5 [==============================] - 2s 363ms/step - loss: 0.2578 - categorical_accuracy: 0.7422
# Epoch 43/200
# 5/5 [==============================] - 3s 663ms/step - loss: 0.2438 - categorical_accuracy: 0.7563
# Epoch 44/200
# 5/5 [==============================] - 2s 375ms/step - loss: 0.2516 - categorical_accuracy: 0.7484
# Epoch 45/200
# 5/5 [==============================] - 2s 351ms/step - loss: 0.2766 - categorical_accuracy: 0.7234
# Epoch 46/200
# 5/5 [==============================] - 2s 352ms/step - loss: 0.2406 - categorical_accuracy: 0.7594
# Epoch 47/200
# 5/5 [==============================] - 3s 538ms/step - loss: 0.2547 - categorical_accuracy: 0.7453
# Epoch 48/200
# 5/5 [==============================] - 2s 358ms/step - loss: 0.2531 - categorical_accuracy: 0.7469
# Epoch 49/200
# 5/5 [==============================] - 3s 568ms/step - loss: 0.2516 - categorical_accuracy: 0.7484
# Epoch 50/200
# 5/5 [==============================] - 2s 412ms/step - loss: 0.2297 - categorical_accuracy: 0.7703
# Epoch 51/200
# 5/5 [==============================] - 2s 370ms/step - loss: 0.2594 - categorical_accuracy: 0.7406
# Epoch 52/200
# 5/5 [==============================] - 2s 344ms/step - loss: 0.2516 - categorical_accuracy: 0.7484
# Epoch 53/200
# 5/5 [==============================] - 2s 352ms/step - loss: 0.2453 - categorical_accuracy: 0.7547
# Epoch 54/200
# 5/5 [==============================] - 2s 351ms/step - loss: 0.2547 - categorical_accuracy: 0.7453
# Epoch 55/200
# 5/5 [==============================] - 2s 381ms/step - loss: 0.2469 - categorical_accuracy: 0.7531
# Epoch 56/200
# 5/5 [==============================] - 3s 609ms/step - loss: 0.2313 - categorical_accuracy: 0.7688
# Epoch 57/200
# 5/5 [==============================] - 2s 370ms/step - loss: 0.2250 - categorical_accuracy: 0.7750
# Epoch 58/200
# 5/5 [==============================] - 2s 359ms/step - loss: 0.2328 - categorical_accuracy: 0.7672
# Epoch 59/200
# 5/5 [==============================] - 2s 346ms/step - loss: 0.2562 - categorical_accuracy: 0.7437
# Epoch 60/200
# 5/5 [==============================] - 2s 363ms/step - loss: 0.2422 - categorical_accuracy: 0.7578
# Epoch 61/200
# 5/5 [==============================] - 2s 346ms/step - loss: 0.2672 - categorical_accuracy: 0.7328
# Epoch 62/200
# 5/5 [==============================] - 2s 504ms/step - loss: 0.2469 - categorical_accuracy: 0.7531
# Epoch 63/200
# 5/5 [==============================] - 2s 481ms/step - loss: 0.2562 - categorical_accuracy: 0.7437
# Epoch 64/200
# 5/5 [==============================] - 2s 363ms/step - loss: 0.2484 - categorical_accuracy: 0.7516
# Epoch 65/200
# 5/5 [==============================] - 2s 361ms/step - loss: 0.2859 - categorical_accuracy: 0.7141
# Epoch 66/200
# 5/5 [==============================] - 2s 372ms/step - loss: 0.2625 - categorical_accuracy: 0.7375
# Epoch 67/200
# 5/5 [==============================] - 2s 384ms/step - loss: 0.2344 - categorical_accuracy: 0.7656
# Epoch 68/200
# 5/5 [==============================] - 2s 363ms/step - loss: 0.2547 - categorical_accuracy: 0.7453
# Epoch 69/200
# 5/5 [==============================] - 3s 647ms/step - loss: 0.2625 - categorical_accuracy: 0.7375
# Epoch 70/200
# 5/5 [==============================] - 2s 358ms/step - loss: 0.2438 - categorical_accuracy: 0.7563
# Epoch 71/200
# 5/5 [==============================] - 2s 367ms/step - loss: 0.2469 - categorical_accuracy: 0.7531
# Epoch 72/200
# 5/5 [==============================] - 2s 346ms/step - loss: 0.2609 - categorical_accuracy: 0.7391
# Epoch 73/200
# 5/5 [==============================] - 2s 354ms/step - loss: 0.2453 - categorical_accuracy: 0.7547
# Epoch 74/200
# 5/5 [==============================] - 2s 377ms/step - loss: 0.2422 - categorical_accuracy: 0.7578
# Epoch 75/200
# 5/5 [==============================] - 2s 484ms/step - loss: 0.2641 - categorical_accuracy: 0.7359
# Epoch 76/200
# 5/5 [==============================] - 3s 506ms/step - loss: 0.2547 - categorical_accuracy: 0.7453
# Epoch 77/200
# 5/5 [==============================] - 2s 368ms/step - loss: 0.2219 - categorical_accuracy: 0.7781
# Epoch 78/200
# 5/5 [==============================] - 2s 361ms/step - loss: 0.2531 - categorical_accuracy: 0.7469
# Epoch 79/200
# 5/5 [==============================] - 2s 359ms/step - loss: 0.2438 - categorical_accuracy: 0.7563
# Epoch 80/200
# 5/5 [==============================] - 2s 351ms/step - loss: 0.2578 - categorical_accuracy: 0.7422
# Epoch 81/200
# 5/5 [==============================] - 2s 357ms/step - loss: 0.2500 - categorical_accuracy: 0.7500
# Epoch 82/200
# 5/5 [==============================] - 3s 631ms/step - loss: 0.2109 - categorical_accuracy: 0.7891
# Epoch 83/200
# 5/5 [==============================] - 2s 408ms/step - loss: 0.2625 - categorical_accuracy: 0.7375
# Epoch 84/200
# 5/5 [==============================] - 3s 509ms/step - loss: 0.2672 - categorical_accuracy: 0.7328
# Epoch 85/200
# 5/5 [==============================] - 2s 379ms/step - loss: 0.2547 - categorical_accuracy: 0.7453
# Epoch 86/200
# 5/5 [==============================] - 2s 341ms/step - loss: 0.2453 - categorical_accuracy: 0.7547
# Epoch 87/200
# 5/5 [==============================] - 2s 354ms/step - loss: 0.2438 - categorical_accuracy: 0.7563
# Epoch 88/200
# 5/5 [==============================] - 3s 639ms/step - loss: 0.2766 - categorical_accuracy: 0.7234
# Epoch 89/200
# 5/5 [==============================] - 2s 365ms/step - loss: 0.2313 - categorical_accuracy: 0.7688
# Epoch 90/200
# 5/5 [==============================] - 2s 373ms/step - loss: 0.2438 - categorical_accuracy: 0.7563
# Epoch 91/200
# 5/5 [==============================] - 2s 350ms/step - loss: 0.2594 - categorical_accuracy: 0.7406
# Epoch 92/200
# 5/5 [==============================] - 2s 382ms/step - loss: 0.2578 - categorical_accuracy: 0.7422
# Epoch 93/200
# 5/5 [==============================] - 2s 356ms/step - loss: 0.2609 - categorical_accuracy: 0.7391
# Epoch 94/200
# 5/5 [==============================] - 2s 482ms/step - loss: 0.2281 - categorical_accuracy: 0.7719
# Epoch 95/200
# 5/5 [==============================] - 3s 505ms/step - loss: 0.2406 - categorical_accuracy: 0.7594
# Epoch 96/200
# 5/5 [==============================] - 2s 356ms/step - loss: 0.2484 - categorical_accuracy: 0.7516
# Epoch 97/200
# 5/5 [==============================] - 2s 349ms/step - loss: 0.2484 - categorical_accuracy: 0.7516
# Epoch 98/200
# 5/5 [==============================] - 2s 350ms/step - loss: 0.2656 - categorical_accuracy: 0.7344
# Epoch 99/200
# 5/5 [==============================] - 2s 372ms/step - loss: 0.2688 - categorical_accuracy: 0.7312
# Epoch 100/200
# 5/5 [==============================] - 2s 355ms/step - loss: 0.2500 - categorical_accuracy: 0.7500
# Epoch 101/200
# 5/5 [==============================] - 3s 644ms/step - loss: 0.2375 - categorical_accuracy: 0.7625
# Epoch 102/200
# 5/5 [==============================] - 2s 377ms/step - loss: 0.2531 - categorical_accuracy: 0.7469
# Epoch 103/200
# 5/5 [==============================] - 2s 365ms/step - loss: 0.2516 - categorical_accuracy: 0.7484
# Epoch 104/200
# 5/5 [==============================] - 2s 356ms/step - loss: 0.2484 - categorical_accuracy: 0.7516
# Epoch 105/200
# 5/5 [==============================] - 2s 374ms/step - loss: 0.2250 - categorical_accuracy: 0.7750
# Epoch 106/200
# 5/5 [==============================] - 2s 355ms/step - loss: 0.2328 - categorical_accuracy: 0.7672
# Epoch 107/200
# 5/5 [==============================] - 2s 450ms/step - loss: 0.2344 - categorical_accuracy: 0.7656
# Epoch 108/200
# 5/5 [==============================] - 3s 553ms/step - loss: 0.2656 - categorical_accuracy: 0.7344
# Epoch 109/200
# 5/5 [==============================] - 2s 351ms/step - loss: 0.2438 - categorical_accuracy: 0.7563
# Epoch 110/200
# 5/5 [==============================] - 2s 449ms/step - loss: 0.2391 - categorical_accuracy: 0.7609
# Epoch 111/200
# 5/5 [==============================] - 2s 366ms/step - loss: 0.2391 - categorical_accuracy: 0.7609
# Epoch 112/200
# 5/5 [==============================] - 2s 380ms/step - loss: 0.2219 - categorical_accuracy: 0.7781
# Epoch 113/200
# 5/5 [==============================] - 2s 378ms/step - loss: 0.2641 - categorical_accuracy: 0.7359
# Epoch 114/200
# 5/5 [==============================] - 3s 662ms/step - loss: 0.2344 - categorical_accuracy: 0.7656
# Epoch 115/200
# 5/5 [==============================] - 2s 356ms/step - loss: 0.2484 - categorical_accuracy: 0.7516
# Epoch 116/200
# 5/5 [==============================] - 2s 369ms/step - loss: 0.2594 - categorical_accuracy: 0.7406
# Epoch 117/200
# 5/5 [==============================] - 2s 365ms/step - loss: 0.2516 - categorical_accuracy: 0.7484
# Epoch 118/200
# 5/5 [==============================] - 2s 362ms/step - loss: 0.2406 - categorical_accuracy: 0.7594
# Epoch 119/200
# 5/5 [==============================] - 2s 368ms/step - loss: 0.2578 - categorical_accuracy: 0.7422
# Epoch 120/200
# 5/5 [==============================] - 3s 583ms/step - loss: 0.2656 - categorical_accuracy: 0.7344
# Epoch 121/200
# 5/5 [==============================] - 2s 430ms/step - loss: 0.2516 - categorical_accuracy: 0.7484
# Epoch 122/200
# 5/5 [==============================] - 2s 350ms/step - loss: 0.2578 - categorical_accuracy: 0.7422
# Epoch 123/200
# 5/5 [==============================] - 2s 371ms/step - loss: 0.2547 - categorical_accuracy: 0.7453
# Epoch 124/200
# 5/5 [==============================] - 2s 355ms/step - loss: 0.2297 - categorical_accuracy: 0.7703
# Epoch 125/200
# 5/5 [==============================] - 2s 358ms/step - loss: 0.2688 - categorical_accuracy: 0.7312
# Epoch 126/200
# 5/5 [==============================] - 2s 432ms/step - loss: 0.2688 - categorical_accuracy: 0.7312
# Epoch 127/200
# 5/5 [==============================] - 3s 580ms/step - loss: 0.2531 - categorical_accuracy: 0.7469
# Epoch 128/200
# 5/5 [==============================] - 2s 357ms/step - loss: 0.2453 - categorical_accuracy: 0.7547
# Epoch 129/200
# 5/5 [==============================] - 2s 386ms/step - loss: 0.2562 - categorical_accuracy: 0.7437
# Epoch 130/200
# 5/5 [==============================] - 2s 393ms/step - loss: 0.2562 - categorical_accuracy: 0.7437
# Epoch 131/200
# 5/5 [==============================] - 2s 357ms/step - loss: 0.2766 - categorical_accuracy: 0.7234
# Epoch 132/200
# 5/5 [==============================] - 2s 369ms/step - loss: 0.2516 - categorical_accuracy: 0.7484
# Epoch 133/200
# 5/5 [==============================] - 3s 621ms/step - loss: 0.2562 - categorical_accuracy: 0.7437
# Epoch 134/200
# 5/5 [==============================] - 2s 373ms/step - loss: 0.2500 - categorical_accuracy: 0.7500
# Epoch 135/200
# 5/5 [==============================] - 2s 364ms/step - loss: 0.2375 - categorical_accuracy: 0.7625
# Epoch 136/200
# 5/5 [==============================] - 2s 359ms/step - loss: 0.2594 - categorical_accuracy: 0.7406
# Epoch 137/200
# 5/5 [==============================] - 2s 362ms/step - loss: 0.2438 - categorical_accuracy: 0.7563
# Epoch 138/200
# 5/5 [==============================] - 2s 399ms/step - loss: 0.2219 - categorical_accuracy: 0.7781
# Epoch 139/200
# 5/5 [==============================] - 2s 498ms/step - loss: 0.2250 - categorical_accuracy: 0.7750
# Epoch 140/200
# 5/5 [==============================] - 3s 514ms/step - loss: 0.2359 - categorical_accuracy: 0.7641
# Epoch 141/200
# 5/5 [==============================] - 2s 370ms/step - loss: 0.2406 - categorical_accuracy: 0.7594
# Epoch 142/200
# 5/5 [==============================] - 2s 352ms/step - loss: 0.2562 - categorical_accuracy: 0.7437
# Epoch 143/200
# 5/5 [==============================] - 2s 362ms/step - loss: 0.2516 - categorical_accuracy: 0.7484
# Epoch 144/200
# 5/5 [==============================] - 2s 353ms/step - loss: 0.2547 - categorical_accuracy: 0.7453
# Epoch 145/200
# 5/5 [==============================] - 2s 371ms/step - loss: 0.2406 - categorical_accuracy: 0.7594
# Epoch 146/200
# 5/5 [==============================] - 3s 669ms/step - loss: 0.2656 - categorical_accuracy: 0.7344
# Epoch 147/200
# 5/5 [==============================] - 2s 359ms/step - loss: 0.2578 - categorical_accuracy: 0.7422
# Epoch 148/200
# 5/5 [==============================] - 2s 361ms/step - loss: 0.2641 - categorical_accuracy: 0.7359
# Epoch 149/200
# 5/5 [==============================] - 2s 389ms/step - loss: 0.2500 - categorical_accuracy: 0.7500
# Epoch 150/200
# 5/5 [==============================] - 2s 370ms/step - loss: 0.2328 - categorical_accuracy: 0.7672
# Epoch 151/200
# 5/5 [==============================] - 2s 358ms/step - loss: 0.2500 - categorical_accuracy: 0.7500
# Epoch 152/200
# 5/5 [==============================] - 3s 542ms/step - loss: 0.2672 - categorical_accuracy: 0.7328
# Epoch 153/200
# 5/5 [==============================] - 3s 455ms/step - loss: 0.2562 - categorical_accuracy: 0.7437
# Epoch 154/200
# 5/5 [==============================] - 2s 366ms/step - loss: 0.2438 - categorical_accuracy: 0.7563
# Epoch 155/200
# 5/5 [==============================] - 2s 366ms/step - loss: 0.2641 - categorical_accuracy: 0.7359
# Epoch 156/200
# 5/5 [==============================] - 2s 359ms/step - loss: 0.2516 - categorical_accuracy: 0.7484
# Epoch 157/200
# 5/5 [==============================] - 2s 376ms/step - loss: 0.2266 - categorical_accuracy: 0.7734
# Epoch 158/200
# 5/5 [==============================] - 2s 383ms/step - loss: 0.2484 - categorical_accuracy: 0.7516
# Epoch 159/200
# 5/5 [==============================] - 3s 626ms/step - loss: 0.2484 - categorical_accuracy: 0.7516
# Epoch 160/200
# 5/5 [==============================] - 2s 379ms/step - loss: 0.2500 - categorical_accuracy: 0.7500
# Epoch 161/200
# 5/5 [==============================] - 2s 366ms/step - loss: 0.2359 - categorical_accuracy: 0.7641
# Epoch 162/200
# 5/5 [==============================] - 2s 353ms/step - loss: 0.2250 - categorical_accuracy: 0.7750
# Epoch 163/200
# 5/5 [==============================] - 2s 351ms/step - loss: 0.2453 - categorical_accuracy: 0.7547
# Epoch 164/200
# 5/5 [==============================] - 2s 370ms/step - loss: 0.2688 - categorical_accuracy: 0.7312
# Epoch 165/200
# 5/5 [==============================] - 3s 562ms/step - loss: 0.2500 - categorical_accuracy: 0.7500
# Epoch 166/200
# 5/5 [==============================] - 2s 425ms/step - loss: 0.2531 - categorical_accuracy: 0.7469
# Epoch 167/200
# 5/5 [==============================] - 2s 356ms/step - loss: 0.2453 - categorical_accuracy: 0.7547
# Epoch 168/200
# 5/5 [==============================] - 2s 356ms/step - loss: 0.2328 - categorical_accuracy: 0.7672
# Epoch 169/200
# 5/5 [==============================] - 2s 381ms/step - loss: 0.2500 - categorical_accuracy: 0.7500
# Epoch 170/200
# 5/5 [==============================] - 2s 365ms/step - loss: 0.2500 - categorical_accuracy: 0.7500
# Epoch 171/200
# 5/5 [==============================] - 2s 412ms/step - loss: 0.2656 - categorical_accuracy: 0.7344
# Epoch 172/200
# 5/5 [==============================] - 3s 576ms/step - loss: 0.2422 - categorical_accuracy: 0.7578
# Epoch 173/200
# 5/5 [==============================] - 2s 369ms/step - loss: 0.2469 - categorical_accuracy: 0.7531
# Epoch 174/200
# 5/5 [==============================] - 2s 350ms/step - loss: 0.2672 - categorical_accuracy: 0.7328
# Epoch 175/200
# 5/5 [==============================] - 2s 365ms/step - loss: 0.2297 - categorical_accuracy: 0.7703
# Epoch 176/200
# 5/5 [==============================] - 2s 378ms/step - loss: 0.2344 - categorical_accuracy: 0.7656
# Epoch 177/200
# 5/5 [==============================] - 2s 378ms/step - loss: 0.2469 - categorical_accuracy: 0.7531
# Epoch 178/200
# 5/5 [==============================] - 3s 600ms/step - loss: 0.2500 - categorical_accuracy: 0.7500
# Epoch 179/200
# 5/5 [==============================] - 2s 371ms/step - loss: 0.2594 - categorical_accuracy: 0.7406
# Epoch 180/200
# 5/5 [==============================] - 2s 362ms/step - loss: 0.2469 - categorical_accuracy: 0.7531
# Epoch 181/200
# 5/5 [==============================] - 2s 369ms/step - loss: 0.2328 - categorical_accuracy: 0.7672
# Epoch 182/200
# 5/5 [==============================] - 2s 346ms/step - loss: 0.2422 - categorical_accuracy: 0.7578
# Epoch 183/200
# 5/5 [==============================] - 2s 369ms/step - loss: 0.2516 - categorical_accuracy: 0.7484
# Epoch 184/200
# 5/5 [==============================] - 2s 427ms/step - loss: 0.2266 - categorical_accuracy: 0.7734
# Epoch 185/200
# 5/5 [==============================] - 3s 566ms/step - loss: 0.2297 - categorical_accuracy: 0.7703
# Epoch 186/200
# 5/5 [==============================] - 2s 377ms/step - loss: 0.2812 - categorical_accuracy: 0.7188
# Epoch 187/200
# 5/5 [==============================] - 2s 369ms/step - loss: 0.2484 - categorical_accuracy: 0.7516
# Epoch 188/200
# 5/5 [==============================] - 2s 356ms/step - loss: 0.2641 - categorical_accuracy: 0.7359
# Epoch 189/200
# 5/5 [==============================] - 2s 366ms/step - loss: 0.2453 - categorical_accuracy: 0.7547
# Epoch 190/200
# 5/5 [==============================] - 2s 372ms/step - loss: 0.2578 - categorical_accuracy: 0.7422
# Epoch 191/200
# 5/5 [==============================] - 3s 609ms/step - loss: 0.2328 - categorical_accuracy: 0.7672
# Epoch 192/200
# 5/5 [==============================] - 2s 388ms/step - loss: 0.2375 - categorical_accuracy: 0.7625
# Epoch 193/200
# 5/5 [==============================] - 2s 349ms/step - loss: 0.2422 - categorical_accuracy: 0.7578
# Epoch 194/200
# 5/5 [==============================] - 2s 342ms/step - loss: 0.2562 - categorical_accuracy: 0.7437
# Epoch 195/200
# 5/5 [==============================] - 2s 355ms/step - loss: 0.2453 - categorical_accuracy: 0.7547
# Epoch 196/200
# 5/5 [==============================] - 2s 358ms/step - loss: 0.2625 - categorical_accuracy: 0.7375
# Epoch 197/200
# 5/5 [==============================] - 2s 367ms/step - loss: 0.2484 - categorical_accuracy: 0.7516
# Epoch 198/200
# 5/5 [==============================] - 3s 629ms/step - loss: 0.2578 - categorical_accuracy: 0.7422
# Epoch 199/200
# 5/5 [==============================] - 2s 362ms/step - loss: 0.2359 - categorical_accuracy: 0.7641
# Epoch 200/200
# 5/5 [==============================] - 2s 369ms/step - loss: 0.2594 - categorical_accuracy: 0.7406

# %% [markdown]
# # Test

# %%
from torch.utils.data import Dataset,  DataLoader
class TestDataset(Dataset):
    def __init__(self, index_pairs, labels):
        self.index_pairs = index_pairs
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
      return [self.index_pairs[idx,0], self.index_pairs[idx,1]], self.labels[idx]

# %%
def get_predict(issues, index_pairs, config, model):
  text_1 = gpt2_tokenizer(issues["text"].loc[index_pairs[0]].values)
  text_2 = gpt2_tokenizer(issues["text"].loc[index_pairs[1]].values)
  cre_1 = issues["created"].loc[index_pairs[0]].values
  cre_2 = issues["created"].loc[index_pairs[1]].values
  update = issues["updated"].loc[index_pairs[1]].values
  cre_cre = np.array(
      (cre_1-cre_2) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)
  cre_up =  np.array(
      (cre_1-update) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)

  if len(config.adding_time_features) == 2:
      time_features = np.array(
          [[cre_cre[i][0], cre_up[i][0]] for i in range(len(cre_cre))])
  elif "CC" in config.adding_time_features:
      time_features = cre_cre
  elif "CU" in config.adding_time_features:
      time_features = cre_up
  else:
    return model([text_1, text_2])
  if len(config.adding_time_features) > 0:
    time_features = np.array(
        [(time_features[i]-config.mean_time_features)/config.std_time_features for i in range(len(time_features))])
  return model([text_1, text_2, time_features])

# %%
labels = []
for i in test_links["label"].values:
  if i==0:
    labels.append([1,0])
  else:
    labels.append([0,1])
test_data = TestDataset(test_links[["key_1", "key_2"]].values, labels)

# %%
test_dataloader = DataLoader(test_data, batch_size=512)
len(test_dataloader)
# Out:
# 32

# %%
if not os.path.exists(f"results_{EMBEDDING_METHOD}_{PROJECT_NAME}"):
  os.mkdir(f"results_{EMBEDDING_METHOD}_{PROJECT_NAME}")

# %%
for index, i in enumerate(test_dataloader):
  index_pairs, label = i
  index_pairs[0] = np.array( index_pairs[0])
  index_pairs[1] = np.array( index_pairs[1])
  proba = get_predict(issues, index_pairs, model_config, model)
  print(f"{index}/{len(test_dataloader)}")
  if index==0:
    pred_proba = proba
    continue
  pred_proba=np.concatenate([pred_proba, proba])
# Out:
# 0/32
# 1/32
# 2/32
# 3/32
# 4/32
# 5/32
# 6/32
# 7/32
# 8/32
# 9/32
# 10/32
# 11/32
# 12/32
# 13/32
# 14/32
# 15/32
# 16/32
# 17/32
# 18/32
# 19/32
# 20/32
# 21/32
# 22/32
# 23/32
# 24/32
# 25/32
# 26/32
# 27/32
# 28/32
# 29/32
# 30/32
# 31/32

# %%
y_s = [np.argmax(i) for i in labels]
pred_s = [np.argmax(i) for i in pred_proba]

# %%
from sklearn.metrics import confusion_matrix, classification_report
print("Confusion maxtrix")
print(confusion_matrix(y_s, pred_s))
print(classification_report(y_s, pred_s, digits= 2))
# Out:
# Confusion maxtrix
# [[15846     0]
#  [  126     0]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     15846
#            1       0.00      0.00      0.00       126
#
#     accuracy                           0.99     15972
#    macro avg       0.50      0.50      0.50     15972
# weighted avg       0.98      0.99      0.99     15972
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Recommend

# %%
match_test_links = test_links[test_links["label"]!=0]

# %%
test_issues = pd.read_csv(f"data/{PROJECT_NAME}/test_issues.csv", index_col="key").index

y_test = []
filter_test_issues = []
for test_issue in tqdm(test_issues):
  filter_links = match_test_links[(match_test_links["key_1"]==test_issue)|(match_test_links["key_2"]==test_issue)]
  if len(filter_links)>0:
    match_issues = set(list(filter_links["key_1"].values) + list(filter_links["key_2"].values))
    match_issues.remove(test_issue)
    y_test.append(list(match_issues))
    filter_test_issues.append(test_issue)
test_issues = filter_test_issues
# Out:
# 100%|██████████| 276/276 [00:00<00:00, 1484.41it/s]

# %%
len(test_issues)
# Out:
# 154

# %%
def get_accuracy(pred, gt):
	acc = 0
	for i, item in enumerate(pred):
		if item in gt:
			acc += 1.0
			break
	return acc

def get_MRR(pred, gt):
	mrr = 0
	for i, item in enumerate(pred):
		if item in gt:
			mrr += 1.0/(i+1)
	return mrr

def get_precision_recall(pred, gt):
	right = 0

	for item in gt:
		if item in pred: # relevant
			right+=1

	if len(pred) == 0:
		precision = 0
	else:
		precision = right/len(pred)
	recall = right/len(gt)

	return precision, recall

def get_f1_score(precision, recall):
    if precision + recall == 0:
        return 0
    f1_score = 2 * (precision * recall) / (precision + recall)
    return f1_score

def get_metrics(recommend, label):
	acc = 0
	mrr = 0
	precision = 0
	recall = 0
	f1 = 0
	for i in range(0, len(recommend)):
		if len(label[i])!=0:
			acc += get_accuracy(recommend[i], label[i])
			mrr += get_MRR(recommend[i], label[i])
			precision_recall = get_precision_recall(recommend[i], label[i])
			precision += precision_recall[0]
			recall += precision_recall[1]
			f1 = get_f1_score(precision_recall[0], precision_recall[1])

	acc = acc/(len(recommend))
	mrr = mrr/(len(recommend))
	precision = precision/(len(recommend))
	recall = recall/(len(recommend))
	f1 = f1/(len(recommend))
	return acc, mrr, precision, recall, f1

# %%
def get_recommendation(test_issue, issues, test_links):
  all_issues = list(issues.index)
  all_issues.remove(test_issue)

  test_links_1 = pd.DataFrame(
      {"key_1": [test_issue]*len(all_issues), "key_2": all_issues})
  test_links_1["link_id"] = test_links_1["key_1"] + "-" + test_links_1["key_2"]
  test_links_1 = test_links[test_links["link_id"].isin(test_links_1["link_id"].values)]
  pred_proba_1 = [(pred, issue) for pred, issue in zip(test_links_1["proba"].values, test_links_1["key_2"].values)]

  test_links_2 = pd.DataFrame(
      {"key_1": all_issues, "key_2": [test_issue]*len(all_issues)})
  test_links_2["link_id"] = test_links_2["key_1"] + "-" + test_links_2["key_2"]
  test_links_2 = test_links[test_links["link_id"].isin(test_links_2["link_id"].values)]
  pred_proba_2 = [(pred, issue) for pred, issue in zip(test_links_2["proba"].values, test_links_2["key_1"].values)]

  pred_proba_3 = pred_proba_1 + pred_proba_2
  preprocess_pred_proba = {}
  for pred, issue in pred_proba_3:
    if issue not in preprocess_pred_proba:
      preprocess_pred_proba[issue] = pred
    else:
      preprocess_pred_proba[issue] = max(pred, preprocess_pred_proba[issue])
  preprocess_pred_proba = [(pred, issue) for issue, pred in preprocess_pred_proba.items()]

  return [pair[1] for pair in sorted(preprocess_pred_proba, reverse=True)]

# %%
test_links["proba"] = pred_proba[:,1]

# %%
test_links["link_id"] = test_links["key_1"] + "-" + test_links["key_2"]

# %%
recommend_results = []
for test_issue in tqdm(test_issues):
    recommend_results.append(get_recommendation(
        test_issue, issues, test_links))
# Out:
# 100%|██████████| 154/154 [00:01<00:00, 138.11it/s]

# %%
for k in [1,2,3,5,10]:
  recommend_list = [i[:k] for i in recommend_results]
  acc, mrr, precision, recall, f1 = get_metrics(recommend_list, y_test)
  print(f"Top {k}:")
  print(f"Acc = {acc}")
  print(f"MRR = {mrr}")
  print(f"Recall = {recall}")
  print(f"F1 = {f1}")
# Out:
# Top 1:
# Acc = 0.025974025974025976
# MRR = 0.025974025974025976
# Recall = 0.025974025974025976
# F1 = 0.0
# Top 2:
# Acc = 0.05844155844155844
# MRR = 0.04220779220779221
# Recall = 0.054112554112554105
# F1 = 0.004329004329004329
# Top 3:
# Acc = 0.05844155844155844
# MRR = 0.04220779220779221
# Recall = 0.054112554112554105
# F1 = 0.003246753246753247
# Top 5:
# Acc = 0.11688311688311688
# MRR = 0.05714285714285715
# Recall = 0.1147186147186147
# F1 = 0.002164502164502165
# Top 10:
# Acc = 0.2532467532467532
# MRR = 0.07695320552463404
# Recall = 0.25108225108225113
# F1 = 0.001443001443001443
