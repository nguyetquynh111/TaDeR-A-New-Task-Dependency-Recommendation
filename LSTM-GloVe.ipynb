# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Global

# %%
cd /content/drive/My Drive/IssuesManagement
# Out:
# /content/drive/.shortcut-targets-by-id/1Hgps4QuC_8w15htjlDJJFgm2WyvBtk5Y/IssuesManagement

# %%
import os
import pandas as pd
import numpy as np
import json
from tqdm import tqdm
import tensorflow as tf
import torch
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
PROJECT_NAME = "FLUME"

TEXT_FEATURES = ["title", "description", "summary"]
ADDING_TIME_FEATURES = ["CC", "CU"]

MAXLEN = 256
MODEL_NAME = "LSTM"
EMBEDDING_METHOD = "GloVe"
DEVICE = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
# Load GloVe pretrained model
__PADDED_INDEX__ = 0
__UNKNOWN_WORD__ = 1

def load_word_embeddings(fname):
    wordvecs = {}
    with open(fname, 'r') as file:
        lines = file.readlines()
        for line in lines:
            tokens = line.split(' ')
            vec = np.array(tokens[1:], dtype=np.float32)
            wordvecs[tokens[0]] = vec

    return wordvecs

if not os.path.exists("GloVe_embedding_matrix.npy"):
  wordvecs = load_word_embeddings("glove.42B.300d.txt")
  vocab = wordvecs.keys()
  matrix = list(wordvecs.values())
  WORD2INDEX = {word: index+2 for index, word in enumerate(vocab)}
  EMBEDDING_MATRIX = np.pad(matrix, [[2,0],[0,0]], mode='constant', constant_values =0.0)
  np.save("GloVe_embedding_matrix.npy", EMBEDDING_MATRIX)
  with open("GloVe_word_to_index.json", "w") as f:
    json.dump(WORD2INDEX, f)
else:
  EMBEDDING_MATRIX = np.load("GloVe_embedding_matrix.npy")
  with open("GloVe_word_to_index.json", "r") as f:
    WORD2INDEX = json.load(f)
EMBEDDING_MATRIX = torch.tensor(EMBEDDING_MATRIX)
HIDDEN_SIZE = EMBEDDING_MATRIX.shape[1]

def glove_tokenizer(sentences):
  tokenized_texts = [nltk.tokenize.word_tokenize(text) for text in sentences]
  X = []
  for text in tokenized_texts:
    cur_text_indices = []
    for word in text:
      if word in WORD2INDEX:
          cur_text_indices.append(WORD2INDEX[word])
      else:
          cur_text_indices.append(__UNKNOWN_WORD__)
    X.append(cur_text_indices)
  return X

# %% [markdown]
# # Load data

# %%
train_links = pd.read_csv(
    f"data/{PROJECT_NAME}/train_links.csv", keep_default_na=False)
train_links['label'] = train_links['label'].map(lambda x: int(x!=0))
issues = pd.read_csv(
    f"data/{PROJECT_NAME}/preprocessed_attributes.csv", index_col="key")
issues['created'] = pd.to_datetime(issues['created'], utc=True)
issues['updated'] = pd.to_datetime(issues['updated'], utc=True)
issues = issues.fillna(" ")
first_feature = TEXT_FEATURES[0]
issues["text"] = issues[first_feature]
if len(TEXT_FEATURES)>1:
  for feature in TEXT_FEATURES[1:]:
    issues["text"] = issues["text"] + " " + issues[feature]

# %% [markdown]
# #Training

# %%
from pydantic import BaseModel

class ModelConfig(BaseModel):
  generate_batch_size: int
  mul: int
  adding_time_features: list
  mean_time_features: float
  std_time_features: float
  value_maxlen: int
  hidden_size: int
  number_units: int
  model_name: str
  learning_rate: float
  steps_per_epoch: int
  epochs: int

def generate_input(issues, train_links, config: ModelConfig):
    match_data = train_links[train_links["label"] != 0]
    none_data = train_links[train_links["label"] == 0]
    match_data = match_data[['key_1', "key_2"]].values
    none_data = none_data[['key_1', "key_2"]].values

    while True:
        each_size = int(config.generate_batch_size/2)

        # Shuffle index of match data
        shuffle_index = [index for index in np.random.choice(
            len(match_data), len(match_data), replace=False)]
        match_data = [match_data[index] for index in shuffle_index]

        for iter in range(int(len(match_data)/each_size)):
            # Split data by batch size and randomly select non_match_links: 1/2 for match data, 1/2 for non-match data

            # Get index
            match_index = np.array(range(iter*each_size, (iter+1)*each_size))
            none_index = np.array([index for index in np.random.choice(
                len(none_data), each_size*config.mul, replace=False)])

            match_links = [match_data[i] for i in match_index]
            none_links = [none_data[i] for i in none_index]

            # Create X by tokenizing and padding X
            index_pairs = np.array(match_links + none_links)
            text_1 = glove_tokenizer(issues["text"].loc[index_pairs[:,0]].values)
            text_1 = tf.keras.utils.pad_sequences(sequences=text_1, padding='post', truncating="post", maxlen=MAXLEN)
            text_2 = glove_tokenizer(issues["text"].loc[index_pairs[:,1]].values)
            text_2 = tf.keras.utils.pad_sequences(sequences=text_2, padding='post', truncating="post", maxlen=MAXLEN)

            # Create label y
            match_y = np.vstack(
                [np.zeros(len(match_links)), np.ones(len(match_links))]).T
            none_y = np.vstack([np.ones(len(none_links)), np.zeros(len(none_links))]).T
            y = np.concatenate([match_y, none_y])

            cre_1 = issues["created"].loc[index_pairs[:, 0]].values
            cre_2 = issues["created"].loc[index_pairs[:, 1]].values
            update = issues["updated"].loc[index_pairs[:, 1]].values
            cre_cre = np.array(
                (cre_1-cre_2) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)
            cre_up =  np.array(
                (cre_1-update) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)
            if len(config.adding_time_features) == 2:
                time_features = np.array(
                    [[cre_cre[i][0], cre_up[i][0]] for i in range(len(cre_cre))])
            elif "CC" in config.adding_time_features:
                time_features = cre_cre
            elif "CU" in config.adding_time_features:
                time_features = cre_up
            index = np.random.choice(len(index_pairs), config.generate_batch_size, replace=False)
            if len(config.adding_time_features) == 0:
                yield [text_1[index], text_2[index]], y[index]
            else:
                time_features = np.array(
                [(time_features[i]-config.mean_time_features)/config.std_time_features for i in range(len(time_features))])
                yield [text_1[index], text_2[index], time_features[index]], y[index]
    return 0

def return_model(config: ModelConfig):
  inputs_A = tf.keras.Input(shape=(config.value_maxlen), name="input_a")
  inputs_B = tf.keras.Input(shape=(config.value_maxlen), name="input_b")

  embedding_layer = tf.keras.layers.Embedding(input_dim=EMBEDDING_MATRIX.shape[0],
                 output_dim=EMBEDDING_MATRIX.shape[1],
                  embeddings_initializer = tf.keras.initializers.Constant(value=EMBEDDING_MATRIX),
                 mask_zero=True)
  embedding_layer.trainable=False
  # Embedding
  emb_A = embedding_layer(inputs_A)
  emb_B = embedding_layer(inputs_B)

  if len(ADDING_TIME_FEATURES)==1:
    inputs_C = tf.keras.Input(shape=(1), name="input_c")
  elif len(ADDING_TIME_FEATURES)==2:
    inputs_C = tf.keras.Input(shape=(2), name="input_c")

  # Deep Learning model's structure
  flatten_layer = tf.keras.layers.Flatten(name="flatten")
  dense_1_layer = tf.keras.layers.Dense(config.number_units, activation="relu", name="dense_1")
  output_layer = tf.keras.layers.Dense(2, activation="softmax", name="dense_output")

  if config.model_name=="CNN":
    core_layer = tf.keras.layers.Conv1D(config.number_units, 3, activation='relu')
  elif config.model_name=="LSTM":
    core_layer = tf.keras.layers.LSTM(config.number_units)
  else:
    core_layer = tf.keras.layers.GRU(config.number_units, name="gru")

  core_A = core_layer(emb_A)
  core_B = core_layer(emb_B)

  if len(ADDING_TIME_FEATURES)==0:

    # Concat two embedded inputs
    X = tf.concat([flatten_layer(core_A), flatten_layer(core_B)], axis=1)

    dense_1_X = dense_1_layer(X)

    outputs = output_layer(dense_1_X)

    model = tf.keras.Model(inputs=[inputs_A, inputs_B], outputs=outputs)

  else:

    # Concat two embedded inputs
    X = tf.concat([flatten_layer(core_A), flatten_layer(core_B), inputs_C], axis=1)

    dense_1_X = dense_1_layer(X)

    outputs = output_layer(dense_1_X)

    model = tf.keras.Model(inputs=[inputs_A, inputs_B, inputs_C], outputs=outputs)

  model.compile(tf.keras.optimizers.Adam(learning_rate=config.learning_rate), loss="mse", metrics=["categorical_accuracy"])
  model.summary()

  return model

def train_model(issues, train_links, config):
  model = return_model(config)
  history = model.fit(generate_input(issues, train_links, config),
              steps_per_epoch=config.steps_per_epoch,
              epochs=config.epochs,
              shuffle=False,
              verbose = 1)
  return model

# %%
def get_normalize_parameter(issues, train_links):
    index_pairs = train_links[["key_1", "key_2"]].values
    cre_1 = issues["created"].loc[index_pairs[:, 0]].values
    cre_2 = issues["created"].loc[index_pairs[:, 1]].values
    update = issues["updated"].loc[index_pairs[:, 1]].values
    cre_cre = np.array((cre_1-cre_2) / np.timedelta64(1,
                       'D'), dtype=int).reshape(-1, 1)
    cre_up = np.array((cre_1-update) / np.timedelta64(1, 'D'),
                      dtype=int).reshape(-1, 1)
    if len(ADDING_TIME_FEATURES) == 2:
        time_features = np.array([[cre_cre[i][0], cre_up[i][0]]
                                 for i in range(len(cre_cre))])
    elif "CC" in ADDING_TIME_FEATURES:
        time_features = cre_cre
    elif "CU" in ADDING_TIME_FEATURES:
        time_features = cre_up
    else:
      time_features = [0]
    mean = np.mean(time_features)
    std = np.std(time_features)
    return mean, std

# %%
MEAN_TIME_FEATURES, STD_TIME_FEATURES = get_normalize_parameter(
    issues, train_links)
print(MEAN_TIME_FEATURES, STD_TIME_FEATURES)
# Out:
# -239.13518612407353 1354.9751217063258

# %%
model_config = ModelConfig(
  model_name = MODEL_NAME,
  generate_batch_size = 128,
  mul = 3,
  adding_time_features = ADDING_TIME_FEATURES,
  mean_time_features = MEAN_TIME_FEATURES,
  std_time_features = STD_TIME_FEATURES,
  value_maxlen = MAXLEN,
  hidden_size = HIDDEN_SIZE,
  number_units = 256,
  learning_rate = 1e-3,
  steps_per_epoch = 5,
  epochs = 200)
model = train_model(issues, train_links, model_config)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_a (InputLayer)        [(None, 256)]                0         []
#
#  input_b (InputLayer)        [(None, 256)]                0         []
#
#  embedding (Embedding)       (None, 256, 300)             5752488   ['input_a[0][0]',
#                                                           00         'input_b[0][0]']
#
#  lstm (LSTM)                 (None, 256)                  570368    ['embedding[0][0]',
#                                                                      'embedding[1][0]']
#
#  flatten (Flatten)           (None, 256)                  0         ['lstm[0][0]',
#                                                                      'lstm[1][0]']
#
#  input_c (InputLayer)        [(None, 2)]                  0         []
#
#  tf.concat (TFOpLambda)      (None, 514)                  0         ['flatten[0][0]',
#                                                                      'flatten[1][0]',
#                                                                      'input_c[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  131840    ['tf.concat[0][0]']
#
#  dense_output (Dense)        (None, 2)                    514       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 575951522 (2.15 GB)
# Trainable params: 702722 (2.68 MB)
# Non-trainable params: 575248800 (2.14 GB)
# __________________________________________________________________________________________________
# Epoch 1/200
# 5/5 [==============================] - 13s 164ms/step - loss: 0.2117 - categorical_accuracy: 0.7203
# Epoch 2/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.1886 - categorical_accuracy: 0.7406
# Epoch 3/200
# 5/5 [==============================] - 1s 254ms/step - loss: 0.1787 - categorical_accuracy: 0.7516
# Epoch 4/200
# 5/5 [==============================] - 1s 265ms/step - loss: 0.1729 - categorical_accuracy: 0.7672
# Epoch 5/200
# 5/5 [==============================] - 2s 351ms/step - loss: 0.1672 - categorical_accuracy: 0.7672
# Epoch 6/200
# 5/5 [==============================] - 2s 408ms/step - loss: 0.1650 - categorical_accuracy: 0.7625
# Epoch 7/200
# 5/5 [==============================] - 2s 423ms/step - loss: 0.1433 - categorical_accuracy: 0.8094
# Epoch 8/200
# 5/5 [==============================] - 1s 261ms/step - loss: 0.1421 - categorical_accuracy: 0.7922
# Epoch 9/200
# 5/5 [==============================] - 1s 236ms/step - loss: 0.1213 - categorical_accuracy: 0.8359
# Epoch 10/200
# 5/5 [==============================] - 1s 246ms/step - loss: 0.1381 - categorical_accuracy: 0.8000
# Epoch 11/200
# 5/5 [==============================] - 1s 253ms/step - loss: 0.1245 - categorical_accuracy: 0.8297
# Epoch 12/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.1201 - categorical_accuracy: 0.8406
# Epoch 13/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.1152 - categorical_accuracy: 0.8281
# Epoch 14/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.1113 - categorical_accuracy: 0.8484
# Epoch 15/200
# 5/5 [==============================] - 1s 269ms/step - loss: 0.0996 - categorical_accuracy: 0.8672
# Epoch 16/200
# 5/5 [==============================] - 3s 688ms/step - loss: 0.1048 - categorical_accuracy: 0.8687
# Epoch 17/200
# 5/5 [==============================] - 3s 524ms/step - loss: 0.0827 - categorical_accuracy: 0.8828
# Epoch 18/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0812 - categorical_accuracy: 0.8969
# Epoch 19/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0903 - categorical_accuracy: 0.8656
# Epoch 20/200
# 5/5 [==============================] - 1s 259ms/step - loss: 0.0723 - categorical_accuracy: 0.9234
# Epoch 21/200
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0752 - categorical_accuracy: 0.9047
# Epoch 22/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0568 - categorical_accuracy: 0.9391
# Epoch 23/200
# 5/5 [==============================] - 1s 264ms/step - loss: 0.0702 - categorical_accuracy: 0.9172
# Epoch 24/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0608 - categorical_accuracy: 0.9250
# Epoch 25/200
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0667 - categorical_accuracy: 0.9281
# Epoch 26/200
# 5/5 [==============================] - 2s 359ms/step - loss: 0.0568 - categorical_accuracy: 0.9328
# Epoch 27/200
# 5/5 [==============================] - 2s 435ms/step - loss: 0.0590 - categorical_accuracy: 0.9250
# Epoch 28/200
# 5/5 [==============================] - 2s 409ms/step - loss: 0.0641 - categorical_accuracy: 0.9172
# Epoch 29/200
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0580 - categorical_accuracy: 0.9203
# Epoch 30/200
# 5/5 [==============================] - 1s 261ms/step - loss: 0.0489 - categorical_accuracy: 0.9422
# Epoch 31/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0528 - categorical_accuracy: 0.9359
# Epoch 32/200
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0467 - categorical_accuracy: 0.9484
# Epoch 33/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0391 - categorical_accuracy: 0.9594
# Epoch 34/200
# 5/5 [==============================] - 1s 254ms/step - loss: 0.0434 - categorical_accuracy: 0.9453
# Epoch 35/200
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0428 - categorical_accuracy: 0.9500
# Epoch 36/200
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0368 - categorical_accuracy: 0.9594
# Epoch 37/200
# 5/5 [==============================] - 2s 360ms/step - loss: 0.0410 - categorical_accuracy: 0.9531
# Epoch 38/200
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0367 - categorical_accuracy: 0.9594
# Epoch 39/200
# 5/5 [==============================] - 2s 421ms/step - loss: 0.0342 - categorical_accuracy: 0.9578
# Epoch 40/200
# 5/5 [==============================] - 1s 239ms/step - loss: 0.0379 - categorical_accuracy: 0.9531
# Epoch 41/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0339 - categorical_accuracy: 0.9609
# Epoch 42/200
# 5/5 [==============================] - 1s 242ms/step - loss: 0.0259 - categorical_accuracy: 0.9750
# Epoch 43/200
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0340 - categorical_accuracy: 0.9547
# Epoch 44/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0279 - categorical_accuracy: 0.9656
# Epoch 45/200
# 5/5 [==============================] - 1s 270ms/step - loss: 0.0365 - categorical_accuracy: 0.9547
# Epoch 46/200
# 5/5 [==============================] - 1s 260ms/step - loss: 0.0336 - categorical_accuracy: 0.9594
# Epoch 47/200
# 5/5 [==============================] - 1s 259ms/step - loss: 0.0272 - categorical_accuracy: 0.9641
# Epoch 48/200
# 5/5 [==============================] - 2s 390ms/step - loss: 0.0306 - categorical_accuracy: 0.9656
# Epoch 49/200
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0217 - categorical_accuracy: 0.9859
# Epoch 50/200
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0218 - categorical_accuracy: 0.9781
# Epoch 51/200
# 5/5 [==============================] - 1s 262ms/step - loss: 0.0247 - categorical_accuracy: 0.9750
# Epoch 52/200
# 5/5 [==============================] - 1s 269ms/step - loss: 0.0222 - categorical_accuracy: 0.9734
# Epoch 53/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0159 - categorical_accuracy: 0.9906
# Epoch 54/200
# 5/5 [==============================] - 1s 239ms/step - loss: 0.0146 - categorical_accuracy: 0.9937
# Epoch 55/200
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0305 - categorical_accuracy: 0.9609
# Epoch 56/200
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0208 - categorical_accuracy: 0.9750
# Epoch 57/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0189 - categorical_accuracy: 0.9812
# Epoch 58/200
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0190 - categorical_accuracy: 0.9812
# Epoch 59/200
# 5/5 [==============================] - 2s 394ms/step - loss: 0.0167 - categorical_accuracy: 0.9844
# Epoch 60/200
# 5/5 [==============================] - 2s 404ms/step - loss: 0.0173 - categorical_accuracy: 0.9781
# Epoch 61/200
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0179 - categorical_accuracy: 0.9781
# Epoch 62/200
# 5/5 [==============================] - 1s 253ms/step - loss: 0.0179 - categorical_accuracy: 0.9844
# Epoch 63/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0174 - categorical_accuracy: 0.9734
# Epoch 64/200
# 5/5 [==============================] - 1s 231ms/step - loss: 0.0187 - categorical_accuracy: 0.9828
# Epoch 65/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0187 - categorical_accuracy: 0.9797
# Epoch 66/200
# 5/5 [==============================] - 1s 243ms/step - loss: 0.0174 - categorical_accuracy: 0.9828
# Epoch 67/200
# 5/5 [==============================] - 1s 235ms/step - loss: 0.0148 - categorical_accuracy: 0.9875
# Epoch 68/200
# 5/5 [==============================] - 1s 240ms/step - loss: 0.0206 - categorical_accuracy: 0.9703
# Epoch 69/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0178 - categorical_accuracy: 0.9812
# Epoch 70/200
# 5/5 [==============================] - 2s 371ms/step - loss: 0.0195 - categorical_accuracy: 0.9781
# Epoch 71/200
# 5/5 [==============================] - 2s 393ms/step - loss: 0.0196 - categorical_accuracy: 0.9781
# Epoch 72/200
# 5/5 [==============================] - 2s 402ms/step - loss: 0.0171 - categorical_accuracy: 0.9828
# Epoch 73/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0151 - categorical_accuracy: 0.9875
# Epoch 74/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0121 - categorical_accuracy: 0.9891
# Epoch 75/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0133 - categorical_accuracy: 0.9875
# Epoch 76/200
# 5/5 [==============================] - 1s 253ms/step - loss: 0.0111 - categorical_accuracy: 0.9891
# Epoch 77/200
# 5/5 [==============================] - 1s 261ms/step - loss: 0.0172 - categorical_accuracy: 0.9828
# Epoch 78/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0138 - categorical_accuracy: 0.9891
# Epoch 79/200
# 5/5 [==============================] - 1s 260ms/step - loss: 0.0129 - categorical_accuracy: 0.9781
# Epoch 80/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0183 - categorical_accuracy: 0.9781
# Epoch 81/200
# 5/5 [==============================] - 1s 323ms/step - loss: 0.0100 - categorical_accuracy: 0.9906
# Epoch 82/200
# 5/5 [==============================] - 2s 424ms/step - loss: 0.0083 - categorical_accuracy: 0.9922
# Epoch 83/200
# 5/5 [==============================] - 2s 389ms/step - loss: 0.0092 - categorical_accuracy: 0.9906
# Epoch 84/200
# 5/5 [==============================] - 1s 239ms/step - loss: 0.0111 - categorical_accuracy: 0.9875
# Epoch 85/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0108 - categorical_accuracy: 0.9906
# Epoch 86/200
# 5/5 [==============================] - 1s 253ms/step - loss: 0.0122 - categorical_accuracy: 0.9844
# Epoch 87/200
# 5/5 [==============================] - 1s 260ms/step - loss: 0.0089 - categorical_accuracy: 0.9937
# Epoch 88/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0131 - categorical_accuracy: 0.9891
# Epoch 89/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0070 - categorical_accuracy: 0.9953
# Epoch 90/200
# 5/5 [==============================] - 1s 242ms/step - loss: 0.0142 - categorical_accuracy: 0.9844
# Epoch 91/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0146 - categorical_accuracy: 0.9844
# Epoch 92/200
# 5/5 [==============================] - 1s 292ms/step - loss: 0.0117 - categorical_accuracy: 0.9859
# Epoch 93/200
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0067 - categorical_accuracy: 0.9906
# Epoch 94/200
# 5/5 [==============================] - 2s 398ms/step - loss: 0.0093 - categorical_accuracy: 0.9906
# Epoch 95/200
# 5/5 [==============================] - 1s 282ms/step - loss: 0.0148 - categorical_accuracy: 0.9844
# Epoch 96/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0162 - categorical_accuracy: 0.9781
# Epoch 97/200
# 5/5 [==============================] - 1s 236ms/step - loss: 0.0082 - categorical_accuracy: 0.9937
# Epoch 98/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0090 - categorical_accuracy: 0.9906
# Epoch 99/200
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0132 - categorical_accuracy: 0.9859
# Epoch 100/200
# 5/5 [==============================] - 1s 253ms/step - loss: 0.0091 - categorical_accuracy: 0.9922
# Epoch 101/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0118 - categorical_accuracy: 0.9875
# Epoch 102/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0129 - categorical_accuracy: 0.9844
# Epoch 103/200
# 5/5 [==============================] - 1s 291ms/step - loss: 0.0114 - categorical_accuracy: 0.9859
# Epoch 104/200
# 5/5 [==============================] - 2s 398ms/step - loss: 0.0099 - categorical_accuracy: 0.9906
# Epoch 105/200
# 5/5 [==============================] - 2s 387ms/step - loss: 0.0072 - categorical_accuracy: 0.9937
# Epoch 106/200
# 5/5 [==============================] - 2s 293ms/step - loss: 0.0087 - categorical_accuracy: 0.9891
# Epoch 107/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0106 - categorical_accuracy: 0.9859
# Epoch 108/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0096 - categorical_accuracy: 0.9922
# Epoch 109/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0073 - categorical_accuracy: 0.9922
# Epoch 110/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0105 - categorical_accuracy: 0.9844
# Epoch 111/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0051 - categorical_accuracy: 0.9969
# Epoch 112/200
# 5/5 [==============================] - 1s 259ms/step - loss: 0.0053 - categorical_accuracy: 0.9937
# Epoch 113/200
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0088 - categorical_accuracy: 0.9891
# Epoch 114/200
# 5/5 [==============================] - 1s 283ms/step - loss: 0.0083 - categorical_accuracy: 0.9906
# Epoch 115/200
# 5/5 [==============================] - 2s 406ms/step - loss: 0.0097 - categorical_accuracy: 0.9891
# Epoch 116/200
# 5/5 [==============================] - 2s 388ms/step - loss: 0.0036 - categorical_accuracy: 0.9984
# Epoch 117/200
# 5/5 [==============================] - 2s 289ms/step - loss: 0.0076 - categorical_accuracy: 0.9937
# Epoch 118/200
# 5/5 [==============================] - 1s 240ms/step - loss: 0.0070 - categorical_accuracy: 0.9937
# Epoch 119/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0104 - categorical_accuracy: 0.9859
# Epoch 120/200
# 5/5 [==============================] - 1s 260ms/step - loss: 0.0089 - categorical_accuracy: 0.9906
# Epoch 121/200
# 5/5 [==============================] - 1s 239ms/step - loss: 0.0044 - categorical_accuracy: 0.9953
# Epoch 122/200
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0111 - categorical_accuracy: 0.9875
# Epoch 123/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0131 - categorical_accuracy: 0.9875
# Epoch 124/200
# 5/5 [==============================] - 1s 243ms/step - loss: 0.0087 - categorical_accuracy: 0.9891
# Epoch 125/200
# 5/5 [==============================] - 1s 254ms/step - loss: 0.0070 - categorical_accuracy: 0.9906
# Epoch 126/200
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0142 - categorical_accuracy: 0.9812
# Epoch 127/200
# 5/5 [==============================] - 2s 396ms/step - loss: 0.0088 - categorical_accuracy: 0.9922
# Epoch 128/200
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0106 - categorical_accuracy: 0.9859
# Epoch 129/200
# 5/5 [==============================] - 1s 254ms/step - loss: 0.0073 - categorical_accuracy: 0.9937
# Epoch 130/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0084 - categorical_accuracy: 0.9922
# Epoch 131/200
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0050 - categorical_accuracy: 0.9953
# Epoch 132/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0070 - categorical_accuracy: 0.9937
# Epoch 133/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0107 - categorical_accuracy: 0.9875
# Epoch 134/200
# 5/5 [==============================] - 1s 243ms/step - loss: 0.0083 - categorical_accuracy: 0.9891
# Epoch 135/200
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0043 - categorical_accuracy: 0.9969
# Epoch 136/200
# 5/5 [==============================] - 1s 242ms/step - loss: 0.0070 - categorical_accuracy: 0.9906
# Epoch 137/200
# 5/5 [==============================] - 2s 396ms/step - loss: 0.0044 - categorical_accuracy: 0.9969
# Epoch 138/200
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0070 - categorical_accuracy: 0.9937
# Epoch 139/200
# 5/5 [==============================] - 2s 340ms/step - loss: 0.0046 - categorical_accuracy: 0.9953
# Epoch 140/200
# 5/5 [==============================] - 1s 263ms/step - loss: 0.0068 - categorical_accuracy: 0.9922
# Epoch 141/200
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0062 - categorical_accuracy: 0.9953
# Epoch 142/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0059 - categorical_accuracy: 0.9937
# Epoch 143/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0045 - categorical_accuracy: 0.9969
# Epoch 144/200
# 5/5 [==============================] - 1s 243ms/step - loss: 0.0051 - categorical_accuracy: 0.9937
# Epoch 145/200
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0061 - categorical_accuracy: 0.9953
# Epoch 146/200
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0099 - categorical_accuracy: 0.9906
# Epoch 147/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0073 - categorical_accuracy: 0.9891
# Epoch 148/200
# 5/5 [==============================] - 2s 393ms/step - loss: 0.0054 - categorical_accuracy: 0.9953
# Epoch 149/200
# 5/5 [==============================] - 2s 388ms/step - loss: 0.0035 - categorical_accuracy: 0.9984
# Epoch 150/200
# 5/5 [==============================] - 2s 365ms/step - loss: 0.0079 - categorical_accuracy: 0.9891
# Epoch 151/200
# 5/5 [==============================] - 1s 239ms/step - loss: 0.0132 - categorical_accuracy: 0.9828
# Epoch 152/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0074 - categorical_accuracy: 0.9953
# Epoch 153/200
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0099 - categorical_accuracy: 0.9891
# Epoch 154/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0102 - categorical_accuracy: 0.9859
# Epoch 155/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0114 - categorical_accuracy: 0.9875
# Epoch 156/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0078 - categorical_accuracy: 0.9922
# Epoch 157/200
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0053 - categorical_accuracy: 0.9969
# Epoch 158/200
# 5/5 [==============================] - 1s 246ms/step - loss: 0.0098 - categorical_accuracy: 0.9859
# Epoch 159/200
# 5/5 [==============================] - 2s 414ms/step - loss: 0.0080 - categorical_accuracy: 0.9906
# Epoch 160/200
# 5/5 [==============================] - 2s 399ms/step - loss: 0.0030 - categorical_accuracy: 0.9984
# Epoch 161/200
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0045 - categorical_accuracy: 0.9937
# Epoch 162/200
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0099 - categorical_accuracy: 0.9875
# Epoch 163/200
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0054 - categorical_accuracy: 0.9953
# Epoch 164/200
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0071 - categorical_accuracy: 0.9937
# Epoch 165/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0066 - categorical_accuracy: 0.9937
# Epoch 166/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0062 - categorical_accuracy: 0.9937
# Epoch 167/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0057 - categorical_accuracy: 0.9937
# Epoch 168/200
# 5/5 [==============================] - 1s 256ms/step - loss: 0.0062 - categorical_accuracy: 0.9906
# Epoch 169/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0047 - categorical_accuracy: 0.9953
# Epoch 170/200
# 5/5 [==============================] - 2s 400ms/step - loss: 0.0036 - categorical_accuracy: 0.9969
# Epoch 171/200
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0043 - categorical_accuracy: 0.9953
# Epoch 172/200
# 5/5 [==============================] - 2s 406ms/step - loss: 0.0037 - categorical_accuracy: 0.9953
# Epoch 173/200
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0034 - categorical_accuracy: 0.9984
# Epoch 174/200
# 5/5 [==============================] - 1s 264ms/step - loss: 0.0052 - categorical_accuracy: 0.9922
# Epoch 175/200
# 5/5 [==============================] - 1s 263ms/step - loss: 0.0073 - categorical_accuracy: 0.9906
# Epoch 176/200
# 5/5 [==============================] - 1s 243ms/step - loss: 0.0034 - categorical_accuracy: 0.9969
# Epoch 177/200
# 5/5 [==============================] - 1s 256ms/step - loss: 0.0038 - categorical_accuracy: 0.9969
# Epoch 178/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0103 - categorical_accuracy: 0.9875
# Epoch 179/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0072 - categorical_accuracy: 0.9922
# Epoch 180/200
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0035 - categorical_accuracy: 0.9984
# Epoch 181/200
# 5/5 [==============================] - 2s 370ms/step - loss: 0.0047 - categorical_accuracy: 0.9969
# Epoch 182/200
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0032 - categorical_accuracy: 0.9969
# Epoch 183/200
# 5/5 [==============================] - 2s 409ms/step - loss: 0.0055 - categorical_accuracy: 0.9953
# Epoch 184/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0065 - categorical_accuracy: 0.9891
# Epoch 185/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0060 - categorical_accuracy: 0.9937
# Epoch 186/200
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0054 - categorical_accuracy: 0.9922
# Epoch 187/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0065 - categorical_accuracy: 0.9922
# Epoch 188/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0019 - categorical_accuracy: 0.9984
# Epoch 189/200
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0073 - categorical_accuracy: 0.9906
# Epoch 190/200
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0097 - categorical_accuracy: 0.9859
# Epoch 191/200
# 5/5 [==============================] - 1s 261ms/step - loss: 0.0089 - categorical_accuracy: 0.9891
# Epoch 192/200
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0121 - categorical_accuracy: 0.9859
# Epoch 193/200
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0055 - categorical_accuracy: 0.9953
# Epoch 194/200
# 5/5 [==============================] - 2s 399ms/step - loss: 0.0052 - categorical_accuracy: 0.9953
# Epoch 195/200
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0059 - categorical_accuracy: 0.9937
# Epoch 196/200
# 5/5 [==============================] - 1s 259ms/step - loss: 0.0052 - categorical_accuracy: 0.9922
# Epoch 197/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0028 - categorical_accuracy: 0.9984
# Epoch 198/200
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0048 - categorical_accuracy: 0.9969
# Epoch 199/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 200/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0107 - categorical_accuracy: 0.9859

# %%
model.save_weights(f"{EMBEDDING_METHOD}_{MODEL_NAME}.h5")

# %% [markdown]
# # Test

# %%
test_links = pd.read_csv(
    f"data/{PROJECT_NAME}/test_links.csv", keep_default_na=False)
test_links['label'] = test_links['label'].map(lambda x: int(x!=0))

# %%
from torch.utils.data import Dataset,  DataLoader
class TestDataset(Dataset):
    def __init__(self, index_pairs, labels):
        self.index_pairs = index_pairs
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
      return [self.index_pairs[idx,0], self.index_pairs[idx,1]], self.labels[idx]

# %%
def get_predict(issues, index_pairs, config, model):
  text_1 = glove_tokenizer(issues["text"].loc[index_pairs[0]].values)
  text_1 = tf.keras.utils.pad_sequences(sequences=text_1, padding='post', truncating="post", maxlen=MAXLEN)
  text_2 = glove_tokenizer(issues["text"].loc[index_pairs[1]].values)
  text_2 = tf.keras.utils.pad_sequences(sequences=text_2, padding='post', truncating="post", maxlen=MAXLEN)
  cre_1 = issues["created"].loc[index_pairs[0]].values
  cre_2 = issues["created"].loc[index_pairs[1]].values
  update = issues["updated"].loc[index_pairs[1]].values
  cre_cre = np.array(
      (cre_1-cre_2) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)
  cre_up =  np.array(
      (cre_1-update) / np.timedelta64(1, 'D'), dtype=np.float64).reshape(-1, 1)

  if len(config.adding_time_features) == 2:
      time_features = np.array(
          [[cre_cre[i][0], cre_up[i][0]] for i in range(len(cre_cre))])
  elif "CC" in config.adding_time_features:
      time_features = cre_cre
  elif "CU" in config.adding_time_features:
      time_features = cre_up
  else:
    return model([text_1, text_2])
  if len(config.adding_time_features) > 0:
    time_features = np.array(
        [(time_features[i]-config.mean_time_features)/config.std_time_features for i in range(len(time_features))])
  return model([text_1, text_2, time_features])

# %%
labels = []
for i in test_links["label"].values:
  if i==0:
    labels.append([1,0])
  else:
    labels.append([0,1])
test_data = TestDataset(test_links[["key_1", "key_2"]].values, labels)

# %%
test_dataloader = DataLoader(test_data, batch_size=2048)
len(test_dataloader)
# Out:
# 243

# %%
if not os.path.exists(f"results_{EMBEDDING_METHOD}_{PROJECT_NAME}"):
  os.mkdir(f"results_{EMBEDDING_METHOD}_{PROJECT_NAME}")

# %%
for index, i in enumerate(test_dataloader):
  index_pairs, label = i
  index_pairs[0] = np.array( index_pairs[0])
  index_pairs[1] = np.array( index_pairs[1])
  proba = get_predict(issues, index_pairs, model_config, model)
  torch.save(proba, f"results_{EMBEDDING_METHOD}_{PROJECT_NAME}/result_{index}.pt")
  torch.cuda.empty_cache()
  print(f"{index}/{len(test_dataloader)}")
# Out:
# 0/243
# 1/243
# 2/243
# 3/243
# 4/243
# 5/243
# 6/243
# 7/243
# 8/243
# 9/243
# 10/243
# 11/243
# 12/243
# 13/243
# 14/243
# 15/243
# 16/243
# 17/243
# 18/243
# 19/243
# 20/243
# 21/243
# 22/243
# 23/243
# 24/243
# 25/243
# 26/243
# 27/243
# 28/243
# 29/243
# 30/243
# 31/243
# 32/243
# 33/243
# 34/243
# 35/243
# 36/243
# 37/243
# 38/243
# 39/243
# 40/243
# 41/243
# 42/243
# 43/243
# 44/243
# 45/243
# 46/243
# 47/243
# 48/243
# 49/243
# 50/243
# 51/243
# 52/243
# 53/243
# 54/243
# 55/243
# 56/243
# 57/243
# 58/243
# 59/243
# 60/243
# 61/243
# 62/243
# 63/243
# 64/243
# 65/243
# 66/243
# 67/243
# 68/243
# 69/243
# 70/243
# 71/243
# 72/243
# 73/243
# 74/243
# 75/243
# 76/243
# 77/243
# 78/243
# 79/243
# 80/243
# 81/243
# 82/243
# 83/243
# 84/243
# 85/243
# 86/243
# 87/243
# 88/243
# 89/243
# 90/243
# 91/243
# 92/243
# 93/243
# 94/243
# 95/243
# 96/243
# 97/243
# 98/243
# 99/243
# 100/243
# 101/243
# 102/243
# 103/243
# 104/243
# 105/243
# 106/243
# 107/243
# 108/243
# 109/243
# 110/243
# 111/243
# 112/243
# 113/243
# 114/243
# 115/243
# 116/243
# 117/243
# 118/243
# 119/243
# 120/243
# 121/243
# 122/243
# 123/243
# 124/243
# 125/243
# 126/243
# 127/243
# 128/243
# 129/243
# 130/243
# 131/243
# 132/243
# 133/243
# 134/243
# 135/243
# 136/243
# 137/243
# 138/243
# 139/243
# 140/243
# 141/243
# 142/243
# 143/243
# 144/243
# 145/243
# 146/243
# 147/243
# 148/243
# 149/243
# 150/243
# 151/243
# 152/243
# 153/243
# 154/243
# 155/243
# 156/243
# 157/243
# 158/243
# 159/243
# 160/243
# 161/243
# 162/243
# 163/243
# 164/243
# 165/243
# 166/243
# 167/243
# 168/243
# 169/243
# 170/243
# 171/243
# 172/243
# 173/243
# 174/243
# 175/243
# 176/243
# 177/243
# 178/243
# 179/243
# 180/243
# 181/243
# 182/243
# 183/243
# 184/243
# 185/243
# 186/243
# 187/243
# 188/243
# 189/243
# 190/243
# 191/243
# 192/243
# 193/243
# 194/243
# 195/243
# 196/243
# 197/243
# 198/243
# 199/243
# 200/243
# 201/243
# 202/243
# 203/243
# 204/243
# 205/243
# 206/243
# 207/243
# 208/243
# 209/243
# 210/243
# 211/243
# 212/243
# 213/243
# 214/243
# 215/243
# 216/243
# 217/243
# 218/243
# 219/243
# 220/243
# 221/243
# 222/243
# 223/243
# 224/243
# 225/243
# 226/243
# 227/243
# 228/243
# 229/243
# 230/243
# 231/243
# 232/243
# 233/243
# 234/243
# 235/243
# 236/243
# 237/243
# 238/243
# 239/243
# 240/243
# 241/243
# 242/243

# %%
pred_proba = torch.tensor([])
for index, _ in tqdm(enumerate(test_dataloader)):
  proba = torch.load(f"results_{EMBEDDING_METHOD}_{PROJECT_NAME}/result_{index}.pt")
  if index==0:
    pred_proba = proba
  else:
    pred_proba=tf.concat([pred_proba, proba],axis=0)
# Out:
# 243it [00:02, 83.58it/s]

# %%
y_s = [np.argmax(i) for i in labels]
pred_s = np.argmax(pred_proba.numpy(),axis=1)

# %%
len(pred_proba)
# Out:
# 496524

# %%
from sklearn.metrics import confusion_matrix, classification_report
print("Confusion maxtrix")
print(confusion_matrix(y_s, pred_s))
print(classification_report(y_s, pred_s, digits= 2))
# Out:
# Confusion maxtrix
# [[494608   1693]
#  [   150     73]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    496301
#            1       0.04      0.33      0.07       223
#
#     accuracy                           1.00    496524
#    macro avg       0.52      0.66      0.54    496524
# weighted avg       1.00      1.00      1.00    496524

# %% [markdown]
# # Recommend

# %%
match_test_links = test_links[test_links["label"]!=0]

# %%
test_issues = pd.read_csv(f"data/{PROJECT_NAME}/test_issues.csv", index_col="key").index

y_test = []
filter_test_issues = []
for test_issue in tqdm(test_issues):
  filter_links = match_test_links[(match_test_links["key_1"]==test_issue)|(match_test_links["key_2"]==test_issue)]
  if len(filter_links)>0:
    match_issues = set(list(filter_links["key_1"].values) + list(filter_links["key_2"].values))
    match_issues.remove(test_issue)
    y_test.append(list(match_issues))
    filter_test_issues.append(test_issue)
test_issues = filter_test_issues
# Out:
# 100%|██████████| 276/276 [00:00<00:00, 1397.95it/s]

# %%
len(test_issues)
# Out:
# 276

# %%
def get_accuracy(pred, gt):
	acc = 0
	for i, item in enumerate(pred):
		if item in gt:
			acc += 1.0
			break
	return acc

def get_MRR(pred, gt):
	mrr = 0
	for i, item in enumerate(pred):
		if item in gt:
			mrr += 1.0/(i+1)
	return mrr

def get_precision_recall(pred, gt):
	right = 0

	for item in gt:
		if item in pred: # relevant
			right+=1

	if len(pred) == 0:
		precision = 0
	else:
		precision = right/len(pred)
	recall = right/len(gt)

	return precision, recall

def get_f1_score(precision, recall):
    if precision + recall == 0:
        return 0
    f1_score = 2 * (precision * recall) / (precision + recall)
    return f1_score

def get_f0_5_score(precision, recall):
    beta = 0.5
    if precision + recall == 0:
        return 0
    f0_5_score = (1 + beta**2) * (precision * recall) / (beta**2 * precision + recall)
    return f0_5_score

def get_f2_score(precision, recall):
    beta = 2
    if precision + recall == 0:
        return 0
    f2_score = (1 + beta**2) * (precision * recall) / (beta**2 * precision + recall)
    return f2_score

def get_metrics(recommend, label):
	acc = 0
	mrr = 0
	precision = 0
	recall = 0
	f1 = 0
	f0_5 = 0
	f2 = 0
	for i in range(0, len(recommend)):
		if len(label[i])!=0:
			acc += get_accuracy(recommend[i], label[i])
			mrr += get_MRR(recommend[i], label[i])
			precision_recall = get_precision_recall(recommend[i], label[i])
			precision += precision_recall[0]
			recall += precision_recall[1]
			f1 = get_f1_score(precision_recall[0], precision_recall[1])
			f0_5 = get_f0_5_score(precision_recall[0], precision_recall[1])
			f2 = get_f2_score(precision_recall[0], precision_recall[1])

	acc = acc/(len(recommend))
	mrr = mrr/(len(recommend))
	precision = precision/(len(recommend))
	recall = recall/(len(recommend))
	f1 = f1/(len(recommend))
	f0_5 = f0_5/(len(recommend))
	f2 = f2/(len(recommend))
	return acc, mrr, precision, recall, f1, f0_5, f2

# %%
def get_recommendation(test_issue, issues, test_links):
  all_issues = list(issues.index)
  all_issues.remove(test_issue)

  test_links_1 = pd.DataFrame(
      {"key_1": [test_issue]*len(all_issues), "key_2": all_issues})
  test_links_1["link_id"] = test_links_1["key_1"] + "-" + test_links_1["key_2"]
  test_links_1 = test_links[test_links["link_id"].isin(test_links_1["link_id"].values)]
  pred_proba_1 = [(pred, issue) for pred, issue in zip(test_links_1["proba"].values, test_links_1["key_2"].values)]

  test_links_2 = pd.DataFrame(
      {"key_1": all_issues, "key_2": [test_issue]*len(all_issues)})
  test_links_2["link_id"] = test_links_2["key_1"] + "-" + test_links_2["key_2"]
  test_links_2 = test_links[test_links["link_id"].isin(test_links_2["link_id"].values)]
  pred_proba_2 = [(pred, issue) for pred, issue in zip(test_links_2["proba"].values, test_links_2["key_1"].values)]

  pred_proba_3 = pred_proba_1 + pred_proba_2
  preprocess_pred_proba = {}
  for pred, issue in pred_proba_3:
    if issue not in preprocess_pred_proba:
      preprocess_pred_proba[issue] = pred
    else:
      preprocess_pred_proba[issue] = max(pred, preprocess_pred_proba[issue])
  preprocess_pred_proba = [(pred, issue) for issue, pred in preprocess_pred_proba.items()]

  return [pair[1] for pair in sorted(preprocess_pred_proba, reverse=True)]

def filter_time(issues, test_issue, recommend_issues, days: int):
    cre_1 = issues["created"].loc[[test_issue]*len(recommend_issues)].values
    cre_2 = issues["created"].loc[recommend_issues].values
    cre_cre = np.abs(
        np.array((cre_1-cre_2) / np.timedelta64(1, 'D'), dtype=int))
    recommend_issues = [i for index, i in enumerate(
        recommend_issues) if cre_cre[index] <= days]
    return recommend_issues

# %%
pred_proba
# Out:
# <tf.Tensor: shape=(496524, 2), dtype=float32, numpy=
# array([[9.99999762e-01, 2.60918227e-07],
#        [9.99988675e-01, 1.13735287e-05],
#        [9.99999881e-01, 1.00601675e-07],
#        ...,
#        [9.99999881e-01, 9.09781335e-08],
#        [1.00000000e+00, 2.84688051e-09],
#        [1.00000000e+00, 5.32193045e-09]], dtype=float32)>

# %%
test_links["link_id"] = test_links["key_1"] + "-" + test_links["key_2"]
test_links["proba"] = pred_proba[:,1]

# %%
recommend_results = []
for test_issue in tqdm(test_issues):
    recommend_results.append(get_recommendation(
        test_issue, issues, test_links))
# Out:
# 100%|██████████| 276/276 [00:17<00:00, 15.78it/s]

# %%
print("---No filter---")
for k in [1,2,3,5,10]:
  recommend_list = [i[:k] for i in recommend_results]
  acc, mrr, precision, recall, f1, f0_5, f2 = get_metrics(recommend_list, y_test)
  print(f"Top {k}:")
  print(f"Acc = {acc}")
  print(f"MRR = {mrr}")
  print(f"Recall = {recall}")
  print(f"F1 = {f1}")
  print(f"F0.5 = {f0_5}")
  print(f"F2 = {f2}")
# Out:
# ---No filter---
# Top 1:
# Acc = 0.15942028985507245
# MRR = 0.15942028985507245
# Recall = 0.15760869565217392
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 2:
# Acc = 0.2210144927536232
# MRR = 0.19202898550724637
# Recall = 0.21316425120772947
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 3:
# Acc = 0.2717391304347826
# MRR = 0.20893719806763295
# Recall = 0.26388888888888895
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 5:
# Acc = 0.2826086956521739
# MRR = 0.21129227053140104
# Recall = 0.27475845410628025
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 10:
# Acc = 0.36231884057971014
# MRR = 0.22172043938348301
# Recall = 0.3502415458937198
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0

# %%
print("---60 days filter---")
filter_recommend_results = []
for test_issue, recommend_issues in zip(test_issues, recommend_results):
    filter_recommend_results.append(
        filter_time(issues, test_issue, recommend_issues, 60))
for k in [1,2,3,5,10]:
  recommend_list = [i[:k] for i in filter_recommend_results]
  acc, mrr, precision, recall, f1, f0_5, f2 = get_metrics(recommend_list, y_test)
  print(f"Top {k}:")
  print(f"Acc = {acc}")
  print(f"MRR = {mrr}")
  print(f"Recall = {recall}")
  print(f"F1 = {f1}")
  print(f"F0.5 = {f0_5}")
  print(f"F2 = {f2}")

print("---30 days filter---")
filter_recommend_results = []
for test_issue, recommend_issues in zip(test_issues, recommend_results):
    filter_recommend_results.append(
        filter_time(issues, test_issue, recommend_issues, 30))
for k in [1,2,3,5,10]:
  recommend_list = [i[:k] for i in filter_recommend_results]
  acc, mrr, precision, recall, f1, f0_5, f2 = get_metrics(recommend_list, y_test)
  print(f"Top {k}:")
  print(f"Acc = {acc}")
  print(f"MRR = {mrr}")
  print(f"Recall = {recall}")
  print(f"F1 = {f1}")
  print(f"F0.5 = {f0_5}")
  print(f"F2 = {f2}")
# Out:
# ---60 days filter---
# Top 1:
# Acc = 0.2391304347826087
# MRR = 0.2391304347826087
# Recall = 0.23128019323671498
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 2:
# Acc = 0.30434782608695654
# MRR = 0.27355072463768115
# Recall = 0.2946859903381643
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 3:
# Acc = 0.3442028985507246
# MRR = 0.2868357487922706
# Recall = 0.33272946859903385
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 5:
# Acc = 0.41304347826086957
# MRR = 0.3040458937198068
# Recall = 0.39975845410628025
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 10:
# Acc = 0.44565217391304346
# MRR = 0.30947492523579484
# Recall = 0.4353864734299517
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# ---30 days filter---
# Top 1:
# Acc = 0.25
# MRR = 0.25
# Recall = 0.2421497584541063
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 2:
# Acc = 0.322463768115942
# MRR = 0.28804347826086957
# Recall = 0.3103864734299517
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 3:
# Acc = 0.33695652173913043
# MRR = 0.29408212560386476
# Recall = 0.32427536231884063
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 5:
# Acc = 0.38405797101449274
# MRR = 0.3067632850241546
# Recall = 0.37439613526570054
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
# Top 10:
# Acc = 0.45652173913043476
# MRR = 0.31685070163331036
# Recall = 0.44625603864734303
# F1 = 0.0
# F0.5 = 0.0
# F2 = 0.0
